# %% [markdown]
# # Step 1 - Get and Prepare Input Datasets

# %%
# Constants
# Number of records we will process
N = 60

# %%
import sys
print(sys.prefix)
# Out:
# /dccstor/shanmukh/sravani_internship/CIF_Benchmark/internship

# %% [markdown]
# ## Get the Test Dataset for constraint generation from github

# %%
# !wget https://raw.githubusercontent.com/gunnusravani/CIF_Benchmark/refs/heads/main/data/outputs/constraint_category_data.csv -O "constraint_category_initial_data.csv"
# Out:
# --2025-06-27 09:28:33--  https://raw.githubusercontent.com/gunnusravani/CIF_Benchmark/refs/heads/main/data/outputs/constraint_category_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 557354 (544K) [text/plain]
# Saving to: ‘constraint_category_initial_data.csv’
#
# constraint_category 100%[===================>] 544.29K  --.-KB/s    in 0.02s
#
# 2025-06-27 09:28:34 (21.4 MB/s) - ‘constraint_category_initial_data.csv’ saved [557354/557354]

# %%
# !pwd
# Out:
# /dccstor/shanmukh/sravani_internship/CIF_Benchmark

# %%
import pandas as pd
full_df = pd.read_csv("constraint_category_initial_data.csv")
full_df.head(60)
# Out:
#                                         dataset  \
# 0         ajibawa-2023/Python-Code-23k-ShareGPT
# 1         ajibawa-2023/Python-Code-23k-ShareGPT
# 2         ajibawa-2023/Python-Code-23k-ShareGPT
# 3         ajibawa-2023/Python-Code-23k-ShareGPT
# 4         ajibawa-2023/Python-Code-23k-ShareGPT
# 5         ajibawa-2023/Python-Code-23k-ShareGPT
# 6         ajibawa-2023/Python-Code-23k-ShareGPT
# 7         ajibawa-2023/Python-Code-23k-ShareGPT
# 8         ajibawa-2023/Python-Code-23k-ShareGPT
# 9         ajibawa-2023/Python-Code-23k-ShareGPT
# 10                              xlangai/DS-1000
# 11                              xlangai/DS-1000
# 12                              xlangai/DS-1000
# 13                              xlangai/DS-1000
# 14                              xlangai/DS-1000
# 15                              xlangai/DS-1000
# 16                              xlangai/DS-1000
# 17                              xlangai/DS-1000
# 18                              xlangai/DS-1000
# 19                              xlangai/DS-1000
# 20                         bigcode/bigcodebench
# 21                         bigcode/bigcodebench
# 22                         bigcode/bigcodebench
# 23                         bigcode/bigcodebench
# 24                         bigcode/bigcodebench
# 25                         bigcode/bigcodebench
# 26                         bigcode/bigcodebench
# 27                         bigcode/bigcodebench
# 28                         bigcode/bigcodebench
# 29                         bigcode/bigcodebench
# 30  Multilingual-Multimodal-NLP/McEval-Instruct
# 31  Multilingual-Multimodal-NLP/McEval-Instruct
# 32  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
# 34  Multilingual-Multimodal-NLP/McEval-Instruct
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 36  Multilingual-Multimodal-NLP/McEval-Instruct
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 38  Multilingual-Multimodal-NLP/McEval-Instruct
# 39  Multilingual-Multimodal-NLP/McEval-Instruct
# 40                             nuprl/EditPackFT
# 41                             nuprl/EditPackFT
# 42                             nuprl/EditPackFT
# 43                             nuprl/EditPackFT
# 44                             nuprl/EditPackFT
# 45                             nuprl/EditPackFT
# 46                             nuprl/EditPackFT
# 47                             nuprl/EditPackFT
# 48                             nuprl/EditPackFT
# 49                             nuprl/EditPackFT
# 50                              nuprl/CanItEdit
# 51                              nuprl/CanItEdit
# 52                              nuprl/CanItEdit
# 53                              nuprl/CanItEdit
# 54                              nuprl/CanItEdit
# 55                              nuprl/CanItEdit
# 56                              nuprl/CanItEdit
# 57                              nuprl/CanItEdit
# 58                              nuprl/CanItEdit
# 59                              nuprl/CanItEdit
#
#                                           instruction  \
# 0   Calculate the distance between two points loca...
# 1   Assuming that the given sentence is stored in ...
# 2   Write a program in Python to find the factoria...
# 3   Create a Python class for Animal with the foll...
# 4   How can I decrypt a set of jokes that are encr...
# 5   What is the purpose of the 'enumerate' keyword...
# 6   Can you provide an example of mutation testing...
# 7   Edit the given code to fix the bug and increas...
# 8   Generate a random password that meets the foll...
# 9   Create a program to combine the elements of tw...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 11  Problem:\n\nI have a logistic regression model...
# 12  Problem:\nHaving a pandas data frame as follow...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 14  Problem:\nSay I have a 3 dimensional numpy arr...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 18  Problem:\nI have a 2-dimensional numpy array w...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 20  Rollback the update of a directory by restorin...
# 21  Randomly generate a pandas DataFrame with spec...
# 22  Extract all names from a string that is not en...
# 23  Replace a random substring (a sequence of char...
# 24  Load e-mail data from a JSON file, convert it ...
# 25  Generate diagrams for the sine and cosine func...
# 26  Perform a chi-square test of independence of v...
# 27  Generates an RSA public and private key pair a...
# 28  Create a list of random numbers, sort them and...
# 29  Search for occurrences of the word "error" in ...
# 30  Write a Python function `calculate_distinct_av...
# 31  Design a Python class `GroupDialogManager` tha...
# 32  You are tasked with creating an automated test...
# 33  In a fictional universe, there are multiple sp...
# 34  Write a Python function `rotate_text` that tak...
# 35  Write a Python module named `motion_control` t...
# 36  Create a Python function named `generate_mobil...
# 37  Design a Python Flask application that acts as...
# 38  Design a self-driving car simulation where the...
# 39  Write a Python function `send_email_with_attac...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 41  Add auth protocol for keystone connection in v...
# 42  Fix up import optional test to use temporary c...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 44  Update manager API for update.\n"""Valve Manag...
# 45  Change Node type a bit\n\nfrom typing import M...
# 46  Make use of the return value of begin() and me...
# 47  Send a message back to client\nimport webapp2\...
# 48  Use Tracking DB Service URL rather than localh...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 51  Fix how the alive neighbor count is calculated...
# 52  Fix the methods in `Course` so that all of the...
# 53  Make the `distances_to` function support negat...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 55  Change the code so that it supports a remove e...
# 56  The distance is not updated correctly, fix the...
# 57  Edit the code to include a method `powermod` t...
# 58  Modify the function syllable_count so each 'co...
# 59  Make the name fully uppercase.\ndef hello_worl...
#
#                                                  code  \
# 0   To calculate the distance between two points i...
# 1   To achieve this, you can use Python's string m...
# 2   Here is a program in Python that finds the fac...
# 3   ```python\nclass Animal:\n    def __init__(sel...
# 4   Sure, here's a Python function that decrypts t...
# 5   The purpose of the 'enumerate' keyword in Pyth...
# 6   Sure, here's an example of mutation testing in...
# 7   ```python\ndef calculate_tax(price):\n    tax_...
# 8   Here is a Python function that generates a ran...
# 9   Here's a Python program that combines the elem...
# 10         plt.plot(*zip(*points))\nplt.yscale("log")
# 11  y = torch.argmax(softmax_output, dim=1).view(-...
# 12  import numpy as np\ndef g(df):\n    softmax = ...
# 13  sns.jointplot(\n    x="total_bill", y="tip", d...
# 14  result = a[:, np.array(second).reshape(-1,1), ...
# 15                   plt.imshow(data)\nplt.colorbar()
# 16  result = True\nfor arr in a:\n    if any(np.is...
# 17  plt.plot(y, x)\nplt.grid(color="blue", linesty...
# 18  bin_data_mean = data[:,:(data.shape[1] // bin_...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 20  # Check if the backup directory exists\n    if...
# 21  # Generate random data and create a DataFrame\...
# 22  names = re.findall('(.*?)(?:\\[.*?\\]|$)', tex...
# 23  random.seed(seed)\n\n    df = pd.DataFrame(dat...
# 24  with open(json_file, 'r') as file:\n        em...
# 25  x_values = np.linspace(0, 2 * np.pi, 400)\n   ...
# 26  # Check if DataFrame is empty\n    if data.emp...
# 27  (pub_key, priv_key) = rsa.newkeys(512)\n    pa...
# 28  if range_limit <= 1:\n        raise ValueError...
# 29  if not os.path.isdir(dir_path):\n        raise...
# 30  ```python\nfrom __future__ import division\n\n...
# 31  ```python\nimport argparse\nfrom termcolor imp...
# 32  ```python\nimport unittest\nfrom selenium impo...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
# 34  ```python\ndef rotate_text(text, rotation):\n ...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 36  ```python\nimport pandas as pd\nimport plotly....
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 38  ```python\nimport pygame as pg\nimport math\nf...
# 39  ```python\nimport smtplib\nfrom email.mime.mul...
# 40  import sys # Used to get rid of py2/3 differen...
# 41  import string\n\ntemplate = string.Template(""...
# 42  import os\nimport subprocess\nimport sys\n\nne...
# 43  import os\n\nfrom unittest import TestCase\nfr...
# 44  """Valve Manager base class"""\n\n# pylint: di...
# 45  from typing import Mapping, Set, Callable, Uni...
# 46  import NDIR\nimport time\n\nsensor = NDIR.Sens...
# 47  import webapp2\n\nfrom google.appengine.api im...
# 48  import pandas as pd\nimport sys\n\n\ndf = pd.r...
# 49  import os\nimport numpy as np\nfrom whaler.dat...
# 50  import math\nfrom typing import List, Dict\n\n...
# 51  from typing import List\n\n\nclass ConwaysGame...
# 52  import functools\nimport numpy as np\nclass St...
# 53  class Graph:\n    def __init__(self):\n       ...
# 54  class Comparators:\n    """\n    A class for t...
# 55  from abc import ABC, abstractmethod\n\nclass L...
# 56  class StepCounter:\n    def __init__(self):\n ...
# 57  import math\n\ndef gcd(a : int, b : int) -> in...
# 58  import string\n\ndef prepare_string(line):\n  ...
# 59  def hello_world(name):\n    return f'{name.upp...
#
#                                                  test  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 11  import torch\nimport copy\n\n\ndef generate_te...
# 12  import pandas as pd\nimport numpy as np\nimpor...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 14  import numpy as np\nimport pandas as pd\nimpor...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 16  import numpy as np\nimport pandas as pd\nimpor...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 18  import numpy as np\nimport pandas as pd\nimpor...
# 19  import copy\nfrom scipy import sparse\n\n\ndef...
# 20  import unittest\nfrom unittest.mock import pat...
# 21  import unittest\nclass TestCases(unittest.Test...
# 22  import unittest\nfrom unittest.mock import pat...
# 23  import unittest\nimport random\nclass TestCase...
# 24  import os\nimport shutil\nimport unittest\ncla...
# 25  import unittest\nimport numpy as np\nimport ma...
# 26  import unittest\nimport pandas as pd\nimport n...
# 27  import unittest\nimport os\nimport rsa\nfrom C...
# 28  import unittest\nimport doctest\nclass TestCas...
# 29  import unittest\nimport os\nimport shutil\nimp...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
#
#                                       Characteristics  \
# 0   1) Logic is modularized using calculate_distan...
# 1   1) Embed the HTML tag using an f-string to dyn...
# 2   1) The function factorial is implemented recur...
# 3   The class defines six attributes: species, nam...
# 4   The function is named decryptJokes and accepts...
# 5   It specifies that enumerate() returns an enume...
# 6   A test module (test_calculate_area.py) is crea...
# 7   The function calculates the base tax at a fixe...
# 8   Accepts a user-specified password length.\n\nA...
# 9   Correct Solution:\n                           ...
# 10  Imports necessary libraries: numpy, pandas, an...
# 11  Uses torch.argmax() to find the index of the m...
# 12  Initializes the DataFrame with columns 'a' (gr...
# 13  Imports required libraries: matplotlib.pyplot,...
# 14  Uses numpy to handle high-dimensional array ma...
# 15  Uses matplotlib.pyplot for plotting.\n\nImport...
# 16  Imports NumPy to utilize np.nan and np.isnan()...
# 17  Uses NumPy to generate x and y as sequences fr...
# 18  Uses NumPy for array manipulation and numerica...
# 19  Concatenates two csr_matrix objects horizontal...
# 20  Uses os.path.exists to check for the existence...
# 21  Generates a NumPy array of shape (length, 5) u...
# 22  Uses re.findall('(.*?)(?:\\[.*?\\]|$)', text) ...
# 23  Uses random.seed(seed) to ensure reproducibili...
# 24  Reads email data from a JSON file using json.l...
# 25  Uses NumPy to generate 400 evenly spaced value...
# 26  Accepts a Pandas DataFrame and two column name...
# 27  Generates an RSA public/private key pair with ...
# 28  Validates range_limit and raises ValueError if...
# 29  Validates that the input path is a directory; ...
# 30  Returns 0.0 if the input list is empty\n\nUses...
# 31  Uses argparse to support a command-line interf...
# 32  Uses the unittest testing framework with setUp...
# 33  The class accepts an external sde_client, allo...
# 34  Uses modulo arithmetic (% 26) to wrap letters ...
# 35  Converts between steps and millimeters using a...
# 36  Converts steps to millimeters using a configur...
# 37  Implements a Flask-based service with no route...
# 38  Initializes a Flask app configured to connect ...
# 39  The provided Python function send_email_with_a...
# 40  Ensures consistent behavior of exec and raw_in...
# 41  Adds AUTHN_PROTOCOL = http under the [auth] se...
# 42  Specifies an output path using -o tmp/import-o...
# 43  Adds a unit test for validating Groovy source ...
# 44  Introduces a new method update_vlan(self, vlan...
# 45  The Node type has been generalized from a spec...
# 46  Checks the return value of sensor.begin() to e...
# 47  Replaces localhost with a service URL run-trac...
# 48  Replaces localhost with a service URL run-trac...
# 49  Automatically identifies subdirectories in the...
# 50    "Precomputes document frequencies and term f...
# 51  "Precomputes document frequencies and term fre...
# 52  No for, while, or map keywords used\n\nAll met...
# 53  Replaces Dijkstra’s algorithm with the Bellman...
# 54  Implements a custom two-level sorting mechanis...
# 55  Adds support for element removal by defining a...
# 56  Fixes the off-by-one error in distance calcula...
# 57  ntroduces a powermod method using recursive su...
# 58  Introduces a new combo function to detect and ...
# 59  Applies a transformation using str.upper() to ...
#
#                                           constraints  \
# 0   ['Implement the distance calculation in a sepa...
# 1   ["Provide a concise solution using Python's st...
# 2   ['The program must use recursion to calculate ...
# 3   ['Include detailed docstrings for each method,...
# 4   ['Provide a complete Python function implement...
# 5   ["Provide a clear and concise explanation of t...
# 6   ['Use `mutmut` and `pytest` for mutation testi...
# 7   ['Add a new condition to apply a handling fee ...
# 8   ['Include a Python function for password gener...
# 9   ['Define a function named `combine_and_sort_li...
# 10  ['Use minimal code to achieve the task.', 'Inc...
# 11  ['Provide a direct and concise code solution w...
# 12  ['Use an iterative approach to compute softmax...
# 13  [\n  "Must use seaborn.jointplot()",\n  "Must ...
# 14  ['Use numpy arrays for indexing instead of lis...
# 15  ['Do not include any customization of plot aes...
# 16  ['Use an explicit for-loop to iterate over eac...
# 17  ['Create a simple line plot without additional...
# 18  ['Use vectorized operations to ensure efficien...
# 19  ["Use 'sparse.hstack' for concatenating the ma...
# 20  ['Check for the existence of the backup direct...
# 21  ['Use np.random.randint to generate random dat...
# 22  ['Use a regex pattern to capture names outside...
# 23  ['Set the random seed at the beginning of the ...
# 24  ["Use pandas for data manipulation and ensure ...
# 25  ['Use numpy to generate x_values with np.linsp...
# 26  ['Check if the DataFrame is empty and raise a ...
# 27  ['Generate RSA keys with a size of 512 bits.',...
# 28  ['Handle ValueError for range_limit less than ...
# 29  ['Ensure the directory existence check uses os...
# 30  ["Include a docstring that describes the funct...
# 31  ['Implement a `GroupDialogManager` class with ...
# 32  ['The test class must extend from `unittest.Te...
# 33  [\n  "The Station class must be initialized wi...
# 34  ["Include a detailed docstring explaining the ...
# 35  ['Include detailed docstrings for each functio...
# 36  ['Use Plotly for creating subplots and visuali...
# 37  ['Use SQLAlchemy ORM for database interactions...
# 38  ['Implement a Car class with methods for movem...
# 39  ['Use `smtplib` and `email.mime` libraries for...
# 40  [\n  "Ensure compatibility between Python 2 an...
# 41  ["Include 'AUTHN_PROTOCOL = http' in the [auth...
# 42  ["Include the '-o tmp/import-optional-missing....
# 43  ["Include specific assertions to verify the pr...
# 44  ["Add a new method 'update_vlan' with a docstr...
# 45  ["Define Node as a Union of 'OrientedDNASegmen...
# 46  ['Check the return value of sensor.begin() and...
# 47  ['Include a direct call to the `send_message` ...
# 48  ["Replace 'localhost' with 'run-tracking-db.se...
# 49  ['Ensure the import statement includes numpy a...
# 50  ['Compute and store document frequencies for e...
# 51  ['Include boundary checks in the computation o...
# 52  ['Use `functools.reduce` to iterate over stude...
# 53  ['Implement the Bellman-Ford algorithm to hand...
# 54  ['Ensure the function definition is clear and ...
# 55  ['Implement the `remove` method to correctly r...
# 56  ['Ensure the response is concise and to the po...
# 57  ['Implement the powermod function using recurs...
# 58  ["Define a separate function to identify and c...
# 59  ["Apply the .upper() method directly to the 'n...
#
#                                  Characteristics_List  \
# 0   ['Logic is modularized using calculate_distanc...
# 1   ['Embed the HTML tag using an f-string to dyna...
# 2   ['The function factorial is implemented recurs...
# 3   ['The class defines six attributes: species, n...
# 4   ['The function is named decryptJokes and accep...
# 5   ['It specifies that enumerate() returns an enu...
# 6   ['A test module (test_calculate_area.py) is cr...
# 7   ['The function calculates the base tax at a fi...
# 8   ['Accepts a user-specified password length.', ...
# 9   ['Defines a function named combine_lists.', 'A...
# 10  ['Imports necessary libraries: numpy, pandas, ...
# 11  ['Uses torch.argmax() to find the index of the...
# 12  ["Initializes the DataFrame with columns 'a' (...
# 13  ['Imports required libraries: matplotlib.pyplo...
# 14  ['Uses numpy to handle high-dimensional array ...
# 15  ['Uses matplotlib.pyplot for plotting.', 'Impo...
# 16  ['Imports NumPy to utilize np.nan and np.isnan...
# 17  ['Uses NumPy to generate x and y as sequences ...
# 18  ['Uses NumPy for array manipulation and numeri...
# 19  ['Concatenates two csr_matrix objects horizont...
# 20  ['Uses os.path.exists to check for the existen...
# 21  ['Generates a NumPy array of shape (length, 5)...
# 22  ["Uses re.findall('(.*?)(?:\\[.*?\\]|$)', text...
# 23  ['Uses random.seed(seed) to ensure reproducibi...
# 24  ['Reads email data from a JSON file using json...
# 25  ['Uses NumPy to generate 400 evenly spaced val...
# 26  ['Accepts a Pandas DataFrame and two column na...
# 27  ['Generates an RSA public/private key pair wit...
# 28  ["Validates range_limit and raises ValueError ...
# 29  ['Validates that the input path is a directory...
# 30  ['Returns 0.0 if the input list is empty.', 'U...
# 31  ['Uses argparse to support a command-line inte...
# 32  ['Uses the unittest testing framework with set...
# 33  ['The class accepts an external sde_client, al...
# 34  ["Uses modulo arithmetic (% 26) to wrap letter...
# 35  ['Converts between steps and millimeters using...
# 36  ['Converts steps to millimeters using a config...
# 37  ['Implements a Flask-based service with no rou...
# 38  ['Initializes a Flask app configured to connec...
# 39  ['The provided Python function send_email_with...
# 40  ['Ensures consistent behavior of exec and raw_...
# 41  ['Adds AUTHN_PROTOCOL = http under the [auth] ...
# 42  ['Specifies an output path using -o tmp/import...
# 43  ['Adds a unit test for validating Groovy sourc...
# 44  ['Introduces a new method update_vlan(self, vl...
# 45  ['The Node type has been generalized from a sp...
# 46  ['Checks the return value of sensor.begin() to...
# 47  ['Replaces localhost with a service URL run-tr...
# 48  ['Replaces localhost with a service URL run-tr...
# 49  ['Automatically identifies subdirectories in t...
# 50  ['Precomputes document frequencies and term fr...
# 51  ['Precomputes document frequencies and term fr...
# 52  ['No for, while, or map keywords used.', 'All ...
# 53  ['Replaces Dijkstra’s algorithm with the Bellm...
# 54  ['Implements a custom two-level sorting mechan...
# 55  ['Adds support for element removal by defining...
# 56  ['Fixes the off-by-one error in distance calcu...
# 57  ['Introduces a powermod method using recursive...
# 58  ['Introduces a new combo function to detect an...
# 59  ['Applies a transformation using str.upper() t...
#
#                                Mapped_Characteristics  \
# 0   {'Modularization': ['Logic is modularized usin...
# 1   {'HTML Tagging Methodology': ['Embed the HTML ...
# 2   {'Functionality': ['The function factorial is ...
# 3   {'Attributes': ['The class defines six attribu...
# 4   {'Function Definition': ['The function is name...
# 5   {'Functionality Description': ['It specifies t...
# 6   {'Test Module Creation': ['A test module (test...
# 7   {'Tax Calculation': ['The function calculates ...
# 8   {'User Input Requirements': ['Accepts a user-s...
# 9   {'Function Definition': ['Defines a function n...
# 10  {'Library Imports': ['Imports necessary librar...
# 11  {'Tensor Operations': ['Uses torch.argmax() to...
# 12  {'DataFrame Initialization': ["Initializes the...
# 13  {'Library Imports': ['Imports required librari...
# 14  {'Numpy Usage': ['Uses numpy to handle high-di...
# 15  {'Library Usage': ['Uses matplotlib.pyplot for...
# 16  {'Import Statements': ['Imports NumPy to utili...
# 17  {'Library Usage': ['Uses NumPy to generate x a...
# 18  {'Library Usage': ['Uses NumPy for array manip...
# 19  {'Matrix Operations': ['Concatenates two csr_m...
# 20  {'Backup Directory Checks': ['Uses os.path.exi...
# 21  {'Data Generation': ['Generates a NumPy array ...
# 22  {'Regex Operations': ["Uses re.findall('(.*?)(...
# 23  {'Reproducibility': ['Uses random.seed(seed) t...
# 24  {'Data Handling': ['Reads email data from a JS...
# 25  {'Data Generation': ['Uses NumPy to generate 4...
# 26  {'Input Requirements': ['Accepts a Pandas Data...
# 27  {'Key Generation': ['Generates an RSA public/p...
# 28  {'Input Validation': ["Validates range_limit a...
# 29  {'Input Validation': ['Validates that the inpu...
# 30  {'Return Behavior': ['Returns 0.0 if the input...
# 31  {'Command-Line Interface': ['Uses argparse to ...
# 32  {'Testing Framework': ['Uses the unittest test...
# 33  {'Class Design': ['The class accepts an extern...
# 34  {'Rotation Logic': ["Uses modulo arithmetic (%...
# 35  {'Conversion Functions': ['Converts between st...
# 36  {'Conversion Operations': ['Converts steps to ...
# 37  {'Flask Application Characteristics': ['Implem...
# 38  {'Web Framework Initialization': ['Initializes...
# 39  {'Function Characteristics': ['The provided Py...
# 40  {'Cross-Version Compatibility': ['Ensures cons...
# 41  {'Configuration Enhancement': ['Adds AUTHN_PRO...
# 42  {'Output Management': ['Specifies an output pa...
# 43  {'Unit Test Characteristics': ['Adds a unit te...
# 44  {'Method Addition': ['Introduces a new method ...
# 45  {'Node Type Modification': ['The Node type has...
# 46  {'Initialization Checks': ['Checks the return ...
# 47  {'Database Configuration': ['Replaces localhos...
# 48  {'Database Connection Configuration': ['Replac...
# 49  {'Directory Management': ['Automatically ident...
# 50  {'Optimization Techniques': ['Precomputes docu...
# 51  {'Performance Optimization': ['Precomputes doc...
# 52  {'Code Structure Constraints': ['No for, while...
# 53  {'Algorithm Change': ['Replaces Dijkstra’s alg...
# 54  {'Sorting Mechanism': ['Implements a custom tw...
# 55  {'Method Implementation': ['Adds support for e...
# 56  {'Bug Fixes': ['Fixes the off-by-one error in ...
# 57  {'Functionality Enhancement': ['Introduces a p...
# 58  {'Functionality Enhancement': ['Introduces a n...
# 59  {'TRANSFORMATION': ['Applies a transformation ...
#
#                                    Mapped_Constraints  \
# 0   {'Function Implementation': ['Implement the di...
# 1   {'Solution Requirements': ["Provide a concise ...
# 2   {'Functionality Requirements': ['The program m...
# 3   {'Docstring Requirements': ['Include detailed ...
# 4   {'Function Implementation': ['Provide a comple...
# 5   {'Purpose Explanation': ["Provide a clear and ...
# 6   {'Mutation Testing Tools': ['Use `mutmut` and ...
# 7   {'Complexity Enhancement': ['Add a new conditi...
# 8   {'Functionality Requirements': ['Include a Pyt...
# 9   {'Function Definition': ['Define a function na...
# 10  {'Code Minimalism': ['Use minimal code to achi...
# 11  {'Code Requirements': ['Provide a direct and c...
# 12  {'Iterative Approach': ['Use an iterative appr...
# 13  {'Function Usage': ['Must use seaborn.jointplo...
# 14  {'Indexing Method': ['Use numpy arrays for ind...
# 15  {'Plot Customization Restrictions': ['Do not i...
# 16  {'Looping and Iteration': ['Use an explicit fo...
# 17  {'Plotting Constraints': ['Create a simple lin...
# 18  {'Efficiency': ['Use vectorized operations to ...
# 19  {'Function Usage': ["Use 'sparse.hstack' for c...
# 20  {'Backup Existence Checks': ['Check for the ex...
# 21  {'Data Generation Constraints': ['Use np.rando...
# 22  {'Regex Pattern Usage': ['Use a regex pattern ...
# 23  {'Reproducibility': ['Set the random seed at t...
# 24  {'DataFrame Structure': ["Use pandas for data ...
# 25  {'Data Generation': ['Use numpy to generate x_...
# 26  {'Data Validation': ['Check if the DataFrame i...
# 27  {'RSA Key Generation': ['Generate RSA keys wit...
# 28  {'Error Handling': ['Handle ValueError for ran...
# 29  {'Directory and File Handling': ['Ensure the d...
# 30  {'Function Documentation': ["Include a docstri...
# 31  {'Class Design': ['Implement a `GroupDialogMan...
# 32  {'Test Class Structure': ['The test class must...
# 33  {'Initialization Requirements': ['The Station ...
# 34  {'Documentation': ["Include a detailed docstri...
# 35  {'Documentation': ['Include detailed docstring...
# 36  {'Visualization Library': ['Use Plotly for cre...
# 37  {'Database Interaction': ['Use SQLAlchemy ORM ...
# 38  {'Class Implementation': ['Implement a Car cla...
# 39  {'Library Usage': ['Use `smtplib` and `email.m...
# 40  {'Compatibility': ['Ensure compatibility betwe...
# 41  {'Configuration Directives': ["Include 'AUTHN_...
# 42  {'Output File Specification': ["Include the '-...
# 43  {'Assertions': ["Include specific assertions t...
# 44  {'Method Addition': ["Add a new method 'update...
# 45  {'Type Modification': ["Define Node as a Union...
# 46  {'Error Handling': ['Check the return value of...
# 47  {'Functionality Constraints': ['Include a dire...
# 48  {'Connection String Modification': ["Replace '...
# 49  {'Import Statements': ['Ensure the import stat...
# 50  {'Initialization Optimization': ['Compute and ...
# 51  {'Boundary Checks': ['Include boundary checks ...
# 52  {'Iteration Method': ['Use `functools.reduce` ...
# 53  {'Algorithm Implementation': ['Implement the B...
# 54  {'Function Clarity': ['Ensure the function def...
# 55  {'Method Implementation': ['Implement the `rem...
# 56  {'Response Clarity': ['Ensure the response is ...
# 57  {'Function Implementation': ['Implement the po...
# 58  {'Functionality Requirements': ["Define a sepa...
# 59  {'INLINE TRANSFORMATION': ["Apply the .upper()...
#
#                             Mapped_Characteristics_v2  \
# 0   {'modularization': ['Logic is modularized usin...
# 1   {'string manipulation': ['Embed the HTML tag u...
# 2   {'function': ['The function factorial is imple...
# 3   {'attributes': ['The class defines six attribu...
# 4   {'function': ['The function is named decryptJo...
# 5   {'functionality': ['It specifies that enumerat...
# 6   {'test_module': ['A test module (test_calculat...
# 7   {'tax_calculation': ['The function calculates ...
# 8   {'user_input': ['Accepts a user-specified pass...
# 9   {'function': ['Defines a function named combin...
# 10  {'import': ['Imports necessary libraries: nump...
# 11  {'tensor_operation': ['Uses torch.argmax() to ...
# 12  {'dataframe_initialization': ["Initializes the...
# 13  {'library_imports': ['Imports required librari...
# 14  {'library': ['Uses numpy to handle high-dimens...
# 15  {'library_usage': ['Uses matplotlib.pyplot for...
# 16  {'import': ['Imports NumPy to utilize np.nan a...
# 17  {'library_usage': ['Uses NumPy to generate x a...
# 18  {'library': ['Uses NumPy for array manipulatio...
# 19  {'concatenation': ['Concatenates two csr_matri...
# 20  {'file_operations': ['Uses os.path.exists to c...
# 21  {'data_generation': ['Generates a NumPy array ...
# 22  {'regex': ["Uses re.findall('(.*?)(?:\\[.*?\\]...
# 23  {'randomness': ['Uses random.seed(seed) to ens...
# 24  {'data handling': ['Reads email data from a JS...
# 25  {'library_usage': ['Uses NumPy to generate 400...
# 26  {'input': ['Accepts a Pandas DataFrame and two...
# 27  {'key_generation': ['Generates an RSA public/p...
# 28  {'error_handling': ["Validates range_limit and...
# 29  {'error handling': ['Validates that the input ...
# 30  {'return': ['Returns 0.0 if the input list is ...
# 31  {'command_line_interface': ['Uses argparse to ...
# 32  {'testing_framework': ['Uses the unittest test...
# 33  {'class_structure': ['The class accepts an ext...
# 34  {'rotation_logic': ["Uses modulo arithmetic (%...
# 35  {'conversion': ['Converts between steps and mi...
# 36  {'conversion': ['Converts steps to millimeters...
# 37  {'service': ['Implements a Flask-based service...
# 38  {'web_framework': ['Initializes a Flask app co...
# 39  {'implementation': ['The provided Python funct...
# 40  {'cross_version_compatibility': ['Ensures cons...
# 41  {'configuration': ['Adds AUTHN_PROTOCOL = http...
# 42  {'output_path': ['Specifies an output path usi...
# 43  {'unit_test': ['Adds a unit test for validatin...
# 44  {'method': ['Introduces a new method update_vl...
# 45  {'type_modification': ['The Node type has been...
# 46  {'initialization': ['Checks the return value o...
# 47  {'database_connection': ['Replaces localhost w...
# 48  {'database_connection': ['Replaces localhost w...
# 49  {'directory_handling': ['Automatically identif...
# 50  {'optimization': ['Precomputes document freque...
# 51  {'performance_optimization': ['Precomputes doc...
# 52  {'keyword_restriction': ['No for, while, or ma...
# 53  {'algorithm': ['Replaces Dijkstra’s algorithm ...
# 54  {'sorting mechanism': ['Implements a custom tw...
# 55  {'method_definition': ['Adds support for eleme...
# 56  {'bug_fix': ['Fixes the off-by-one error in di...
# 57  {'function': ['Introduces a powermod method us...
# 58  {'functionality': ['Introduces a new combo fun...
# 59  {'transformation': ['Applies a transformation ...
#
#                                 Mapped_Constraints_v2  \
# 0   {'function': ['Implement the distance calculat...
# 1   {'solution': ["Provide a concise solution usin...
# 2   {'recursion': ['The program must use recursion...
# 3   {'docstring': ['Include detailed docstrings fo...
# 4   {'function': ['Provide a complete Python funct...
# 5   {'explanation': ["Provide a clear and concise ...
# 6   {'mutation_testing_tool': ['Use `mutmut` and `...
# 7   {'feature': ['Add a new condition to apply a h...
# 8   {'function': ['Include a Python function for p...
# 9   {'function': ['Define a function named `combin...
# 10  {'code simplicity': ['Use minimal code to achi...
# 11  {'code_solution': ['Provide a direct and conci...
# 12  {'iteration': ['Use an iterative approach to c...
# 13  {'function': ['Must use seaborn.jointplot()'],...
# 14  {'indexing': ['Use numpy arrays for indexing i...
# 15  {'plot aesthetics': ['Do not include any custo...
# 16  {'loop': ['Use an explicit for-loop to iterate...
# 17  {'plotting': ['Create a simple line plot witho...
# 18  {'efficiency': ['Use vectorized operations to ...
# 19  {'function_usage': ["Use 'sparse.hstack' for c...
# 20  {'backup_check': ['Check for the existence of ...
# 21  {'data_generation': ['Use np.random.randint to...
# 22  {'regex': ['Use a regex pattern to capture nam...
# 23  {'random_seed': ['Set the random seed at the b...
# 24  {'data_manipulation': ["Use pandas for data ma...
# 25  {'library_usage': ['Use numpy to generate x_va...
# 26  {'data_validation': ['Check if the DataFrame i...
# 27  {'key_generation': ['Generate RSA keys with a ...
# 28  {'error_handling': ['Handle ValueError for ran...
# 29  {'error_handling': ['Ensure the directory exis...
# 30  {'documentation': ["Include a docstring that d...
# 31  {'class_definition': ['Implement a `GroupDialo...
# 32  {'class_structure': ['The test class must exte...
# 33  {'initialization': ['The Station class must be...
# 34  {'documentation': ["Include a detailed docstri...
# 35  {'documentation': ['Include detailed docstring...
# 36  {'visualization_library': ['Use Plotly for cre...
# 37  {'database_interaction': ['Use SQLAlchemy ORM ...
# 38  {'class_definition': ['Implement a Car class w...
# 39  {'library': ['Use `smtplib` and `email.mime` l...
# 40  {'compatibility': ['Ensure compatibility betwe...
# 41  {'configuration': ["Include 'AUTHN_PROTOCOL = ...
# 42  {'output_file': ["Include the '-o tmp/import-o...
# 43  {'assertions': ["Include specific assertions t...
# 44  {'method': ["Add a new method 'update_vlan' wi...
# 45  {'type_definition': ["Define Node as a Union o...
# 46  {'return_value_check': ['Check the return valu...
# 47  {'method_call': ['Include a direct call to the...
# 48  {'connection_string': ["Replace 'localhost' wi...
# 49  {'import': ['Ensure the import statement inclu...
# 50  {'initialization': ['Compute and store documen...
# 51  {'boundary_check': ['Include boundary checks i...
# 52  {'iteration_method': ['Use `functools.reduce` ...
# 53  {'algorithm': ['Implement the Bellman-Ford alg...
# 54  {'function clarity': ['Ensure the function def...
# 55  {'method implementation': ['Implement the `rem...
# 56  {'response_format': ['Ensure the response is c...
# 57  {'function': ['Implement the powermod function...
# 58  {'function': ["Define a separate function to i...
# 59  {'method_usage': ["Apply the .upper() method d...
#
#                                         categories_v1  \
# 0   ["Modularity", "Rounding", "Vector Calculation...
# 1   ["String Manipulation", "HTML Integration", "C...
# 2   ["Recursion", "Input Validation", "Error Handl...
# 3   ["Attributes", "Methods", "Documentation", "Er...
# 4   ["Function Implementation", "Text Decryption",...
# 5   ["Explanation", "Code Example", "Error Handlin...
# 6   ["Mutation Testing", "Code Coverage", "Testing...
# 7   ["Complexity", "Condition Handling", "Fee Calc...
# 8   ["Functionality", "Input Handling", "Output Fo...
# 9   ["Function Definition", "Input Handling", "Lis...
# 10  ["Code Efficiency", "Code Minimalism", "Plotti...
# 11  ["Code Efficiency", "Functionality", "Output F...
# 12  ["DataFrame Manipulation", "Mathematical Compu...
# 13  ["Library Usage", "Data Visualization", "Plot ...
# 14  ["Array Manipulation", "Indexing", "Vectorizat...
# 15  ["Plotting Constraints", "Aesthetic Constraint...
# 16  ["Looping Constructs", "Array Manipulation", "...
# 17  ["Plotting", "Customization", "Data Visualizat...
# 18  ["Efficiency", "Array Manipulation", "Vectoriz...
# 19  ["Matrix Operations", "Sparse Matrix Handling"...
# 20  ["Directory Management", "File Operations", "E...
# 21  ["Data Generation", "DataFrame Creation", "Sta...
# 22  ["Regex Usage", "Email Formatting", "SMTP Conn...
# 23  ["Reproducibility", "DataFrame Creation", "Str...
# 24  ["Data Manipulation", "Data Visualization", "E...
# 25  ["Function Definition", "Plotting", "Subplot A...
# 26  ["Input Validation", "Statistical Assumptions"...
# 27  ["Key Generation", "Encryption", "File Handlin...
# 28  ["Error Handling", "Reproducibility", "Random ...
# 29  ["Error Handling", "File I/O", "File Searching...
# 30  ["Function Definition", "Input Handling", "Out...
# 31  ["Class Design", "Command-Line Interface", "Me...
# 32  ["Testing Framework", "Browser Automation", "U...
# 33  ["Initialization Constraints", "Method Impleme...
# 34  ["Functionality", "Input Handling", "Output Ha...
# 35  ["Documentation", "Modularity", "Type Safety",...
# 36  ["Data Visualization", "Function Parameters", ...
# 37  ["Database Interaction", "Message Broker Integ...
# 38  ["Class Design", "Method Implementation", "Col...
# 39  ["Email Sending", "Error Handling", "File Atta...
# 40  ["Cross-Version Compatibility", "Function Defi...
# 41  ["Configuration Management", "Code Clarity and...
# 42  ["File Management", "Error Handling", "Subproc...
# 43  ["Unit Testing", "Assertions", "Code Structure...
# 44  ["Method Addition", "Naming Conventions", "Doc...
# 45  ["Type Flexibility", "Type Safety", "Code Comp...
# 46  ["Error Handling", "Input Validation", "Code S...
# 47  ["Functionality", "User Interaction", "Code Co...
# 48  ["Database Connection", "Code Structure", "Dat...
# 49  ["File Handling", "Data Processing", "Output F...
# 50  ["Performance Optimization", "Code Efficiency"...
# 51  ["Boundary Conditions", "Logical Flow", "Code ...
# 52  ["Iteration Constraints", "Error Handling Cons...
# 53  ["Algorithm Implementation", "Data Structure U...
# 54  ["Function Definition", "Code Clarity", "Data ...
# 55  ["Method Implementation", "Data Structure Inte...
# 56  ["Bug Fixing", "Code Correction", "Technical A...
# 57  ["Function Implementation", "Mathematical Inte...
# 58  ["Functionality", "Modularity", "Input Handlin...
# 59  ["FUNCTIONALITY", "CODE STRUCTURE", "STRING MA...
#
#                                         categories_v2  \
# 0   ["function", "output", "mathematical", "modula...
# 1   ["string manipulation", "HTML embedding", "var...
# 2   ["function", "error handling", "recursion", "i...
# 3   ["class", "method", "attribute", "error handli...
# 4   ["function", "control", "variable", "loop", "s...
# 5   ["function", "error handling", "example", "out...
# 6   ["testing", "mutation", "coverage", "installat...
# 7   ["function", "control", "variable", "structura...
# 8   ["function", "control", "variable", "algorithm...
# 9   ["function", "variable", "control", "error han...
# 10  ["global", "structural", "function", "interfac...
# 11  ["function", "variable", "structural control",...
# 12  ["global", "structural", "variable", "function...
# 13  ["function", "library", "data", "visualization...
# 14  ["array", "indexing", "slicing", "vectorizatio...
# 15  ["global", "structural control", "function", "...
# 16  ["control", "loop", "function", "variable", "i...
# 17  ["global", "structural", "function", "interfac...
# 18  ["global", "structural", "variable", "function...
# 19  ["structural", "function", "variable", "interf...
# 20  ["file", "error handling", "directory", "funct...
# 21  ["data generation", "data structure", "functio...
# 22  ["regex", "email", "smtp", "string manipulatio...
# 23  ["function", "data structure", "string manipul...
# 24  ["data handling", "data manipulation", "numeri...
# 25  ["global", "structural control", "function", "...
# 26  ["input validation", "statistical testing", "e...
# 27  ["global", "structural", "security", "file", "...
# 28  ["error handling", "random number generation",...
# 29  ["error handling", "file I/O", "directory mana...
# 30  ["function", "variable", "documentation", "err...
# 31  ["class", "function", "interface", "variable",...
# 32  ["global", "structural", "function", "variable...
# 33  ["class", "method", "variable", "interface", "...
# 34  ["function", "variable", "control", "interface...
# 35  ["function", "variable", "module", "interface"...
# 36  ["function", "variable", "interface", "structu...
# 37  ["global", "structural", "database", "message_...
# 38  ["class", "function", "module", "control", "in...
# 39  ["function", "error handling", "email", "file"...
# 40  ["compatibility", "function", "control", "name...
# 41  ["global", "structural", "variable", "function...
# 42  ["file", "execution", "error handling", "outpu...
# 43  ["testing", "function", "assertion", "data_str...
# 44  ["function", "interface", "documentation", "st...
# 45    ["type", "variable", "structural", "interface"]
# 46  ["control", "error handling", "function", "str...
# 47  ["function", "control", "security", "interface...
# 48  ["connection", "security", "database", "file",...
# 49  ["global", "structural", "function", "variable...
# 50  ["global", "structural", "function", "optimiza...
# 51  ["structural", "function", "variable", "contro...
# 52  ["structural", "functional", "error handling",...
# 53  ["algorithm", "data structure", "error handlin...
# 54  ["function", "structural", "variable", "algori...
# 55  ["structural", "functional", "interface", "err...
# 56  ["structural", "function", "variable", "interf...
# 57  ["function", "mathematical", "control", "struc...
# 58  ["function", "control", "variable", "string", ...
# 59     ["FUNCTION", "VARIABLE", "STRUCTURAL CONTROL"]
#
#                                     Manual_categories  \
# 0   ['Modularization', 'Rounding', 'Vector Calcula...
# 1   ['HTML Tagging Methodology', 'String Manipulat...
# 2   ['Functionality', 'Input Validation', 'Error H...
# 3   ['Attributes', 'Constructor', 'Getter Methods'...
# 4   ['Function Definition', 'Random Selection', 'D...
# 5   ['Functionality Description', 'Correct Usage E...
# 6   ['Test Module Creation', 'Test Suite Robustnes...
# 7   ['Tax Calculation', 'Total Adjustments', 'Calc...
# 8   ['User Input Requirements', 'Character Set Def...
# 9   ['Function Definition', 'Input Handling', 'Lis...
# 10  ['Library Imports', 'Data Structure Definition...
# 11  ['Tensor Operations', 'Differentiability', 'Ef...
# 12  ['DataFrame Initialization', 'Function Definit...
# 13  ['Library Imports', 'Dataset Loading', 'Plotti...
# 14  ['Numpy Usage', 'Index Definition', 'Advanced ...
# 15  ['Library Usage', 'Data Generation', 'Data Vis...
# 16  ['Import Statements', 'Data Initialization', '...
# 17  ['Library Usage', 'Plotting Functionality', 'G...
# 18  ['Library Usage', 'Data Structure', 'Parameter...
# 19  ['Matrix Operations', 'Performance Considerati...
# 20  ['Backup Directory Checks', 'Backup Retrieval'...
# 21             ['Data Generation', 'CDF Calculation']
# 22  ['Regex Operations', 'Data Processing', 'Email...
# 23  ['Reproducibility', 'Input Handling', 'String ...
# 24  ['Data Handling', 'Data Structure', 'Calculati...
# 25  ['Data Generation', 'Figure Initialization', '...
# 26  ['Input Requirements', 'Processing Steps', 'Ou...
# 27  ['Key Generation', 'Password Generation', 'Enc...
# 28  ['Input Validation', 'Randomness Control', 'Ra...
# 29  ['Input Validation', 'File Handling', 'Search ...
# 30  ['Return Behavior', 'Data Handling', 'Function...
# 31  ['Command-Line Interface', 'Core Functionality...
# 32  ['Testing Framework', 'Browser Automation', 'F...
# 33  ['Class Design', 'Method Functionality', 'Opti...
# 34  ['Rotation Logic', 'Case Handling', 'Non-Alpha...
# 35  ['Conversion Functions', 'Utility Functions', ...
# 36  ['Conversion Operations', 'Data Chunking', 'Mo...
# 37  ['Flask Application Characteristics', 'RabbitM...
# 38  ['Web Framework Initialization', 'Database Tab...
# 39  ['Function Characteristics', 'Key Modules Used...
# 40  ['Cross-Version Compatibility', 'Functionality...
# 41  ['Configuration Enhancement', 'Backward Compat...
# 42  ['Output Management', 'Error Handling', 'Execu...
# 43  ['Unit Test Characteristics', 'Test Structure ...
# 44  ['Method Addition', 'Consistency in Naming', '...
# 45  ['Node Type Modification', 'Compatibility Pres...
# 46  ['Initialization Checks', 'Communication Valid...
# 47  ['Database Configuration', 'Data Processing', ...
# 48  ['Database Connection Configuration', 'Functio...
# 49  ['Directory Management', 'Energy Evaluation', ...
# 50  ['Optimization Techniques', 'Functionality and...
# 51  ['Performance Optimization', 'Caching Mechanis...
# 52  ['Code Structure Constraints', 'Error Handling...
# 53  ['Algorithm Change', 'Data Structure', 'Initia...
# 54  ['Sorting Mechanism', 'Grouping Logic', 'Sorti...
# 55  ['Method Implementation', 'Behavioral Characte...
# 56  ['Bug Fixes', 'Encapsulation', 'Code Consisten...
# 57  ['Functionality Enhancement', 'Performance Imp...
# 58  ['Functionality Enhancement', 'Input Handling'...
# 59      ['TRANSFORMATION', 'FORMAT', 'COMPATIBILITY']
#
#                                        LLM_categories  \
# 0   ['Function Implementation', 'Output Formatting...
# 1   ['Solution Requirements', 'Code Explanation', ...
# 2   ['Functionality Requirements', 'Complexity Req...
# 3   ['Docstring Requirements', 'String Formatting'...
# 4   ['Function Implementation', 'Decryption Logic'...
# 5   ['Purpose Explanation', 'Correct Usage Example...
# 6   ['Mutation Testing Tools', 'Step-by-Step Guide...
# 7   ['Complexity Enhancement', 'Logic Maintenance'...
# 8   ['Functionality Requirements', 'Output Specifi...
# 9   ['Function Definition', 'List Operations', 'So...
# 10     ['Code Minimalism', 'Plotting Specifications']
# 11  ['Code Requirements', 'Method Constraints', 'F...
# 12  ['Iterative Approach', 'Avoid Vectorization', ...
# 13  ['Function Usage', 'Plot Type', 'Plot Customiz...
# 14  ['Indexing Method', 'Array Reshaping', 'Perfor...
# 15  ['Plot Customization Restrictions', 'Output Re...
# 16  ['Looping and Iteration', 'NaN Checking', 'Res...
# 17     ['Plotting Constraints', 'Grid Customization']
# 18  ['Efficiency', 'Array Manipulation', 'Reshapin...
# 19  ['Function Usage', 'Output Format', 'Response ...
# 20  ['Backup Existence Checks', 'Backup Handling',...
# 21  ['Data Generation Constraints', 'CDF Calculati...
# 22  ['Regex Pattern Usage', 'Email Formatting', 'S...
# 23  ['Reproducibility', 'DataFrame Structure', 'St...
# 24  ['DataFrame Structure', 'Calculations', 'Plott...
# 25  ['Data Generation', 'Subplot Creation', 'Funct...
# 26  ['Data Validation', 'Chi-Square Test Execution...
# 27  ['RSA Key Generation', 'AES Encryption', 'File...
# 28  ['Error Handling', 'Reproducibility', 'Random ...
# 29  ['Directory and File Handling', 'Variable Nami...
# 30  ['Function Documentation', 'Input Handling', '...
# 31  ['Class Design', 'Command-Line Interface', 'Me...
# 32  ['Test Class Structure', 'Test Method Requirem...
# 33  ['Initialization Requirements', 'Method Requir...
# 34  ['Documentation', 'Case Handling', 'Non-Alphab...
# 35  ['Documentation', 'Modularity', 'Rounding', 'G...
# 36  ['Visualization Library', 'Function Parameters...
# 37  ['Database Interaction', 'Message Broker Inter...
# 38  ['Class Implementation', 'Rendering and Event ...
# 39  ['Library Usage', 'Function Documentation', 'M...
# 40  ['Compatibility', 'Function Definition', 'Buil...
# 41  ['Configuration Directives', 'Structure and Cl...
# 42  ['Output File Specification', 'Execution Path'...
# 43  ['Assertions', 'Data Structures', 'Test Clarit...
# 44   ['Method Addition', 'Documentation Consistency']
# 45                              ['Type Modification']
# 46               ['Error Handling', 'Code Structure']
# 47  ['Functionality Constraints', 'Error Handling ...
# 48  ['Connection String Modification', 'Code Struc...
# 49  ['Import Statements', 'Method Parameters', 'Da...
# 50  ['Initialization Optimization', 'Scoring Effic...
# 51  ['Boundary Checks', 'Logical Flow', 'Code Qual...
# 52  ['Iteration Method', 'GPA Calculation', 'Metho...
# 53  ['Algorithm Implementation', 'Error Handling',...
# 54  ['Function Clarity', 'Commenting and Documenta...
# 55  ['Method Implementation', 'Structural Integrit...
# 56  ['Response Clarity', 'Focus on Bug Fix', 'Tech...
# 57  ['Function Implementation', 'Arithmetic Integr...
# 58   ['Functionality Requirements', 'Code Structure']
# 59  ['INLINE TRANSFORMATION', 'FUNCTION DESIGN MAI...
#
#                                      Final_categories
# 0   ['Modularization', 'Rounding', 'Vector Calcula...
# 1   ['HTML Tagging Methodology', 'String Manipulat...
# 2   ['Functionality', 'Input Validation', 'Error H...
# 3   ['Attributes', 'Constructor', 'Getter Methods'...
# 4   ['Function Definition', 'Random Selection', 'D...
# 5   ['Functionality Description', 'Correct Usage E...
# 6   ['Test Module Creation', 'Test Suite Robustnes...
# 7   ['Tax Calculation', 'Total Adjustments', 'Calc...
# 8   ['User Input Requirements', 'Character Set Def...
# 9   ['Function Definition', 'Input Handling', 'Lis...
# 10  ['Library Imports', 'Data Structure Definition...
# 11  ['Tensor Operations', 'Differentiability', 'Ef...
# 12  ['DataFrame Initialization', 'Function Definit...
# 13  ['Library Imports', 'Dataset Loading', 'Plotti...
# 14  ['Numpy Usage', 'Index Definition', 'Advanced ...
# 15  ['Library Usage', 'Data Generation', 'Data Vis...
# 16  ['Import Statements', 'Data Initialization', '...
# 17  ['Library Usage', 'Plotting Functionality', 'G...
# 18  ['Library Usage', 'Data Structure', 'Parameter...
# 19  ['Matrix Operations', 'Performance Considerati...
# 20  ['Backup Directory Checks', 'Backup Retrieval'...
# 21  ['Data Generation', 'CDF Calculation', 'Data G...
# 22  ['Regex Operations', 'Data Processing', 'Email...
# 23  ['Reproducibility', 'Input Handling', 'String ...
# 24  ['Data Handling', 'Data Structure', 'Calculati...
# 25  ['Data Generation', 'Figure Initialization', '...
# 26  ['Input Requirements', 'Processing Steps', 'Ou...
# 27  ['Key Generation', 'Password Generation', 'Enc...
# 28  ['Input Validation', 'Randomness Control', 'Ra...
# 29  ['Input Validation', 'File Handling', 'Search ...
# 30  ['Return Behavior', 'Data Handling', 'Function...
# 31  ['Command-Line Interface', 'Core Functionality...
# 32  ['Testing Framework', 'Browser Automation', 'F...
# 33  ['Class Design', 'Method Functionality', 'Opti...
# 34  ['Rotation Logic', 'Case Handling', 'Non-Alpha...
# 35  ['Conversion Functions', 'Utility Functions', ...
# 36  ['Conversion Operations', 'Data Chunking', 'Mo...
# 37  ['Flask Application Characteristics', 'RabbitM...
# 38  ['Web Framework Initialization', 'Database Tab...
# 39  ['Function Characteristics', 'Key Modules Used...
# 40  ['Cross-Version Compatibility', 'Functionality...
# 41  ['Configuration Enhancement', 'Backward Compat...
# 42  ['Output Management', 'Error Handling', 'Execu...
# 43  ['Unit Test Characteristics', 'Test Structure ...
# 44  ['Method Addition', 'Consistency in Naming', '...
# 45  ['Node Type Modification', 'Compatibility Pres...
# 46  ['Initialization Checks', 'Communication Valid...
# 47  ['Database Configuration', 'Data Processing', ...
# 48  ['Database Connection Configuration', 'Functio...
# 49  ['Directory Management', 'Energy Evaluation', ...
# 50  ['Optimization Techniques', 'Functionality and...
# 51  ['Performance Optimization', 'Caching Mechanis...
# 52  ['Code Structure Constraints', 'Error Handling...
# 53  ['Algorithm Change', 'Data Structure', 'Initia...
# 54  ['Sorting Mechanism', 'Grouping Logic', 'Sorti...
# 55  ['Method Implementation', 'Behavioral Characte...
# 56  ['Bug Fixes', 'Encapsulation', 'Code Consisten...
# 57  ['Functionality Enhancement', 'Performance Imp...
# 58  ['Functionality Enhancement', 'Input Handling'...
# 59  ['TRANSFORMATION', 'FORMAT', 'COMPATIBILITY', ...

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   dataset                    60 non-null     object
#  1   instruction                60 non-null     object
#  2   code                       60 non-null     object
#  3   test                       20 non-null     object
#  4   Characteristics            60 non-null     object
#  5   constraints                60 non-null     object
#  6   Characteristics_List       60 non-null     object
#  7   Mapped_Characteristics     60 non-null     object
#  8   Mapped_Constraints         60 non-null     object
#  9   Mapped_Characteristics_v2  60 non-null     object
#  10  Mapped_Constraints_v2      60 non-null     object
#  11  categories_v1              60 non-null     object
#  12  categories_v2              60 non-null     object
#  13  Manual_categories          60 non-null     object
#  14  LLM_categories             60 non-null     object
#  15  Final_categories           60 non-null     object
# dtypes: object(16)
# memory usage: 7.6+ KB

# %%
full_df = full_df[["dataset","instruction","code"]]
full_df.head(60)
# Out:
#                                         dataset  \
# 0         ajibawa-2023/Python-Code-23k-ShareGPT
# 1         ajibawa-2023/Python-Code-23k-ShareGPT
# 2         ajibawa-2023/Python-Code-23k-ShareGPT
# 3         ajibawa-2023/Python-Code-23k-ShareGPT
# 4         ajibawa-2023/Python-Code-23k-ShareGPT
# 5         ajibawa-2023/Python-Code-23k-ShareGPT
# 6         ajibawa-2023/Python-Code-23k-ShareGPT
# 7         ajibawa-2023/Python-Code-23k-ShareGPT
# 8         ajibawa-2023/Python-Code-23k-ShareGPT
# 9         ajibawa-2023/Python-Code-23k-ShareGPT
# 10                              xlangai/DS-1000
# 11                              xlangai/DS-1000
# 12                              xlangai/DS-1000
# 13                              xlangai/DS-1000
# 14                              xlangai/DS-1000
# 15                              xlangai/DS-1000
# 16                              xlangai/DS-1000
# 17                              xlangai/DS-1000
# 18                              xlangai/DS-1000
# 19                              xlangai/DS-1000
# 20                         bigcode/bigcodebench
# 21                         bigcode/bigcodebench
# 22                         bigcode/bigcodebench
# 23                         bigcode/bigcodebench
# 24                         bigcode/bigcodebench
# 25                         bigcode/bigcodebench
# 26                         bigcode/bigcodebench
# 27                         bigcode/bigcodebench
# 28                         bigcode/bigcodebench
# 29                         bigcode/bigcodebench
# 30  Multilingual-Multimodal-NLP/McEval-Instruct
# 31  Multilingual-Multimodal-NLP/McEval-Instruct
# 32  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
# 34  Multilingual-Multimodal-NLP/McEval-Instruct
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 36  Multilingual-Multimodal-NLP/McEval-Instruct
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 38  Multilingual-Multimodal-NLP/McEval-Instruct
# 39  Multilingual-Multimodal-NLP/McEval-Instruct
# 40                             nuprl/EditPackFT
# 41                             nuprl/EditPackFT
# 42                             nuprl/EditPackFT
# 43                             nuprl/EditPackFT
# 44                             nuprl/EditPackFT
# 45                             nuprl/EditPackFT
# 46                             nuprl/EditPackFT
# 47                             nuprl/EditPackFT
# 48                             nuprl/EditPackFT
# 49                             nuprl/EditPackFT
# 50                              nuprl/CanItEdit
# 51                              nuprl/CanItEdit
# 52                              nuprl/CanItEdit
# 53                              nuprl/CanItEdit
# 54                              nuprl/CanItEdit
# 55                              nuprl/CanItEdit
# 56                              nuprl/CanItEdit
# 57                              nuprl/CanItEdit
# 58                              nuprl/CanItEdit
# 59                              nuprl/CanItEdit
#
#                                           instruction  \
# 0   Calculate the distance between two points loca...
# 1   Assuming that the given sentence is stored in ...
# 2   Write a program in Python to find the factoria...
# 3   Create a Python class for Animal with the foll...
# 4   How can I decrypt a set of jokes that are encr...
# 5   What is the purpose of the 'enumerate' keyword...
# 6   Can you provide an example of mutation testing...
# 7   Edit the given code to fix the bug and increas...
# 8   Generate a random password that meets the foll...
# 9   Create a program to combine the elements of tw...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 11  Problem:\n\nI have a logistic regression model...
# 12  Problem:\nHaving a pandas data frame as follow...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 14  Problem:\nSay I have a 3 dimensional numpy arr...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 18  Problem:\nI have a 2-dimensional numpy array w...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 20  Rollback the update of a directory by restorin...
# 21  Randomly generate a pandas DataFrame with spec...
# 22  Extract all names from a string that is not en...
# 23  Replace a random substring (a sequence of char...
# 24  Load e-mail data from a JSON file, convert it ...
# 25  Generate diagrams for the sine and cosine func...
# 26  Perform a chi-square test of independence of v...
# 27  Generates an RSA public and private key pair a...
# 28  Create a list of random numbers, sort them and...
# 29  Search for occurrences of the word "error" in ...
# 30  Write a Python function `calculate_distinct_av...
# 31  Design a Python class `GroupDialogManager` tha...
# 32  You are tasked with creating an automated test...
# 33  In a fictional universe, there are multiple sp...
# 34  Write a Python function `rotate_text` that tak...
# 35  Write a Python module named `motion_control` t...
# 36  Create a Python function named `generate_mobil...
# 37  Design a Python Flask application that acts as...
# 38  Design a self-driving car simulation where the...
# 39  Write a Python function `send_email_with_attac...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 41  Add auth protocol for keystone connection in v...
# 42  Fix up import optional test to use temporary c...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 44  Update manager API for update.\n"""Valve Manag...
# 45  Change Node type a bit\n\nfrom typing import M...
# 46  Make use of the return value of begin() and me...
# 47  Send a message back to client\nimport webapp2\...
# 48  Use Tracking DB Service URL rather than localh...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 51  Fix how the alive neighbor count is calculated...
# 52  Fix the methods in `Course` so that all of the...
# 53  Make the `distances_to` function support negat...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 55  Change the code so that it supports a remove e...
# 56  The distance is not updated correctly, fix the...
# 57  Edit the code to include a method `powermod` t...
# 58  Modify the function syllable_count so each 'co...
# 59  Make the name fully uppercase.\ndef hello_worl...
#
#                                                  code
# 0   To calculate the distance between two points i...
# 1   To achieve this, you can use Python's string m...
# 2   Here is a program in Python that finds the fac...
# 3   ```python\nclass Animal:\n    def __init__(sel...
# 4   Sure, here's a Python function that decrypts t...
# 5   The purpose of the 'enumerate' keyword in Pyth...
# 6   Sure, here's an example of mutation testing in...
# 7   ```python\ndef calculate_tax(price):\n    tax_...
# 8   Here is a Python function that generates a ran...
# 9   Here's a Python program that combines the elem...
# 10         plt.plot(*zip(*points))\nplt.yscale("log")
# 11  y = torch.argmax(softmax_output, dim=1).view(-...
# 12  import numpy as np\ndef g(df):\n    softmax = ...
# 13  sns.jointplot(\n    x="total_bill", y="tip", d...
# 14  result = a[:, np.array(second).reshape(-1,1), ...
# 15                   plt.imshow(data)\nplt.colorbar()
# 16  result = True\nfor arr in a:\n    if any(np.is...
# 17  plt.plot(y, x)\nplt.grid(color="blue", linesty...
# 18  bin_data_mean = data[:,:(data.shape[1] // bin_...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 20  # Check if the backup directory exists\n    if...
# 21  # Generate random data and create a DataFrame\...
# 22  names = re.findall('(.*?)(?:\\[.*?\\]|$)', tex...
# 23  random.seed(seed)\n\n    df = pd.DataFrame(dat...
# 24  with open(json_file, 'r') as file:\n        em...
# 25  x_values = np.linspace(0, 2 * np.pi, 400)\n   ...
# 26  # Check if DataFrame is empty\n    if data.emp...
# 27  (pub_key, priv_key) = rsa.newkeys(512)\n    pa...
# 28  if range_limit <= 1:\n        raise ValueError...
# 29  if not os.path.isdir(dir_path):\n        raise...
# 30  ```python\nfrom __future__ import division\n\n...
# 31  ```python\nimport argparse\nfrom termcolor imp...
# 32  ```python\nimport unittest\nfrom selenium impo...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
# 34  ```python\ndef rotate_text(text, rotation):\n ...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 36  ```python\nimport pandas as pd\nimport plotly....
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 38  ```python\nimport pygame as pg\nimport math\nf...
# 39  ```python\nimport smtplib\nfrom email.mime.mul...
# 40  import sys # Used to get rid of py2/3 differen...
# 41  import string\n\ntemplate = string.Template(""...
# 42  import os\nimport subprocess\nimport sys\n\nne...
# 43  import os\n\nfrom unittest import TestCase\nfr...
# 44  """Valve Manager base class"""\n\n# pylint: di...
# 45  from typing import Mapping, Set, Callable, Uni...
# 46  import NDIR\nimport time\n\nsensor = NDIR.Sens...
# 47  import webapp2\n\nfrom google.appengine.api im...
# 48  import pandas as pd\nimport sys\n\n\ndf = pd.r...
# 49  import os\nimport numpy as np\nfrom whaler.dat...
# 50  import math\nfrom typing import List, Dict\n\n...
# 51  from typing import List\n\n\nclass ConwaysGame...
# 52  import functools\nimport numpy as np\nclass St...
# 53  class Graph:\n    def __init__(self):\n       ...
# 54  class Comparators:\n    """\n    A class for t...
# 55  from abc import ABC, abstractmethod\n\nclass L...
# 56  class StepCounter:\n    def __init__(self):\n ...
# 57  import math\n\ndef gcd(a : int, b : int) -> in...
# 58  import string\n\ndef prepare_string(line):\n  ...
# 59  def hello_world(name):\n    return f'{name.upp...

# %%
df = full_df.sample(n=N)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 37 to 30
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dataset      60 non-null     object
#  1   instruction  60 non-null     object
#  2   code         60 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %% [markdown]
# ## Decide Dataset Sampling Ratios Based on Real-World Complexity
# - ShareGPT - 25%
# - DS-1000 - 15%
# - Bigcodebench -25%
# - MCeval - 35%

# %% [markdown]
# ## Write transformation scripts for each dataset format

# %% [markdown]
# ## Create a benchmark dataset of 1000–1200 examples

# %% [markdown]
# # Step 2 - Define Constraint Categories

# %%
categories = [
    "Code Structure and Modularity",
    "Input and Output Handling",
    "Error Handling and Robustness",
    "Data Processing and Transformation",
    "Performance and Optimization",
    "Library and API Usage",
    "Testing and Debugging",
    "Documentation and Readability",
    "Security and Privacy",
    "Reproducibility and Consistency",
    "Mathematical Computation",
    "File and Data Management",
    "UI and Interaction",
]
categories_str = "\n".join(categories)

# %% [markdown]
# # Utility Functions

# %%
import json

def extract_json(string,col_name="Constraints"):
    try:
        json_string = string.strip().replace('```json\n', '', 1).replace('\n```', '', 1)
        constraint_json = json.loads(json_string)
        return constraint_json.get(col_name, [])
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e} in string: {string}")
        return []
    except AttributeError as e:
        print(f"Attribute error: {e} in string: {string}")
        return []

# %% [markdown]
# # Step 3 Generating Constraints

# %%
# !pwd
# Out:
# /dccstor/shanmukh/sravani_internship/CIF_Benchmark

# %%
import pandas as pd
import time
from openai import OpenAI
import os

if os.path.exists("/content"):
    from google.colab import userdata
    openai_api_key = userdata.get('OPENAPI_KEY')
else:
    from dotenv import load_dotenv
    load_dotenv()
    openai_api_key = os.getenv("OPENAI_API_KEY")
    print("Running in local environment, loaded key from .env")

# Check if key was actually found
if not openai_api_key:
    raise ValueError("OPENAI_API_KEY is not set. Please check your environment or .env file.")

# Initialize OpenAI client
client = OpenAI(api_key=openai_api_key)
# Out:
# Running in local environment, loaded key from .env

# %%
SYSTEM_PROMPT = f"""
You are a helpful assistant. You will be given a programming instruction and the corresponding code.
"""

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

def get_model_response_batch(user_prompts=None, system_prompt=SYSTEM_PROMPT):
    messages_list = [[{
                "role": "system",
                "content": system_prompt
            }, {
                "role": "user",
                "content": user_prompt
            }] for user_prompt in user_prompts]
    with ThreadPoolExecutor(max_workers=60) as executor:
            response_texts = list(tqdm(
                executor.map(lambda messages: get_response_v2(messages), messages_list),
                total=len(messages_list),
                desc="Processing"
            ))
    return response_texts

def get_response_v2(messages, max_retries=1):
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            temperature=0
            )
            # print(response)
            return response.choices[0].message.content
        except Exception as e:
            print(f"Error on attempt {attempt+1}: {e}")
            time.sleep(2)
    return "[]"

def get_response(user_prompt,system_prompt=SYSTEM_PROMPT, max_retries=1):
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0
            )
            # print(response)
            return response.choices[0].message.content
        except Exception as e:
            print(f"Error on attempt {attempt+1}: {e}")
            time.sleep(2)
    return "[]"

# %% [markdown]
# ## Stage 1: Relevant Category Selection

# %%
SYSTEM_PROMPT_STAGE1 = """
You are a categorization expert for programming tasks. Your goal is to accurately map a programming instruction and its associated code to all applicable high-level constraint categories from a predefined list.
"""

def get_prompt_stage1_select_categories(instruction: str, code: str, all_constraint_categories: list[str]) -> str:
    categories_str = "\n".join(all_constraint_categories)
    prompt = f"""
    "task": "Classify the natural language `instruction` and its corresponding `code` into all relevant high-level constraint categories from the provided comprehensive list.",

    "context": "You are given an `instruction` that describes a coding task, `code` for context, and a list of `all_constraint_categories`.",

    "goal": "Select **all** relevant categories from the `all_constraint_categories` list that apply directly, indirectly, or even potentially to the given `instruction` and `code`.
    For each category, think carefully about both explicit requirements and implicit expectations that might arise in real-world programming tasks.
    If there is **any plausible reason**—whether due to the instruction's wording, the code's structure, edge cases, potential extensions, or real-world usage scenarios—that the category might impose constraints, then **include it**.

    Be exhaustive on the side of inclusion. The goal is to **maximize coverage** of all semantically or practically relevant constraint categories, not to limit selection to a minimal subset.

    Your output must be a JSON object containing a single field: 'relevant_categories'.
    ",

    "JSON Response Format": {{
        "relevant_categories": [
            "List of selected relevant categories from 'all_constraint_categories'. Each string should be the exact name of the matching supercategory."
        ]
    }},

    "Inputs Required": {{
        "instruction": {instruction}
        "code": {code}
        "all_constraint_categories": {categories_str}
    }}
    """
    return prompt
prompt = get_prompt_stage1_select_categories(full_df.iloc[26]["instruction"],full_df.iloc[26]["code"],categories)
print(prompt)
# Out:
#     "task": "Classify the natural language `instruction` and its corresponding `code` into all relevant high-level constraint categories from the provided comprehensive list.",
#
#     "context": "You are given an `instruction` that describes a coding task, `code` for context, and a list of `all_constraint_categories`.",
#
#     "goal": "Select **all** relevant categories from the `all_constraint_categories` list that apply directly, indirectly, or even potentially to the given `instruction` and `code`.
#     For each category, think carefully about both explicit requirements and implicit expectations that might arise in real-world programming tasks.
#     If there is **any plausible reason**—whether due to the instruction's wording, the code's structure, edge cases, potential extensions, or real-world usage scenarios—that the category might impose constraints, then **include it**.
#
#     Be exhaustive on the side of inclusion. The goal is to **maximize coverage** of all semantically or practically relevant constraint categories, not to limit selection to a minimal subset.
#
#     Your output must be a JSON object containing a single field: 'relevant_categories'.
#     ",
#
#     "JSON Response Format": {
#         "relevant_categories": [
#             "List of selected relevant categories from 'all_constraint_categories'. Each string should be the exact name of the matching supercategory."
#         ]
#     },
#
#     "Inputs Required": {
#         "instruction": Perform a chi-square test of independence of variables in a contingency table. This function takes a DataFrame containing categorical data and two column names, then constructs a contingency table from the two categorical columns and performs a chi-square test of independence. It returns the p-value of the test, which indicates the probability of observing the data if the null hypothesis (independence of the variables) is true. >>> np.random.seed(42) >>> data = pd.DataFrame({ ...     'a': np.random.choice(['A', 'B'], size=100), ...     'b': np.random.choice(['X', 'Y'], size=100) ... }) >>> task_func(data, 'a', 'b') 1.0
# The function should raise the exception for: ValueError: If 'data' is empty, if 'col1' or 'col2' are not in 'data', if one or both of the columns do not have multiple categories, or if some categories have less than 5 observations (violating the chi-square test assumptions). TypeError: If one or both of the columns contain non-categorical data.
# The function should output with:
#     float: The p-value of the chi-square test of independence.
# You should write self-contained code starting with:
# ```
# import pandas as pd
# import numpy as np
# from scipy.stats import chi2_contingency
# def task_func(data, col1, col2):
# ```
#         "code": # Check if DataFrame is empty
#     if data.empty:
#         raise ValueError("The input DataFrame is empty.")
#
#     # Check if specified columns exist
#     if col1 not in data or col2 not in data:
#         raise ValueError(f"One or both of the columns '{col1}' and '{col2}' do not exist in the DataFrame.")
#
#     # Check for non-categorical data (numerical values)
#     if np.issubdtype(data[col1].dtype, np.number) or np.issubdtype(data[col2].dtype, np.number):
#         raise TypeError("One or both of the columns contain non-categorical data. The chi-square test requires categorical data.")
#
#     # Check for single category (no variability)
#     if len(data[col1].unique()) < 2 or len(data[col2].unique()) < 2:
#         raise ValueError("One or both of the columns do not have multiple categories. The chi-square test requires variability in data.")
#
#     # Check for small counts in numerous categories
#     contingency_table = pd.crosstab(data[col1], data[col2])
#     if (contingency_table < 5).any().any():
#         raise ValueError("Some categories have less than 5 observations. This violates the assumptions of the chi-square test.")
#
#     # Perform the chi-square test
#     chi2, p, dof, expected = chi2_contingency(contingency_table)
#     return p
#         "all_constraint_categories": Code Structure and Modularity
# Input and Output Handling
# Error Handling and Robustness
# Data Processing and Transformation
# Performance and Optimization
# Library and API Usage
# Testing and Debugging
# Documentation and Readability
# Security and Privacy
# Reproducibility and Consistency
# Mathematical Computation
# File and Data Management
# UI and Interaction
#     }

# %%
print(full_df.iloc[26]["instruction"])
# Out:
# Perform a chi-square test of independence of variables in a contingency table. This function takes a DataFrame containing categorical data and two column names, then constructs a contingency table from the two categorical columns and performs a chi-square test of independence. It returns the p-value of the test, which indicates the probability of observing the data if the null hypothesis (independence of the variables) is true. >>> np.random.seed(42) >>> data = pd.DataFrame({ ...     'a': np.random.choice(['A', 'B'], size=100), ...     'b': np.random.choice(['X', 'Y'], size=100) ... }) >>> task_func(data, 'a', 'b') 1.0
# The function should raise the exception for: ValueError: If 'data' is empty, if 'col1' or 'col2' are not in 'data', if one or both of the columns do not have multiple categories, or if some categories have less than 5 observations (violating the chi-square test assumptions). TypeError: If one or both of the columns contain non-categorical data.
# The function should output with:
#     float: The p-value of the chi-square test of independence.
# You should write self-contained code starting with:
# ```
# import pandas as pd
# import numpy as np
# from scipy.stats import chi2_contingency
# def task_func(data, col1, col2):
# ```

# %%
relevant_categories = get_response(prompt,SYSTEM_PROMPT_STAGE1)
print(relevant_categories)
relevant_categories = extract_json(relevant_categories,"relevant_categories")
print(relevant_categories)
# Out:
# ```json
# {
#     "relevant_categories": [
#         "Code Structure and Modularity",
#         "Input and Output Handling",
#         "Error Handling and Robustness",
#         "Data Processing and Transformation",
#         "Library and API Usage",
#         "Mathematical Computation"
#     ]
# }
# ```
# ['Code Structure and Modularity', 'Input and Output Handling', 'Error Handling and Robustness', 'Data Processing and Transformation', 'Library and API Usage', 'Mathematical Computation']

# %% [markdown]
# ## Stage 2: Instruction Simplification & Implicit Constraint Extraction

# %%
SYSTEM_PROMPT_STAGE2 = """
You are an expert natural language processor and code instruction analyst. Your task is to meticulously read a programming instruction, identify and extract any embedded constraints, separate them from the core problem description, and map them to provided high-level categories. You must preserve any provided starter code or solution snippets.
"""

def get_prompt_stage2_extract_and_simplify(instruction: str, relevant_categories: list[str]) -> str:
    relevant_categories_str = ", ".join(relevant_categories)

    prompt = f"""
    "task": "Carefully analyze the provided programming `instruction`. Your main goal is to separate the core problem description from any explicit constraints or directives embedded within the instruction's text. You must return the core problem description as 'simplified_instruction' and all identified explicit constraints as 'extracted_constraints'.",

    "context": "You are provided with an `instruction` that describes a coding task and a list of `relevant_categories` that apply to this instruction. The `instruction` might contain specific rules, formatting requirements, or implementation details interwoven into its narrative. You need to pull these out.",

    "goal": "Perform the following steps:
    1. **Identify and Extract Explicit Constraints:** Read the `instruction` and pinpoint all **explicit** constraints, directives, or specific requirements (e.g., about function names, return types, error handling, algorithms to use, variable naming, documentation, etc.).
    2. **Split Compound Constraints into Atomic Ones:** If any sentence or clause contains multiple distinct requirements, split it into **multiple entries**, ensuring **each extracted constraint refers to exactly one requirement or condition**.
       Do not combine multiple checks (e.g., multiple `if` conditions or causes for `ValueError`) into one constraint.
    3. **Simplify Instruction:** Create a 'simplified_instruction' by removing only these identified explicit constraints, leaving behind the core problem explanation.
        **CRITICAL:** If the original `instruction` contains any starter code (e.g., code in ```python blocks) or any solution snippets demarcated by 'BEGIN SOLUTION', you **MUST NOT** modify or remove these from the 'simplified_instruction'.
        **Important:** If the original instruction contains any explanation or examples that are not constraints, you should keep them in the 'simplified_instruction' as they are part of the core problem description.
    4. **Format Extracted Constraints with Categories:** For each extracted constraint:
        - Include a separate item in the 'extracted_constraints' list.
        - Set its 'type' to one of the categories from `relevant_categories`.
        - Set 'instruction_part' to 'Extracted from instruction'.

    Example:
    - Original compound constraint: "Raise ValueError if input is None or if it's an empty list."
    - Extracted as:
        {{
            "type": "Error Handling and Robustness",
            "constraint": "Raise ValueError if input is None.",
            "instruction_part": "Extracted from instruction"
        }},
        {{
            "type": "Error Handling and Robustness",
            "constraint": "Raise ValueError if input is an empty list.",
            "instruction_part": "Extracted from instruction"
        }}

    Your output must be a JSON object with two fields: 'simplified_instruction' and 'extracted_constraints'.
    ",

    "JSON Response Format": {{
        "simplified_instruction": "The core problem description from the original instruction, with explicit constraints/directives removed. Starter code (e.g., ```python blocks) and solution snippets (e.g., marked by 'BEGIN SOLUTION') must be preserved.",
        "extracted_constraints": [
            {{
                "type": "Constraint_Category_Name",  // MUST be one of the provided relevant_categories
                "constraint": "A single, atomic extracted constraint.",
                "instruction_part": "Extracted from instruction"
            }}
        ]
    }},

    "Inputs Required": {{
        "instruction": {instruction}
        "relevant_categories": {relevant_categories_str}
    }}
    """
    return prompt


prompt_stage2 = get_prompt_stage2_extract_and_simplify(full_df.iloc[26]["instruction"],relevant_categories)
print(prompt_stage2)
# Out:
#     "task": "Carefully analyze the provided programming `instruction`. Your main goal is to separate the core problem description from any explicit constraints or directives embedded within the instruction's text. You must return the core problem description as 'simplified_instruction' and all identified explicit constraints as 'extracted_constraints'.",
#
#     "context": "You are provided with an `instruction` that describes a coding task and a list of `relevant_categories` that apply to this instruction. The `instruction` might contain specific rules, formatting requirements, or implementation details interwoven into its narrative. You need to pull these out.",
#
#     "goal": "Perform the following steps:
#     1. **Identify and Extract Explicit Constraints:** Read the `instruction` and pinpoint all **explicit** constraints, directives, or specific requirements (e.g., about function names, return types, error handling, algorithms to use, variable naming, documentation, etc.).
#     2. **Split Compound Constraints into Atomic Ones:** If any sentence or clause contains multiple distinct requirements, split it into **multiple entries**, ensuring **each extracted constraint refers to exactly one requirement or condition**.
#        Do not combine multiple checks (e.g., multiple `if` conditions or causes for `ValueError`) into one constraint.
#     3. **Simplify Instruction:** Create a 'simplified_instruction' by removing only these identified explicit constraints, leaving behind the core problem explanation.
#         **CRITICAL:** If the original `instruction` contains any starter code (e.g., code in ```python blocks) or any solution snippets demarcated by 'BEGIN SOLUTION', you **MUST NOT** modify or remove these from the 'simplified_instruction'.
#         **Important:** If the original instruction contains any explanation or examples that are not constraints, you should keep them in the 'simplified_instruction' as they are part of the core problem description.
#     4. **Format Extracted Constraints with Categories:** For each extracted constraint:
#         - Include a separate item in the 'extracted_constraints' list.
#         - Set its 'type' to one of the categories from `relevant_categories`.
#         - Set 'instruction_part' to 'Extracted from instruction'.
#
#     Example:
#     - Original compound constraint: "Raise ValueError if input is None or if it's an empty list."
#     - Extracted as:
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if input is None.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if input is an empty list.",
#             "instruction_part": "Extracted from instruction"
#         }
#
#     Your output must be a JSON object with two fields: 'simplified_instruction' and 'extracted_constraints'.
#     ",
#
#     "JSON Response Format": {
#         "simplified_instruction": "The core problem description from the original instruction, with explicit constraints/directives removed. Starter code (e.g., ```python blocks) and solution snippets (e.g., marked by 'BEGIN SOLUTION') must be preserved.",
#         "extracted_constraints": [
#             {
#                 "type": "Constraint_Category_Name",  // MUST be one of the provided relevant_categories
#                 "constraint": "A single, atomic extracted constraint.",
#                 "instruction_part": "Extracted from instruction"
#             }
#         ]
#     },
#
#     "Inputs Required": {
#         "instruction": Perform a chi-square test of independence of variables in a contingency table. This function takes a DataFrame containing categorical data and two column names, then constructs a contingency table from the two categorical columns and performs a chi-square test of independence. It returns the p-value of the test, which indicates the probability of observing the data if the null hypothesis (independence of the variables) is true. >>> np.random.seed(42) >>> data = pd.DataFrame({ ...     'a': np.random.choice(['A', 'B'], size=100), ...     'b': np.random.choice(['X', 'Y'], size=100) ... }) >>> task_func(data, 'a', 'b') 1.0
# The function should raise the exception for: ValueError: If 'data' is empty, if 'col1' or 'col2' are not in 'data', if one or both of the columns do not have multiple categories, or if some categories have less than 5 observations (violating the chi-square test assumptions). TypeError: If one or both of the columns contain non-categorical data.
# The function should output with:
#     float: The p-value of the chi-square test of independence.
# You should write self-contained code starting with:
# ```
# import pandas as pd
# import numpy as np
# from scipy.stats import chi2_contingency
# def task_func(data, col1, col2):
# ```
#         "relevant_categories": Code Structure and Modularity, Input and Output Handling, Error Handling and Robustness, Data Processing and Transformation, Library and API Usage, Testing and Debugging, Documentation and Readability, Reproducibility and Consistency, Mathematical Computation
#     }

# %%
instruction2 = "Write a function that sorts a list of numbers using merge sort with time complexity O(n log n)."
code2 = "def merge_sort(arr):\n    if len(arr) > 1:\n        mid = len(arr) // 2\n        left_half = arr[:mid]\n        right_half = arr[mid:]\n\n        merge_sort(left_half)\n        merge_sort(right_half)\n\n        i = j = k = 0\n\n        while i < len(left_half) and j < len(right_half):\n            if left_half[i] < right_half[j]:\n                arr[k] = left_half[i]\  i += 1\n            else:\n                arr[k] = right_half[j]\  j += 1\n            k += 1\n\n        while i < len(left_half):\n            arr[k] = left_half[i]\  i += 1\  k += 1\n\n        while j < len(right_half):\n            arr[k] = right_half[j]\  j += 1\  k += 1\n\n    return arr"
example_prompt2 = get_prompt_stage2_extract_and_simplify(instruction2,relevant_categories)
print(example_prompt2)
# Out:
#     "task": "Carefully analyze the provided programming `instruction`. Your main goal is to separate the core problem description from any explicit constraints or directives embedded within the instruction's text. You must return the core problem description as 'simplified_instruction' and all identified explicit constraints as 'extracted_constraints'.",
#
#     "context": "You are provided with an `instruction` that describes a coding task and a list of `relevant_categories` that apply to this instruction. The `instruction` might contain specific rules, formatting requirements, or implementation details interwoven into its narrative. You need to pull these out.",
#
#     "goal": "Perform the following steps:
#     1. **Identify and Extract Explicit Constraints:** Read the `instruction` and pinpoint all **explicit** constraints, directives, or specific requirements (e.g., about function names, return types, error handling, algorithms to use, variable naming, documentation, etc.).
#     2. **Split Compound Constraints into Atomic Ones:** If any sentence or clause contains multiple distinct requirements, split it into **multiple entries**, ensuring **each extracted constraint refers to exactly one requirement or condition**.
#        Do not combine multiple checks (e.g., multiple `if` conditions or causes for `ValueError`) into one constraint.
#     3. **Simplify Instruction:** Create a 'simplified_instruction' by removing only these identified explicit constraints, leaving behind the core problem explanation.
#         **CRITICAL:** If the original `instruction` contains any starter code (e.g., code in ```python blocks) or any solution snippets demarcated by 'BEGIN SOLUTION', you **MUST NOT** modify or remove these from the 'simplified_instruction'.
#         **Important:** If the original instruction contains any explanation or examples that are not constraints, you should keep them in the 'simplified_instruction' as they are part of the core problem description.
#     4. **Format Extracted Constraints with Categories:** For each extracted constraint:
#         - Include a separate item in the 'extracted_constraints' list.
#         - Set its 'type' to one of the categories from `relevant_categories`.
#         - Set 'instruction_part' to 'Extracted from instruction'.
#
#     Example:
#     - Original compound constraint: "Raise ValueError if input is None or if it's an empty list."
#     - Extracted as:
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if input is None.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if input is an empty list.",
#             "instruction_part": "Extracted from instruction"
#         }
#
#     Your output must be a JSON object with two fields: 'simplified_instruction' and 'extracted_constraints'.
#     ",
#
#     "JSON Response Format": {
#         "simplified_instruction": "The core problem description from the original instruction, with explicit constraints/directives removed. Starter code (e.g., ```python blocks) and solution snippets (e.g., marked by 'BEGIN SOLUTION') must be preserved.",
#         "extracted_constraints": [
#             {
#                 "type": "Constraint_Category_Name",  // MUST be one of the provided relevant_categories
#                 "constraint": "A single, atomic extracted constraint.",
#                 "instruction_part": "Extracted from instruction"
#             }
#         ]
#     },
#
#     "Inputs Required": {
#         "instruction": Write a function that sorts a list of numbers using merge sort with time complexity O(n log n).
#         "relevant_categories": Code Structure and Modularity, Input and Output Handling, Error Handling and Robustness, Data Processing and Transformation, Library and API Usage, Testing and Debugging, Documentation and Readability, Reproducibility and Consistency, Mathematical Computation
#     }

# %%
response = get_response(example_prompt2,SYSTEM_PROMPT_STAGE2)
print(response)
# Out:
# {
#     "simplified_instruction": "Write a function that sorts a list of numbers using merge sort.",
#     "extracted_constraints": [
#         {
#             "type": "Mathematical Computation",
#             "constraint": "The function must have a time complexity of O(n log n).",
#             "instruction_part": "Extracted from instruction"
#         }
#     ]
# }

# %%
instruction = """Write a Python function `rotate_text` that takes a string `text` and an integer `rotation` as its parameters and returns a new string where each letter in the original string is rotated by the given rotation amount through the alphabet. The rotation should maintain the case of the original letters (i.e., uppercase letters remain uppercase, and lowercase letters remain lowercase) and should leave non-alphabetic characters unchanged.

For example, with a rotation of 1, 'a' becomes 'b', 'z' becomes 'a', 'A' becomes 'B', and 'Z' becomes 'A'. The function should handle negative rotation values as well, which rotate the letters in the opposite direction.
"""
relevant_categories = ['Input and Output Handling', 'Code Structure and Modularity', 'Scalability and Maintainability']
example_prompt = get_prompt_stage2_extract_and_simplify(instruction,relevant_categories)
response = get_response(example_prompt,SYSTEM_PROMPT_STAGE2)
print(response)
# Out:
# ```json
# {
#     "simplified_instruction": "Write a Python function `rotate_text` that takes a string `text` and an integer `rotation` as its parameters and returns a new string where each letter in the original string is rotated by the given rotation amount through the alphabet. For example, with a rotation of 1, 'a' becomes 'b', 'z' becomes 'a', 'A' becomes 'B', and 'Z' becomes 'A'.",
#     "extracted_constraints": [
#         {
#             "type": "Input and Output Handling",
#             "constraint": "The function should maintain the case of the original letters.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Input and Output Handling",
#             "constraint": "The function should leave non-alphabetic characters unchanged.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Input and Output Handling",
#             "constraint": "The function should handle negative rotation values.",
#             "instruction_part": "Extracted from instruction"
#         }
#     ]
# }
# ```

# %%
instruction = """Edit the given code to fix the bug and increase the difficulty:

```python
def calculate_tax(price):
    tax_rate = 0.20
    total = price + (price * tax_rate)
    
    # Apply a discount of 10% if the price is greater than $1000
    if price > 1000:
        discount = price * 0.10
        total -= discount
    
    # Round the total to the nearest cent
    total = round(total, 2)
    
    # Add a surcharge of 5% if the total is greater than $500 and less than $1000
    if total > 500 and total < 1000:
        surcharge = total * 0.05
        total += surcharge
    
    # Add a service fee of $50 if the total is less than $100
    if total < 100:
        total += 50
    
    return total
```

Explanation of changes:

1. Added an additional condition to check if the total is greater than $500 and less than $1000. If it is, a surcharge of 5% is added to the total.
2. This additional condition adds complexity to the function, requiring the programmer to consider multiple scenarios and perform additional calculations."""
relevant_categories = ['Code Structure and Modularity', 'Input and Output Handling', 'Documentation and Readability']
example_prompt = get_prompt_stage2_extract_and_simplify(instruction,relevant_categories)
response = get_response(example_prompt,SYSTEM_PROMPT_STAGE2)
print(response)
# Out:
# ```json
# {
#     "simplified_instruction": "Edit the given code to fix the bug and increase the difficulty:\n\n```python\ndef calculate_tax(price):\n    tax_rate = 0.20\n    total = price + (price * tax_rate)\n    \n    # Apply a discount of 10% if the price is greater than $1000\n    if price > 1000:\n        discount = price * 0.10\n        total -= discount\n    \n    # Round the total to the nearest cent\n    total = round(total, 2)\n    \n    # Add a surcharge of 5% if the total is greater than $500 and less than $1000\n    if total > 500 and total < 1000:\n        surcharge = total * 0.05\n        total += surcharge\n    \n    # Add a service fee of $50 if the total is less than $100\n    if total < 100:\n        total += 50\n    \n    return total\n```\n\nExplanation of changes:\n\n1. Added an additional condition to check if the total is greater than $500 and less than $1000. If it is, a surcharge of 5% is added to the total.\n2. This additional condition adds complexity to the function, requiring the programmer to consider multiple scenarios and perform additional calculations.",
#     "extracted_constraints": []
# }
# ```

# %%
instruction = """Problem:
I have two csr_matrix, c1, c2.

I want a new matrix Feature = [c1, c2]. But if I directly concatenate them horizontally this way, there's an error that says the matrix Feature is a list. How can I achieve the matrix concatenation and still get the same type of matrix, i.e. a csr_matrix?

And it doesn't work if I do this after the concatenation: Feature = csr_matrix(Feature) It gives the error:

Traceback (most recent call last):
  File "yelpfilter.py", line 91, in <module>
    Feature = csr_matrix(Feature)
  File "c:\python27\lib\site-packages\scipy\sparse\compressed.py", line 66, in __init__
    self._set_self( self.__class__(coo_matrix(arg1, dtype=dtype)) )
  File "c:\python27\lib\site-packages\scipy\sparse\coo.py", line 185, in __init__
    self.row, self.col = M.nonzero()
TypeError: __nonzero__ should return bool or int, returned numpy.bool_

A:
<code>
from scipy import sparse
c1 = sparse.csr_matrix([[0, 0, 1, 0], [2, 0, 0, 0], [0, 0, 0, 0]])
c2 = sparse.csr_matrix([[0, 3, 4, 0], [0, 0, 0, 5], [6, 7, 0, 8]])
</code>
Feature = ... # put solution in this variable
BEGIN SOLUTION
<code>"""
relevant_categories = ['Code Structure and Modularity', 'Input and Output Handling', 'Error Handling and Robustness', 'Data Processing and Transformation', 'Library and API Usage', 'Testing and Debugging', 'Documentation and Readability', 'Reproducibility and Consistency', 'Mathematical Computation']
example_prompt = get_prompt_stage2_extract_and_simplify(instruction,relevant_categories)
response = get_response(example_prompt,SYSTEM_PROMPT_STAGE2)
print(response)
# Out:
# ```json
# {
#     "simplified_instruction": "Problem:\nI have two csr_matrix, c1, c2.\n\nI want a new matrix Feature = [c1, c2]. But if I directly concatenate them horizontally this way, there's an error that says the matrix Feature is a list. How can I achieve the matrix concatenation and still get the same type of matrix, i.e. a csr_matrix?\n\nAnd it doesn't work if I do this after the concatenation: Feature = csr_matrix(Feature) It gives the error:\n\nTraceback (most recent call last):\n  File \"yelpfilter.py\", line 91, in <module>\n    Feature = csr_matrix(Feature)\n  File \"c:\\python27\\lib\\site-packages\\scipy\\sparse\\compressed.py\", line 66, in __init__\n    self._set_self( self.__class__(coo_matrix(arg1, dtype=dtype)) )\n  File \"c:\\python27\\lib\\site-packages\\scipy\\sparse\\coo.py\", line 185, in __init__\n    self.row, self.col = M.nonzero();\nTypeError: __nonzero__ should return bool or int, returned numpy.bool_\n\nA:\n<code>\nfrom scipy import sparse\nc1 = sparse.csr_matrix([[0, 0, 1, 0], [2, 0, 0, 0], [0, 0, 0, 0]])\nc2 = sparse.csr_matrix([[0, 3, 4, 0], [0, 0, 0, 5], [6, 7, 0, 8]])\n</code>\nFeature = ... # put solution in this variable\nBEGIN SOLUTION\n<code>",
#     "extracted_constraints": [
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "The matrix Feature must not be a list after concatenation.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Feature must be of type csr_matrix after concatenation.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Library and API Usage",
#             "constraint": "Do not use csr_matrix(Feature) after concatenation as it raises a TypeError.",
#             "instruction_part": "Extracted from instruction"
#         }
#     ]
# }
# ```

# %%
response_stage2 = get_response(prompt_stage2,SYSTEM_PROMPT_STAGE2)
print(response_stage2)
simplified_instruction = extract_json(response_stage2,"simplified_instruction")
extracted_constraints = extract_json(response_stage2,"extracted_constraints")
print(simplified_instruction)
print(extracted_constraints)
# Out:
# ```json
# {
#     "simplified_instruction": "Perform a chi-square test of independence of variables in a contingency table. This function takes a DataFrame containing categorical data and two column names, then constructs a contingency table from the two categorical columns and performs a chi-square test of independence. It returns the p-value of the test, which indicates the probability of observing the data if the null hypothesis (independence of the variables) is true. >>> np.random.seed(42) >>> data = pd.DataFrame({ ...     'a': np.random.choice(['A', 'B'], size=100), ...     'b': np.random.choice(['X', 'Y'], size=100) ... }) >>> task_func(data, 'a', 'b') 1.0\nThe function should output with:\n    float: The p-value of the chi-square test of independence.\nYou should write self-contained code starting with:\n```\nimport pandas as pd\nimport numpy as np\nfrom scipy.stats import chi2_contingency\ndef task_func(data, col1, col2):\n```",
#     "extracted_constraints": [
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if 'data' is empty.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if 'col1' or 'col2' are not in 'data'.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if one or both of the columns do not have multiple categories.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if some categories have less than 5 observations.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise TypeError if one or both of the columns contain non-categorical data.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Input and Output Handling",
#             "constraint": "The function should output a float representing the p-value of the chi-square test of independence.",
#             "instruction_part": "Extracted from instruction"
#         }
#     ]
# }
# ```
# Perform a chi-square test of independence of variables in a contingency table. This function takes a DataFrame containing categorical data and two column names, then constructs a contingency table from the two categorical columns and performs a chi-square test of independence. It returns the p-value of the test, which indicates the probability of observing the data if the null hypothesis (independence of the variables) is true. >>> np.random.seed(42) >>> data = pd.DataFrame({ ...     'a': np.random.choice(['A', 'B'], size=100), ...     'b': np.random.choice(['X', 'Y'], size=100) ... }) >>> task_func(data, 'a', 'b') 1.0
# The function should output with:
#     float: The p-value of the chi-square test of independence.
# You should write self-contained code starting with:
# ```
# import pandas as pd
# import numpy as np
# from scipy.stats import chi2_contingency
# def task_func(data, col1, col2):
# ```
# [{'type': 'Error Handling and Robustness', 'constraint': "Raise ValueError if 'data' is empty.", 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': "Raise ValueError if 'col1' or 'col2' are not in 'data'.", 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise ValueError if one or both of the columns do not have multiple categories.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise ValueError if some categories have less than 5 observations.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise TypeError if one or both of the columns contain non-categorical data.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Input and Output Handling', 'constraint': 'The function should output a float representing the p-value of the chi-square test of independence.', 'instruction_part': 'Extracted from instruction'}]

# %% [markdown]
# ##   Stage 3: New Constraint Generation & Merging

# %%
SYSTEM_PROMPT_STAGE3_NEW = """
You are a highly skilled constraint curator and generator for code development tasks. Your job is to combine existing constraints with newly generated ones, ensuring the final list is comprehensive, free of conflicts and duplicates, and adheres to strict quality and relevance standards.
"""

def get_prompt_stage3_generate_and_merge_constraints(
    instruction: str,
    code: str,
    relevant_categories: list[str],
    extracted_constraints: list # These are from Stage 2 output
) -> str:
    relevant_categories_str = ", ".join(relevant_categories)
    extracted_constraints_str = json.dumps(extracted_constraints, indent=2)

    prompt = f"""
    "task": "Generate additional high-quality constraints, combine them with provided `extracted_constraints`, and refine the final comprehensive list based on quality principles and category alignment.",

    "context": "You are provided with a `instruction` (core problem), `code` for context, a list of `relevant_categories` for this task, and `extracted_constraints` that were found directly in the original instruction. Your job is to build the definitive, final set of constraints for this benchmark entry.",

    "goal": "Perform the following steps:
    1.  **Generate New Constraints:** Based on the `instruction`, `code`, and `relevant_categories`, generate 5 to 10 **new** natural language constraints. These new constraints must be specific, objective, and leave little room for subjective interpretation. Each should pose a tangible challenge and be clearly verifiable. For each newly generated constraint, set its `instruction_part` to 'Newly Generated'.
        **Note:** If the combined total with extracted constraints exceeds 15, generate fewer new ones; if it falls short of 5, generate more to meet the minimum.
    2.  **Combine and Curate:** Create a single preliminary list of all constraints by merging the `extracted_constraints` with your newly generated constraints.
    3.  **Refine and Resolve Conflicts/Duplicates:**
        * Review the combined list for any duplicate constraints (exact text or very similar meaning) or any subtle contradictions between extracted and newly generated constraints.
        * **Crucially, if a newly generated constraint is a duplicate of, or is semantically covered by, an 'Extracted from instruction' constraint, you MUST discard the newly generated constraint in favor of the extracted one. Do NOT change or tweak the 'Extracted from instruction' constraints.**
        * Resolve other conflicts by refining or merging existing constraints, prioritizing clarity and adhering to the 'Prioritize Modification over Deletion' principle.
    4.  **Finalize Count (5-15 Constraints):** Ensure the final list contains between **5 and 15** unique, valid constraints.
        * If the curated list has less than 5, identify which of the `relevant_categories` are underrepresented and create *additional* high-quality constraints for those categories to reach the minimum.
        * If the curated list has more than 15, select the most critical and impactful constraints that best cover the `relevant_categories` to reduce the list to 15, without losing essential information.
    5.  **Validate Category Alignment:** For every constraint in the final list, ensure its 'type' field is one of the categories explicitly listed in the `relevant_categories` list. If a type does not perfectly match, correct it to the most appropriate category from `relevant_categories`. There should be a perfect overlap.

    **Principles for All Constraints (Extracted & Newly Generated):**
        * **Actionable, Precise, Objective:** Ensure all constraints are specific, measurable, and unambiguous.
        * **Accept Requirements for Additional Code:** If meeting a constraint primarily requires generating *additional* code or functionality (rather than fundamentally altering the core solution), ensure the constraint is phrased to encourage this.
        * **No Unresolved Directives:** Ensure the final generated constraints do not contain any unreplaced directive keywords (e.g., `{{keyword}}`).

    Your output should be a JSON object containing a single field: 'final_comprehensive_constraints'.
    ",

    "JSON Response Format": {{
        "final_comprehensive_constraints": [
            {{
                "type": "Constraint_Category_Name", // MUST be from the 'relevant_categories' list
                "constraint": "Final, specific, objective, and atomic constraint statement.",
                "instruction_part": "Original source: 'Extracted from instruction' or 'Newly Generated' or 'Combined/Refined'"
            }},
            // ... list of 5 to 15 curated constraints
        ]
    }},

    "Inputs Required": {{
        "instruction": {instruction},
        "code": {code},
        "relevant_categories": {relevant_categories_str},
        "extracted_constraints": {extracted_constraints_str}
    }}
    """
    return prompt


prompt_stage3 = get_prompt_stage3_generate_and_merge_constraints(full_df.iloc[26]["instruction"],full_df.iloc[26]["code"],relevant_categories,extracted_constraints)
print(prompt_stage3)
# Out:
#     "task": "Generate additional high-quality constraints, combine them with provided `extracted_constraints`, and refine the final comprehensive list based on quality principles and category alignment.",
#
#     "context": "You are provided with a `instruction` (core problem), `code` for context, a list of `relevant_categories` for this task, and `extracted_constraints` that were found directly in the original instruction. Your job is to build the definitive, final set of constraints for this benchmark entry.",
#
#     "goal": "Perform the following steps:
#     1.  **Generate New Constraints:** Based on the `instruction`, `code`, and `relevant_categories`, generate 5 to 10 **new** natural language constraints. These new constraints must be specific, objective, and leave little room for subjective interpretation. Each should pose a tangible challenge and be clearly verifiable. For each newly generated constraint, set its `instruction_part` to 'Newly Generated'.
#         **Note:** If the combined total with extracted constraints exceeds 15, generate fewer new ones; if it falls short of 5, generate more to meet the minimum.
#     2.  **Combine and Curate:** Create a single preliminary list of all constraints by merging the `extracted_constraints` with your newly generated constraints.
#     3.  **Refine and Resolve Conflicts/Duplicates:**
#         * Review the combined list for any duplicate constraints (exact text or very similar meaning) or any subtle contradictions between extracted and newly generated constraints.
#         * **Crucially, if a newly generated constraint is a duplicate of, or is semantically covered by, an 'Extracted from instruction' constraint, you MUST discard the newly generated constraint in favor of the extracted one. Do NOT change or tweak the 'Extracted from instruction' constraints.**
#         * Resolve other conflicts by refining or merging existing constraints, prioritizing clarity and adhering to the 'Prioritize Modification over Deletion' principle.
#     4.  **Finalize Count (5-15 Constraints):** Ensure the final list contains between **5 and 15** unique, valid constraints.
#         * If the curated list has less than 5, identify which of the `relevant_categories` are underrepresented and create *additional* high-quality constraints for those categories to reach the minimum.
#         * If the curated list has more than 15, select the most critical and impactful constraints that best cover the `relevant_categories` to reduce the list to 15, without losing essential information.
#     5.  **Validate Category Alignment:** For every constraint in the final list, ensure its 'type' field is one of the categories explicitly listed in the `relevant_categories` list. If a type does not perfectly match, correct it to the most appropriate category from `relevant_categories`. There should be a perfect overlap.
#
#     **Principles for All Constraints (Extracted & Newly Generated):**
#         * **Actionable, Precise, Objective:** Ensure all constraints are specific, measurable, and unambiguous.
#         * **Accept Requirements for Additional Code:** If meeting a constraint primarily requires generating *additional* code or functionality (rather than fundamentally altering the core solution), ensure the constraint is phrased to encourage this.
#         * **No Unresolved Directives:** Ensure the final generated constraints do not contain any unreplaced directive keywords (e.g., `{keyword}`).
#
#     Your output should be a JSON object containing a single field: 'final_comprehensive_constraints'.
#     ",
#
#     "JSON Response Format": {
#         "final_comprehensive_constraints": [
#             {
#                 "type": "Constraint_Category_Name", // MUST be from the 'relevant_categories' list
#                 "constraint": "Final, specific, objective, and atomic constraint statement.",
#                 "instruction_part": "Original source: 'Extracted from instruction' or 'Newly Generated' or 'Combined/Refined'"
#             },
#             // ... list of 5 to 15 curated constraints
#         ]
#     },
#
#     "Inputs Required": {
#         "instruction": Perform a chi-square test of independence of variables in a contingency table. This function takes a DataFrame containing categorical data and two column names, then constructs a contingency table from the two categorical columns and performs a chi-square test of independence. It returns the p-value of the test, which indicates the probability of observing the data if the null hypothesis (independence of the variables) is true. >>> np.random.seed(42) >>> data = pd.DataFrame({ ...     'a': np.random.choice(['A', 'B'], size=100), ...     'b': np.random.choice(['X', 'Y'], size=100) ... }) >>> task_func(data, 'a', 'b') 1.0
# The function should raise the exception for: ValueError: If 'data' is empty, if 'col1' or 'col2' are not in 'data', if one or both of the columns do not have multiple categories, or if some categories have less than 5 observations (violating the chi-square test assumptions). TypeError: If one or both of the columns contain non-categorical data.
# The function should output with:
#     float: The p-value of the chi-square test of independence.
# You should write self-contained code starting with:
# ```
# import pandas as pd
# import numpy as np
# from scipy.stats import chi2_contingency
# def task_func(data, col1, col2):
# ```,
#         "code": # Check if DataFrame is empty
#     if data.empty:
#         raise ValueError("The input DataFrame is empty.")
#
#     # Check if specified columns exist
#     if col1 not in data or col2 not in data:
#         raise ValueError(f"One or both of the columns '{col1}' and '{col2}' do not exist in the DataFrame.")
#
#     # Check for non-categorical data (numerical values)
#     if np.issubdtype(data[col1].dtype, np.number) or np.issubdtype(data[col2].dtype, np.number):
#         raise TypeError("One or both of the columns contain non-categorical data. The chi-square test requires categorical data.")
#
#     # Check for single category (no variability)
#     if len(data[col1].unique()) < 2 or len(data[col2].unique()) < 2:
#         raise ValueError("One or both of the columns do not have multiple categories. The chi-square test requires variability in data.")
#
#     # Check for small counts in numerous categories
#     contingency_table = pd.crosstab(data[col1], data[col2])
#     if (contingency_table < 5).any().any():
#         raise ValueError("Some categories have less than 5 observations. This violates the assumptions of the chi-square test.")
#
#     # Perform the chi-square test
#     chi2, p, dof, expected = chi2_contingency(contingency_table)
#     return p,
#         "relevant_categories": Code Structure and Modularity, Input and Output Handling, Error Handling and Robustness, Data Processing and Transformation, Library and API Usage, Testing and Debugging, Documentation and Readability, Reproducibility and Consistency, Mathematical Computation,
#         "extracted_constraints": [
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if 'data' is empty.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if 'col1' or 'col2' are not in 'data'.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if one or both of the columns do not have multiple categories.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if some categories have less than 5 observations.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise TypeError if one or both of the columns contain non-categorical data.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Input and Output Handling",
#     "constraint": "The function should output a float representing the p-value of the chi-square test of independence.",
#     "instruction_part": "Extracted from instruction"
#   }
# ]
#     }

# %%
response_stage3 = get_response(prompt_stage3,SYSTEM_PROMPT_STAGE3_NEW)
print(response_stage3)
final_comprehensive_constraints = extract_json(response_stage3,"final_comprehensive_constraints")
print(final_comprehensive_constraints)
# Out:
# ```json
# {
#     "final_comprehensive_constraints": [
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if 'data' is empty.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if 'col1' or 'col2' are not in 'data'.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if one or both of the columns do not have multiple categories.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise ValueError if some categories have less than 5 observations.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Error Handling and Robustness",
#             "constraint": "Raise TypeError if one or both of the columns contain non-categorical data.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Input and Output Handling",
#             "constraint": "The function should output a float representing the p-value of the chi-square test of independence.",
#             "instruction_part": "Extracted from instruction"
#         },
#         {
#             "type": "Data Processing and Transformation",
#             "constraint": "The function must construct a contingency table from the two specified categorical columns.",
#             "instruction_part": "Newly Generated"
#         },
#         {
#             "type": "Mathematical Computation",
#             "constraint": "The function should perform a chi-square test of independence using the contingency table.",
#             "instruction_part": "Newly Generated"
#         },
#         {
#             "type": "Documentation and Readability",
#             "constraint": "The function should include docstrings explaining the parameters and return value.",
#             "instruction_part": "Newly Generated"
#         },
#         {
#             "type": "Testing and Debugging",
#             "constraint": "The function should be tested with a variety of DataFrames to ensure robustness against edge cases.",
#             "instruction_part": "Newly Generated"
#         }
#     ]
# }
# ```
# [{'type': 'Error Handling and Robustness', 'constraint': "Raise ValueError if 'data' is empty.", 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': "Raise ValueError if 'col1' or 'col2' are not in 'data'.", 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise ValueError if one or both of the columns do not have multiple categories.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise ValueError if some categories have less than 5 observations.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise TypeError if one or both of the columns contain non-categorical data.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Input and Output Handling', 'constraint': 'The function should output a float representing the p-value of the chi-square test of independence.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Data Processing and Transformation', 'constraint': 'The function must construct a contingency table from the two specified categorical columns.', 'instruction_part': 'Newly Generated'}, {'type': 'Mathematical Computation', 'constraint': 'The function should perform a chi-square test of independence using the contingency table.', 'instruction_part': 'Newly Generated'}, {'type': 'Documentation and Readability', 'constraint': 'The function should include docstrings explaining the parameters and return value.', 'instruction_part': 'Newly Generated'}, {'type': 'Testing and Debugging', 'constraint': 'The function should be tested with a variety of DataFrames to ensure robustness against edge cases.', 'instruction_part': 'Newly Generated'}]

# %% [markdown]
# ## Stage 4: Final Relevance Validation

# %%
SYSTEM_PROMPT_STAGE4_FINAL_RELEVANCE_FILTER = """
You are a meticulous validator of programming task specifications. Your role is to critically assess each constraint for relevance to a simplified instruction’s core intent, and then provide a refined list of only the relevant constraints.

You must generate a reasoning statement for each constraint first, and then decide whether the constraint is relevant based on that reasoning. Do not make a binary decision without a clear explanation.
"""


def get_prompt_stage4_final_relevance_and_filter(instruction: str, final_comprehensive_constraints: list) -> str:
    import json
    constraints_str = json.dumps(final_comprehensive_constraints, indent=2)

    prompt = f"""
"task": "Critically evaluate each constraint in the `final_comprehensive_constraints` list against the `instruction` to determine its direct relevance. For each constraint, first write a reasoning statement explaining your judgment. Then, based on the reasoning, assign a boolean `is_relevant` value. Finally, provide a new list containing only the relevant constraints.",

"context": "You are provided with a `instruction` and a list of `final_comprehensive_constraints` that are intended to guide code generation for this task. Your job is to assess each constraint's logical consistency and direct relevance to the simplified core problem.",

"goal": "Perform the following steps:
1. **Understand the Instruction:** Read and understand the core task described in the `instruction`.
2. **Evaluate Constraints with Justification:**
   a. For each constraint:
     - Write a reasoning paragraph explaining whether and how the constraint supports, complements, or conflicts with the `instruction`.
     - Then, based on your reasoning, assign a boolean value `is_relevant`.
     - If the constraint is vague, off-topic, too generic, or in conflict with the instruction, mark it as false.
     - If the constraint is about documentation, include it only if it directly supports the core problem or is necessary for understanding the code's functionality. 
3. **Filter the Relevant Ones:** Build a new list containing only those constraints with `is_relevant: true`.
4. **Explain Exclusions:** At the end, explain which constraints were removed and why (summary).

Output Format:

Return a single JSON object with the following structure:

{{
  "evaluated_constraints": [
    {{
      "constraint": "The original constraint text.",
      "reasoning": "Detailed explanation of why this constraint is or is not relevant.",
      "is_relevant": true // or false, based on the reasoning
    }},
    // one per constraint
  ],
  "filtered_relevant_constraints": [
    {{
      "type": "Constraint_Category_Name",
      "constraint": "Relevant constraint statement.",
      "instruction_part": "Original source: 'Extracted from instruction', 'Newly Generated', or 'Combined/Refined'"
    }}
    // only constraints marked relevant
  ],
  "reasoning_for_removal": "Summary of why certain constraints were removed."
}}

Inputs Required:
- instruction: {instruction}
- final_comprehensive_constraints: {constraints_str}
"""
    return prompt


prompt_stage4 = get_prompt_stage4_final_relevance_and_filter(full_df.iloc[26]["instruction"],final_comprehensive_constraints)
print(prompt_stage4)
# Out:
# "task": "Critically evaluate each constraint in the `final_comprehensive_constraints` list against the `instruction` to determine its direct relevance. For each constraint, first write a reasoning statement explaining your judgment. Then, based on the reasoning, assign a boolean `is_relevant` value. Finally, provide a new list containing only the relevant constraints.",
#
# "context": "You are provided with a `instruction` and a list of `final_comprehensive_constraints` that are intended to guide code generation for this task. Your job is to assess each constraint's logical consistency and direct relevance to the simplified core problem.",
#
# "goal": "Perform the following steps:
# 1. **Understand the Instruction:** Read and understand the core task described in the `instruction`.
# 2. **Evaluate Constraints with Justification:**
#    a. For each constraint:
#      - Write a reasoning paragraph explaining whether and how the constraint supports, complements, or conflicts with the `instruction`.
#      - Then, based on your reasoning, assign a boolean value `is_relevant`.
#      - If the constraint is vague, off-topic, too generic, or in conflict with the instruction, mark it as false.
#      - If the constraint is about documentation, include it only if it directly supports the core problem or is necessary for understanding the code's functionality.
# 3. **Filter the Relevant Ones:** Build a new list containing only those constraints with `is_relevant: true`.
# 4. **Explain Exclusions:** At the end, explain which constraints were removed and why (summary).
#
# Output Format:
#
# Return a single JSON object with the following structure:
#
# {
#   "evaluated_constraints": [
#     {
#       "constraint": "The original constraint text.",
#       "reasoning": "Detailed explanation of why this constraint is or is not relevant.",
#       "is_relevant": true // or false, based on the reasoning
#     },
#     // one per constraint
#   ],
#   "filtered_relevant_constraints": [
#     {
#       "type": "Constraint_Category_Name",
#       "constraint": "Relevant constraint statement.",
#       "instruction_part": "Original source: 'Extracted from instruction', 'Newly Generated', or 'Combined/Refined'"
#     }
#     // only constraints marked relevant
#   ],
#   "reasoning_for_removal": "Summary of why certain constraints were removed."
# }
#
# Inputs Required:
# - instruction: Perform a chi-square test of independence of variables in a contingency table. This function takes a DataFrame containing categorical data and two column names, then constructs a contingency table from the two categorical columns and performs a chi-square test of independence. It returns the p-value of the test, which indicates the probability of observing the data if the null hypothesis (independence of the variables) is true. >>> np.random.seed(42) >>> data = pd.DataFrame({ ...     'a': np.random.choice(['A', 'B'], size=100), ...     'b': np.random.choice(['X', 'Y'], size=100) ... }) >>> task_func(data, 'a', 'b') 1.0
# The function should raise the exception for: ValueError: If 'data' is empty, if 'col1' or 'col2' are not in 'data', if one or both of the columns do not have multiple categories, or if some categories have less than 5 observations (violating the chi-square test assumptions). TypeError: If one or both of the columns contain non-categorical data.
# The function should output with:
#     float: The p-value of the chi-square test of independence.
# You should write self-contained code starting with:
# ```
# import pandas as pd
# import numpy as np
# from scipy.stats import chi2_contingency
# def task_func(data, col1, col2):
# ```
# - final_comprehensive_constraints: [
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if 'data' is empty.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if 'col1' or 'col2' are not in 'data'.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if one or both of the columns do not have multiple categories.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise ValueError if some categories have less than 5 observations.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Error Handling and Robustness",
#     "constraint": "Raise TypeError if one or both of the columns contain non-categorical data.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Input and Output Handling",
#     "constraint": "The function should output a float representing the p-value of the chi-square test of independence.",
#     "instruction_part": "Extracted from instruction"
#   },
#   {
#     "type": "Data Processing and Transformation",
#     "constraint": "The function must construct a contingency table from the two specified categorical columns.",
#     "instruction_part": "Newly Generated"
#   },
#   {
#     "type": "Mathematical Computation",
#     "constraint": "The function should perform a chi-square test of independence using the contingency table.",
#     "instruction_part": "Newly Generated"
#   },
#   {
#     "type": "Documentation and Readability",
#     "constraint": "The function should include docstrings explaining the parameters and return value.",
#     "instruction_part": "Newly Generated"
#   },
#   {
#     "type": "Testing and Debugging",
#     "constraint": "The function should be tested with a variety of DataFrames to ensure robustness against edge cases.",
#     "instruction_part": "Newly Generated"
#   }
# ]

# %%
response_stage4 = get_response(prompt_stage4,SYSTEM_PROMPT_STAGE4_FINAL_RELEVANCE_FILTER)
print(response_stage4)
final_final_constraints = extract_json(response_stage4,"filtered_relevant_constraints")
print(final_final_constraints)
# Out:
# {
#   "evaluated_constraints": [
#     {
#       "constraint": "Raise ValueError if 'data' is empty.",
#       "reasoning": "This constraint directly supports the instruction by ensuring that the function handles the case where the input DataFrame is empty, which is a critical aspect of robust error handling in the context of performing a chi-square test.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "Raise ValueError if 'col1' or 'col2' are not in 'data'.",
#       "reasoning": "This constraint is relevant as it ensures that the specified columns for the chi-square test exist in the DataFrame, which is essential for the function to operate correctly.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "Raise ValueError if one or both of the columns do not have multiple categories.",
#       "reasoning": "This constraint is relevant because the chi-square test requires that the columns have multiple categories to be valid. Thus, this check is necessary for the function's correctness.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "Raise ValueError if some categories have less than 5 observations.",
#       "reasoning": "This constraint is relevant as it addresses a fundamental assumption of the chi-square test, ensuring that the test is valid and the results are interpretable.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "Raise TypeError if one or both of the columns contain non-categorical data.",
#       "reasoning": "This constraint is relevant because the chi-square test is designed for categorical data, and ensuring that the input data types are correct is crucial for the function's proper execution.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "The function should output a float representing the p-value of the chi-square test of independence.",
#       "reasoning": "This constraint is directly relevant as it specifies the expected output of the function, which is a key aspect of the task.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "The function must construct a contingency table from the two specified categorical columns.",
#       "reasoning": "This constraint is relevant because constructing a contingency table is a necessary step in performing the chi-square test, aligning with the core task.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "The function should perform a chi-square test of independence using the contingency table.",
#       "reasoning": "This constraint is relevant as it describes the main computational task that the function must accomplish, which is central to the instruction.",
#       "is_relevant": true
#     },
#     {
#       "constraint": "The function should include docstrings explaining the parameters and return value.",
#       "reasoning": "While documentation is important for code readability, this constraint does not directly support the core functionality of the task itself. It is more about code quality than the execution of the chi-square test.",
#       "is_relevant": false
#     },
#     {
#       "constraint": "The function should be tested with a variety of DataFrames to ensure robustness against edge cases.",
#       "reasoning": "Testing is important for ensuring the function works correctly, but this constraint does not directly affect the implementation of the chi-square test itself. It is more about validation after the function is written.",
#       "is_relevant": false
#     }
#   ],
#   "filtered_relevant_constraints": [
#     {
#       "type": "Error Handling and Robustness",
#       "constraint": "Raise ValueError if 'data' is empty.",
#       "instruction_part": "Extracted from instruction"
#     },
#     {
#       "type": "Error Handling and Robustness",
#       "constraint": "Raise ValueError if 'col1' or 'col2' are not in 'data'.",
#       "instruction_part": "Extracted from instruction"
#     },
#     {
#       "type": "Error Handling and Robustness",
#       "constraint": "Raise ValueError if one or both of the columns do not have multiple categories.",
#       "instruction_part": "Extracted from instruction"
#     },
#     {
#       "type": "Error Handling and Robustness",
#       "constraint": "Raise ValueError if some categories have less than 5 observations.",
#       "instruction_part": "Extracted from instruction"
#     },
#     {
#       "type": "Error Handling and Robustness",
#       "constraint": "Raise TypeError if one or both of the columns contain non-categorical data.",
#       "instruction_part": "Extracted from instruction"
#     },
#     {
#       "type": "Input and Output Handling",
#       "constraint": "The function should output a float representing the p-value of the chi-square test of independence.",
#       "instruction_part": "Extracted from instruction"
#     },
#     {
#       "type": "Data Processing and Transformation",
#       "constraint": "The function must construct a contingency table from the two specified categorical columns.",
#       "instruction_part": "Newly Generated"
#     },
#     {
#       "type": "Mathematical Computation",
#       "constraint": "The function should perform a chi-square test of independence using the contingency table.",
#       "instruction_part": "Newly Generated"
#     }
#   ],
#   "reasoning_for_removal": "The constraints regarding documentation and testing were removed because they do not directly impact the implementation of the chi-square test of independence, which is the core focus of the instruction. They are more about code quality and validation rather than the functionality required to perform the task."
# }
# [{'type': 'Error Handling and Robustness', 'constraint': "Raise ValueError if 'data' is empty.", 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': "Raise ValueError if 'col1' or 'col2' are not in 'data'.", 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise ValueError if one or both of the columns do not have multiple categories.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise ValueError if some categories have less than 5 observations.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Raise TypeError if one or both of the columns contain non-categorical data.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Input and Output Handling', 'constraint': 'The function should output a float representing the p-value of the chi-square test of independence.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Data Processing and Transformation', 'constraint': 'The function must construct a contingency table from the two specified categorical columns.', 'instruction_part': 'Newly Generated'}, {'type': 'Mathematical Computation', 'constraint': 'The function should perform a chi-square test of independence using the contingency table.', 'instruction_part': 'Newly Generated'}]

# %% [markdown]
# ## Testing the 4 step process

# %% [markdown]
# ### dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 37 to 30
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dataset      60 non-null     object
#  1   instruction  60 non-null     object
#  2   code         60 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %% [markdown]
# ### Implementing stage 1

# %%
# Run on first 20 rows (you can change this limit)
def map_categories(df,output_pth,input_col1,input_col2,output_col,categories=categories):
    results = []
    prompts = []
    for i, row in df.iterrows():
        # print(f"Processing row {i}")
        prompt = get_prompt_stage1_select_categories(row[input_col1], row[input_col2], categories)
        prompts.append(prompt)
    categories_list = get_model_response_batch(prompts,SYSTEM_PROMPT_STAGE1)

    
    categories_list = [extract_json(categories,"relevant_categories") for categories in categories_list]
    results = categories_list

    df[output_col] = results
    df.to_csv(output_pth, index=False)
    print("Saved the file successfully")
    return df

# %%
map_categories(df,"step1_with_categories.csv","instruction","code","relevant_categories")
# Out:
# Processing: 100%|██████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:03<00:00, 18.52it/s]
# Saved the file successfully
#                                         dataset  \
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 19                              xlangai/DS-1000
# 26                         bigcode/bigcodebench
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
# 43                             nuprl/EditPackFT
# 31  Multilingual-Multimodal-NLP/McEval-Instruct
# 48                             nuprl/EditPackFT
# 24                         bigcode/bigcodebench
# 22                         bigcode/bigcodebench
# 41                             nuprl/EditPackFT
# 13                              xlangai/DS-1000
# 9         ajibawa-2023/Python-Code-23k-ShareGPT
# 27                         bigcode/bigcodebench
# 21                         bigcode/bigcodebench
# 1         ajibawa-2023/Python-Code-23k-ShareGPT
# 6         ajibawa-2023/Python-Code-23k-ShareGPT
# 52                              nuprl/CanItEdit
# 12                              xlangai/DS-1000
# 49                             nuprl/EditPackFT
# 56                              nuprl/CanItEdit
# 18                              xlangai/DS-1000
# 53                              nuprl/CanItEdit
# 42                             nuprl/EditPackFT
# 44                             nuprl/EditPackFT
# 0         ajibawa-2023/Python-Code-23k-ShareGPT
# 8         ajibawa-2023/Python-Code-23k-ShareGPT
# 40                             nuprl/EditPackFT
# 20                         bigcode/bigcodebench
# 10                              xlangai/DS-1000
# 14                              xlangai/DS-1000
# 45                             nuprl/EditPackFT
# 4         ajibawa-2023/Python-Code-23k-ShareGPT
# 54                              nuprl/CanItEdit
# 3         ajibawa-2023/Python-Code-23k-ShareGPT
# 5         ajibawa-2023/Python-Code-23k-ShareGPT
# 15                              xlangai/DS-1000
# 34  Multilingual-Multimodal-NLP/McEval-Instruct
# 57                              nuprl/CanItEdit
# 28                         bigcode/bigcodebench
# 11                              xlangai/DS-1000
# 29                         bigcode/bigcodebench
# 17                              xlangai/DS-1000
# 16                              xlangai/DS-1000
# 25                         bigcode/bigcodebench
# 55                              nuprl/CanItEdit
# 58                              nuprl/CanItEdit
# 39  Multilingual-Multimodal-NLP/McEval-Instruct
# 38  Multilingual-Multimodal-NLP/McEval-Instruct
# 23                         bigcode/bigcodebench
# 32  Multilingual-Multimodal-NLP/McEval-Instruct
# 46                             nuprl/EditPackFT
# 50                              nuprl/CanItEdit
# 36  Multilingual-Multimodal-NLP/McEval-Instruct
# 7         ajibawa-2023/Python-Code-23k-ShareGPT
# 47                             nuprl/EditPackFT
# 2         ajibawa-2023/Python-Code-23k-ShareGPT
# 51                              nuprl/CanItEdit
# 59                              nuprl/CanItEdit
# 30  Multilingual-Multimodal-NLP/McEval-Instruct
#
#                                           instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 31  Design a Python class `GroupDialogManager` tha...
# 48  Use Tracking DB Service URL rather than localh...
# 24  Load e-mail data from a JSON file, convert it ...
# 22  Extract all names from a string that is not en...
# 41  Add auth protocol for keystone connection in v...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 9   Create a program to combine the elements of tw...
# 27  Generates an RSA public and private key pair a...
# 21  Randomly generate a pandas DataFrame with spec...
# 1   Assuming that the given sentence is stored in ...
# 6   Can you provide an example of mutation testing...
# 52  Fix the methods in `Course` so that all of the...
# 12  Problem:\nHaving a pandas data frame as follow...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 56  The distance is not updated correctly, fix the...
# 18  Problem:\nI have a 2-dimensional numpy array w...
# 53  Make the `distances_to` function support negat...
# 42  Fix up import optional test to use temporary c...
# 44  Update manager API for update.\n"""Valve Manag...
# 0   Calculate the distance between two points loca...
# 8   Generate a random password that meets the foll...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 20  Rollback the update of a directory by restorin...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 14  Problem:\nSay I have a 3 dimensional numpy arr...
# 45  Change Node type a bit\n\nfrom typing import M...
# 4   How can I decrypt a set of jokes that are encr...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 3   Create a Python class for Animal with the foll...
# 5   What is the purpose of the 'enumerate' keyword...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 34  Write a Python function `rotate_text` that tak...
# 57  Edit the code to include a method `powermod` t...
# 28  Create a list of random numbers, sort them and...
# 11  Problem:\n\nI have a logistic regression model...
# 29  Search for occurrences of the word "error" in ...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 25  Generate diagrams for the sine and cosine func...
# 55  Change the code so that it supports a remove e...
# 58  Modify the function syllable_count so each 'co...
# 39  Write a Python function `send_email_with_attac...
# 38  Design a self-driving car simulation where the...
# 23  Replace a random substring (a sequence of char...
# 32  You are tasked with creating an automated test...
# 46  Make use of the return value of begin() and me...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 36  Create a Python function named `generate_mobil...
# 7   Edit the given code to fix the bug and increas...
# 47  Send a message back to client\nimport webapp2\...
# 2   Write a program in Python to find the factoria...
# 51  Fix how the alive neighbor count is calculated...
# 59  Make the name fully uppercase.\ndef hello_worl...
# 30  Write a Python function `calculate_distinct_av...
#
#                                                  code  \
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 26  # Check if DataFrame is empty\n    if data.emp...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
# 43  import os\n\nfrom unittest import TestCase\nfr...
# 31  ```python\nimport argparse\nfrom termcolor imp...
# 48  import pandas as pd\nimport sys\n\n\ndf = pd.r...
# 24  with open(json_file, 'r') as file:\n        em...
# 22  names = re.findall('(.*?)(?:\\[.*?\\]|$)', tex...
# 41  import string\n\ntemplate = string.Template(""...
# 13  sns.jointplot(\n    x="total_bill", y="tip", d...
# 9   Here's a Python program that combines the elem...
# 27  (pub_key, priv_key) = rsa.newkeys(512)\n    pa...
# 21  # Generate random data and create a DataFrame\...
# 1   To achieve this, you can use Python's string m...
# 6   Sure, here's an example of mutation testing in...
# 52  import functools\nimport numpy as np\nclass St...
# 12  import numpy as np\ndef g(df):\n    softmax = ...
# 49  import os\nimport numpy as np\nfrom whaler.dat...
# 56  class StepCounter:\n    def __init__(self):\n ...
# 18  bin_data_mean = data[:,:(data.shape[1] // bin_...
# 53  class Graph:\n    def __init__(self):\n       ...
# 42  import os\nimport subprocess\nimport sys\n\nne...
# 44  """Valve Manager base class"""\n\n# pylint: di...
# 0   To calculate the distance between two points i...
# 8   Here is a Python function that generates a ran...
# 40  import sys # Used to get rid of py2/3 differen...
# 20  # Check if the backup directory exists\n    if...
# 10         plt.plot(*zip(*points))\nplt.yscale("log")
# 14  result = a[:, np.array(second).reshape(-1,1), ...
# 45  from typing import Mapping, Set, Callable, Uni...
# 4   Sure, here's a Python function that decrypts t...
# 54  class Comparators:\n    """\n    A class for t...
# 3   ```python\nclass Animal:\n    def __init__(sel...
# 5   The purpose of the 'enumerate' keyword in Pyth...
# 15                   plt.imshow(data)\nplt.colorbar()
# 34  ```python\ndef rotate_text(text, rotation):\n ...
# 57  import math\n\ndef gcd(a : int, b : int) -> in...
# 28  if range_limit <= 1:\n        raise ValueError...
# 11  y = torch.argmax(softmax_output, dim=1).view(-...
# 29  if not os.path.isdir(dir_path):\n        raise...
# 17  plt.plot(y, x)\nplt.grid(color="blue", linesty...
# 16  result = True\nfor arr in a:\n    if any(np.is...
# 25  x_values = np.linspace(0, 2 * np.pi, 400)\n   ...
# 55  from abc import ABC, abstractmethod\n\nclass L...
# 58  import string\n\ndef prepare_string(line):\n  ...
# 39  ```python\nimport smtplib\nfrom email.mime.mul...
# 38  ```python\nimport pygame as pg\nimport math\nf...
# 23  random.seed(seed)\n\n    df = pd.DataFrame(dat...
# 32  ```python\nimport unittest\nfrom selenium impo...
# 46  import NDIR\nimport time\n\nsensor = NDIR.Sens...
# 50  import math\nfrom typing import List, Dict\n\n...
# 36  ```python\nimport pandas as pd\nimport plotly....
# 7   ```python\ndef calculate_tax(price):\n    tax_...
# 47  import webapp2\n\nfrom google.appengine.api im...
# 2   Here is a program in Python that finds the fac...
# 51  from typing import List\n\n\nclass ConwaysGame...
# 59  def hello_world(name):\n    return f'{name.upp...
# 30  ```python\nfrom __future__ import division\n\n...
#
#                                   relevant_categories
# 37  [Code Structure and Modularity, Input and Outp...
# 19  [Code Structure and Modularity, Input and Outp...
# 26  [Code Structure and Modularity, Input and Outp...
# 35  [Code Structure and Modularity, Input and Outp...
# 33  [Code Structure and Modularity, Input and Outp...
# 43  [Code Structure and Modularity, Testing and De...
# 31  [Code Structure and Modularity, Input and Outp...
# 48  [Code Structure and Modularity, Input and Outp...
# 24  [Code Structure and Modularity, Input and Outp...
# 22  [Code Structure and Modularity, Input and Outp...
# 41  [Code Structure and Modularity, Input and Outp...
# 13  [Library and API Usage, Data Processing and Tr...
# 9   [Code Structure and Modularity, Input and Outp...
# 27  [Code Structure and Modularity, Input and Outp...
# 21  [Code Structure and Modularity, Input and Outp...
# 1   [Code Structure and Modularity, Input and Outp...
# 6   [Code Structure and Modularity, Input and Outp...
# 52  [Error Handling and Robustness, Input and Outp...
# 12  [Code Structure and Modularity, Input and Outp...
# 49  [Code Structure and Modularity, Input and Outp...
# 56  [Code Structure and Modularity, Input and Outp...
# 18  [Code Structure and Modularity, Input and Outp...
# 53  [Code Structure and Modularity, Input and Outp...
# 42  [Code Structure and Modularity, Input and Outp...
# 44  [Code Structure and Modularity, Input and Outp...
# 0   [Code Structure and Modularity, Input and Outp...
# 8   [Code Structure and Modularity, Input and Outp...
# 40  [Code Structure and Modularity, Input and Outp...
# 20  [Code Structure and Modularity, Input and Outp...
# 10  [Code Structure and Modularity, Input and Outp...
# 14  [Code Structure and Modularity, Input and Outp...
# 45  [Code Structure and Modularity, Data Processin...
# 4   [Code Structure and Modularity, Input and Outp...
# 54  [Code Structure and Modularity, Input and Outp...
# 3   [Code Structure and Modularity, Input and Outp...
# 5   [Code Structure and Modularity, Input and Outp...
# 15  [Code Structure and Modularity, Input and Outp...
# 34  [Code Structure and Modularity, Input and Outp...
# 57  [Code Structure and Modularity, Error Handling...
# 28  [Code Structure and Modularity, Input and Outp...
# 11  [Code Structure and Modularity, Input and Outp...
# 29  [Code Structure and Modularity, Input and Outp...
# 17  [Code Structure and Modularity, Input and Outp...
# 16  [Code Structure and Modularity, Input and Outp...
# 25  [Code Structure and Modularity, Input and Outp...
# 55  [Code Structure and Modularity, Error Handling...
# 58  [Code Structure and Modularity, Input and Outp...
# 39  [Code Structure and Modularity, Input and Outp...
# 38  [Code Structure and Modularity, Input and Outp...
# 23  [Code Structure and Modularity, Input and Outp...
# 32  [Code Structure and Modularity, Input and Outp...
# 46  [Code Structure and Modularity, Input and Outp...
# 50  [Code Structure and Modularity, Performance an...
# 36  [Code Structure and Modularity, Input and Outp...
# 7   [Code Structure and Modularity, Input and Outp...
# 47  [Code Structure and Modularity, Input and Outp...
# 2   [Code Structure and Modularity, Input and Outp...
# 51  [Code Structure and Modularity, Error Handling...
# 59  [Code Structure and Modularity, Input and Outp...
# 30  [Code Structure and Modularity, Input and Outp...

# %%
from collections import Counter
import ast

all_categories = [category for sublist in df['relevant_categories'] for category in sublist]
category_counts = Counter(all_categories)
category_df = pd.DataFrame.from_dict(category_counts, orient='index', columns=['Count'])
category_df = category_df.sort_values(by='Count', ascending=False)
display(category_df)
# Out:
#                                     Count
# Code Structure and Modularity          59
# Documentation and Readability          57
# Input and Output Handling              54
# Error Handling and Robustness          50
# Data Processing and Transformation     41
# Library and API Usage                  37
# Testing and Debugging                  34
# Mathematical Computation               24
# Performance and Optimization           23
# Reproducibility and Consistency        17
# Security and Privacy                   10
# File and Data Management               10
# UI and Interaction                      5

# %% [markdown]
# ### Implementing stage 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 37 to 30
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dataset              60 non-null     object
#  1   instruction          60 non-null     object
#  2   code                 60 non-null     object
#  3   relevant_categories  60 non-null     object
# dtypes: object(4)
# memory usage: 2.3+ KB

# %%
def extract_and_simplify(df,output_pth,input_col1,input_col2):
    extracted_constraints = []
    prompts = []
    for _,row in df.iterrows():
        # print(f"Processing row {i}")
        prompt = get_prompt_stage2_extract_and_simplify(row[input_col1], row[input_col2])
        prompts.append(prompt)
    responses = get_model_response_batch(prompts,SYSTEM_PROMPT_STAGE2)
    simplified_instructions = [extract_json(response,"simplified_instruction") for response in responses]
    extracted_constraints = [extract_json(response,"extracted_constraints") for response in responses]
    df["simplified_instruction"] = simplified_instructions
    df["extracted_constraints"] = extracted_constraints

    df.to_csv(output_pth, index=False)
    print("Saved the file successfully")
    return df

# %%
extract_and_simplify(df,"step2_with_simplified_instruction_and_constraints.csv","instruction","relevant_categories")
# Out:
# Processing:   0%|                                                                                               | 0/60 [00:00<?, ?it/s]
# Processing: 100%|██████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:19<00:00,  3.05it/s]
# Saved the file successfully
#                                         dataset  \
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 19                              xlangai/DS-1000
# 26                         bigcode/bigcodebench
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
# 43                             nuprl/EditPackFT
# 31  Multilingual-Multimodal-NLP/McEval-Instruct
# 48                             nuprl/EditPackFT
# 24                         bigcode/bigcodebench
# 22                         bigcode/bigcodebench
# 41                             nuprl/EditPackFT
# 13                              xlangai/DS-1000
# 9         ajibawa-2023/Python-Code-23k-ShareGPT
# 27                         bigcode/bigcodebench
# 21                         bigcode/bigcodebench
# 1         ajibawa-2023/Python-Code-23k-ShareGPT
# 6         ajibawa-2023/Python-Code-23k-ShareGPT
# 52                              nuprl/CanItEdit
# 12                              xlangai/DS-1000
# 49                             nuprl/EditPackFT
# 56                              nuprl/CanItEdit
# 18                              xlangai/DS-1000
# 53                              nuprl/CanItEdit
# 42                             nuprl/EditPackFT
# 44                             nuprl/EditPackFT
# 0         ajibawa-2023/Python-Code-23k-ShareGPT
# 8         ajibawa-2023/Python-Code-23k-ShareGPT
# 40                             nuprl/EditPackFT
# 20                         bigcode/bigcodebench
# 10                              xlangai/DS-1000
# 14                              xlangai/DS-1000
# 45                             nuprl/EditPackFT
# 4         ajibawa-2023/Python-Code-23k-ShareGPT
# 54                              nuprl/CanItEdit
# 3         ajibawa-2023/Python-Code-23k-ShareGPT
# 5         ajibawa-2023/Python-Code-23k-ShareGPT
# 15                              xlangai/DS-1000
# 34  Multilingual-Multimodal-NLP/McEval-Instruct
# 57                              nuprl/CanItEdit
# 28                         bigcode/bigcodebench
# 11                              xlangai/DS-1000
# 29                         bigcode/bigcodebench
# 17                              xlangai/DS-1000
# 16                              xlangai/DS-1000
# 25                         bigcode/bigcodebench
# 55                              nuprl/CanItEdit
# 58                              nuprl/CanItEdit
# 39  Multilingual-Multimodal-NLP/McEval-Instruct
# 38  Multilingual-Multimodal-NLP/McEval-Instruct
# 23                         bigcode/bigcodebench
# 32  Multilingual-Multimodal-NLP/McEval-Instruct
# 46                             nuprl/EditPackFT
# 50                              nuprl/CanItEdit
# 36  Multilingual-Multimodal-NLP/McEval-Instruct
# 7         ajibawa-2023/Python-Code-23k-ShareGPT
# 47                             nuprl/EditPackFT
# 2         ajibawa-2023/Python-Code-23k-ShareGPT
# 51                              nuprl/CanItEdit
# 59                              nuprl/CanItEdit
# 30  Multilingual-Multimodal-NLP/McEval-Instruct
#
#                                           instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 31  Design a Python class `GroupDialogManager` tha...
# 48  Use Tracking DB Service URL rather than localh...
# 24  Load e-mail data from a JSON file, convert it ...
# 22  Extract all names from a string that is not en...
# 41  Add auth protocol for keystone connection in v...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 9   Create a program to combine the elements of tw...
# 27  Generates an RSA public and private key pair a...
# 21  Randomly generate a pandas DataFrame with spec...
# 1   Assuming that the given sentence is stored in ...
# 6   Can you provide an example of mutation testing...
# 52  Fix the methods in `Course` so that all of the...
# 12  Problem:\nHaving a pandas data frame as follow...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 56  The distance is not updated correctly, fix the...
# 18  Problem:\nI have a 2-dimensional numpy array w...
# 53  Make the `distances_to` function support negat...
# 42  Fix up import optional test to use temporary c...
# 44  Update manager API for update.\n"""Valve Manag...
# 0   Calculate the distance between two points loca...
# 8   Generate a random password that meets the foll...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 20  Rollback the update of a directory by restorin...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 14  Problem:\nSay I have a 3 dimensional numpy arr...
# 45  Change Node type a bit\n\nfrom typing import M...
# 4   How can I decrypt a set of jokes that are encr...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 3   Create a Python class for Animal with the foll...
# 5   What is the purpose of the 'enumerate' keyword...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 34  Write a Python function `rotate_text` that tak...
# 57  Edit the code to include a method `powermod` t...
# 28  Create a list of random numbers, sort them and...
# 11  Problem:\n\nI have a logistic regression model...
# 29  Search for occurrences of the word "error" in ...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 25  Generate diagrams for the sine and cosine func...
# 55  Change the code so that it supports a remove e...
# 58  Modify the function syllable_count so each 'co...
# 39  Write a Python function `send_email_with_attac...
# 38  Design a self-driving car simulation where the...
# 23  Replace a random substring (a sequence of char...
# 32  You are tasked with creating an automated test...
# 46  Make use of the return value of begin() and me...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 36  Create a Python function named `generate_mobil...
# 7   Edit the given code to fix the bug and increas...
# 47  Send a message back to client\nimport webapp2\...
# 2   Write a program in Python to find the factoria...
# 51  Fix how the alive neighbor count is calculated...
# 59  Make the name fully uppercase.\ndef hello_worl...
# 30  Write a Python function `calculate_distinct_av...
#
#                                                  code  \
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 26  # Check if DataFrame is empty\n    if data.emp...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
# 43  import os\n\nfrom unittest import TestCase\nfr...
# 31  ```python\nimport argparse\nfrom termcolor imp...
# 48  import pandas as pd\nimport sys\n\n\ndf = pd.r...
# 24  with open(json_file, 'r') as file:\n        em...
# 22  names = re.findall('(.*?)(?:\\[.*?\\]|$)', tex...
# 41  import string\n\ntemplate = string.Template(""...
# 13  sns.jointplot(\n    x="total_bill", y="tip", d...
# 9   Here's a Python program that combines the elem...
# 27  (pub_key, priv_key) = rsa.newkeys(512)\n    pa...
# 21  # Generate random data and create a DataFrame\...
# 1   To achieve this, you can use Python's string m...
# 6   Sure, here's an example of mutation testing in...
# 52  import functools\nimport numpy as np\nclass St...
# 12  import numpy as np\ndef g(df):\n    softmax = ...
# 49  import os\nimport numpy as np\nfrom whaler.dat...
# 56  class StepCounter:\n    def __init__(self):\n ...
# 18  bin_data_mean = data[:,:(data.shape[1] // bin_...
# 53  class Graph:\n    def __init__(self):\n       ...
# 42  import os\nimport subprocess\nimport sys\n\nne...
# 44  """Valve Manager base class"""\n\n# pylint: di...
# 0   To calculate the distance between two points i...
# 8   Here is a Python function that generates a ran...
# 40  import sys # Used to get rid of py2/3 differen...
# 20  # Check if the backup directory exists\n    if...
# 10         plt.plot(*zip(*points))\nplt.yscale("log")
# 14  result = a[:, np.array(second).reshape(-1,1), ...
# 45  from typing import Mapping, Set, Callable, Uni...
# 4   Sure, here's a Python function that decrypts t...
# 54  class Comparators:\n    """\n    A class for t...
# 3   ```python\nclass Animal:\n    def __init__(sel...
# 5   The purpose of the 'enumerate' keyword in Pyth...
# 15                   plt.imshow(data)\nplt.colorbar()
# 34  ```python\ndef rotate_text(text, rotation):\n ...
# 57  import math\n\ndef gcd(a : int, b : int) -> in...
# 28  if range_limit <= 1:\n        raise ValueError...
# 11  y = torch.argmax(softmax_output, dim=1).view(-...
# 29  if not os.path.isdir(dir_path):\n        raise...
# 17  plt.plot(y, x)\nplt.grid(color="blue", linesty...
# 16  result = True\nfor arr in a:\n    if any(np.is...
# 25  x_values = np.linspace(0, 2 * np.pi, 400)\n   ...
# 55  from abc import ABC, abstractmethod\n\nclass L...
# 58  import string\n\ndef prepare_string(line):\n  ...
# 39  ```python\nimport smtplib\nfrom email.mime.mul...
# 38  ```python\nimport pygame as pg\nimport math\nf...
# 23  random.seed(seed)\n\n    df = pd.DataFrame(dat...
# 32  ```python\nimport unittest\nfrom selenium impo...
# 46  import NDIR\nimport time\n\nsensor = NDIR.Sens...
# 50  import math\nfrom typing import List, Dict\n\n...
# 36  ```python\nimport pandas as pd\nimport plotly....
# 7   ```python\ndef calculate_tax(price):\n    tax_...
# 47  import webapp2\n\nfrom google.appengine.api im...
# 2   Here is a program in Python that finds the fac...
# 51  from typing import List\n\n\nclass ConwaysGame...
# 59  def hello_world(name):\n    return f'{name.upp...
# 30  ```python\nfrom __future__ import division\n\n...
#
#                                   relevant_categories  \
# 37  [Code Structure and Modularity, Input and Outp...
# 19  [Code Structure and Modularity, Input and Outp...
# 26  [Code Structure and Modularity, Input and Outp...
# 35  [Code Structure and Modularity, Input and Outp...
# 33  [Code Structure and Modularity, Input and Outp...
# 43  [Code Structure and Modularity, Testing and De...
# 31  [Code Structure and Modularity, Input and Outp...
# 48  [Code Structure and Modularity, Input and Outp...
# 24  [Code Structure and Modularity, Input and Outp...
# 22  [Code Structure and Modularity, Input and Outp...
# 41  [Code Structure and Modularity, Input and Outp...
# 13  [Library and API Usage, Data Processing and Tr...
# 9   [Code Structure and Modularity, Input and Outp...
# 27  [Code Structure and Modularity, Input and Outp...
# 21  [Code Structure and Modularity, Input and Outp...
# 1   [Code Structure and Modularity, Input and Outp...
# 6   [Code Structure and Modularity, Input and Outp...
# 52  [Error Handling and Robustness, Input and Outp...
# 12  [Code Structure and Modularity, Input and Outp...
# 49  [Code Structure and Modularity, Input and Outp...
# 56  [Code Structure and Modularity, Input and Outp...
# 18  [Code Structure and Modularity, Input and Outp...
# 53  [Code Structure and Modularity, Input and Outp...
# 42  [Code Structure and Modularity, Input and Outp...
# 44  [Code Structure and Modularity, Input and Outp...
# 0   [Code Structure and Modularity, Input and Outp...
# 8   [Code Structure and Modularity, Input and Outp...
# 40  [Code Structure and Modularity, Input and Outp...
# 20  [Code Structure and Modularity, Input and Outp...
# 10  [Code Structure and Modularity, Input and Outp...
# 14  [Code Structure and Modularity, Input and Outp...
# 45  [Code Structure and Modularity, Data Processin...
# 4   [Code Structure and Modularity, Input and Outp...
# 54  [Code Structure and Modularity, Input and Outp...
# 3   [Code Structure and Modularity, Input and Outp...
# 5   [Code Structure and Modularity, Input and Outp...
# 15  [Code Structure and Modularity, Input and Outp...
# 34  [Code Structure and Modularity, Input and Outp...
# 57  [Code Structure and Modularity, Error Handling...
# 28  [Code Structure and Modularity, Input and Outp...
# 11  [Code Structure and Modularity, Input and Outp...
# 29  [Code Structure and Modularity, Input and Outp...
# 17  [Code Structure and Modularity, Input and Outp...
# 16  [Code Structure and Modularity, Input and Outp...
# 25  [Code Structure and Modularity, Input and Outp...
# 55  [Code Structure and Modularity, Error Handling...
# 58  [Code Structure and Modularity, Input and Outp...
# 39  [Code Structure and Modularity, Input and Outp...
# 38  [Code Structure and Modularity, Input and Outp...
# 23  [Code Structure and Modularity, Input and Outp...
# 32  [Code Structure and Modularity, Input and Outp...
# 46  [Code Structure and Modularity, Input and Outp...
# 50  [Code Structure and Modularity, Performance an...
# 36  [Code Structure and Modularity, Input and Outp...
# 7   [Code Structure and Modularity, Input and Outp...
# 47  [Code Structure and Modularity, Input and Outp...
# 2   [Code Structure and Modularity, Input and Outp...
# 51  [Code Structure and Modularity, Error Handling...
# 59  [Code Structure and Modularity, Input and Outp...
# 30  [Code Structure and Modularity, Input and Outp...
#
#                                simplified_instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 31  Design a Python class `GroupDialogManager` tha...
# 48  Use Tracking DB Service URL rather than localh...
# 24  Load e-mail data from a JSON file, convert it ...
# 22  Extract all names from a string that is not en...
# 41  Add auth protocol for keystone connection in v...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 9   Create a program to combine the elements of tw...
# 27  Generates an RSA public and private key pair a...
# 21  Randomly generate a pandas DataFrame with spec...
# 1   Assuming that the given sentence is stored in ...
# 6   Can you provide an example of mutation testing...
# 52  Fix the methods in `Course` so that all of the...
# 12  Problem:\nHaving a pandas data frame as follow...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 56  The distance is not updated correctly, fix the...
# 18  Problem: I have a 2-dimensional numpy array wh...
# 53  Make the `distances_to` function support negat...
# 42  Fix up import optional test to use temporary c...
# 44  Update manager API for update.\n"""Valve Manag...
# 0   Calculate the distance between two points loca...
# 8   Generate a random password. The password must ...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 20  Rollback the update of a directory by restorin...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 14  Problem: Say I have a 3 dimensional numpy arra...
# 45  Change Node type a bit\n\nfrom typing import M...
# 4   How can I decrypt a set of jokes that are encr...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 3   Create a Python class for Animal with the foll...
# 5   What is the purpose of the 'enumerate' keyword...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 34  Write a Python function `rotate_text` that tak...
# 57  Edit the code to include a method `powermod` t...
# 28  Create a list of random numbers, sort them and...
# 11  I have a logistic regression model using Pytor...
# 29  Search for occurrences of the word "error" in ...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 25  Generate diagrams for the sine and cosine func...
# 55  Change the code so that it supports a remove e...
# 58  Modify the function syllable_count so each 'co...
# 39  Write a Python function `send_email_with_attac...
# 38  Design a self-driving car simulation where the...
# 23  Replace a random substring (a sequence of char...
# 32  You are tasked with creating an automated test...
# 46  Make use of the return value of begin() and me...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 36  Create a Python function named `generate_mobil...
# 7   Edit the given code to fix the bug and increas...
# 47  Send a message back to client\nimport webapp2\...
# 2   Write a program in Python to find the factoria...
# 51  Fix how the alive neighbor count is calculated...
# 59  Make the name fully uppercase.\ndef hello_worl...
# 30  Write a Python function `calculate_distinct_av...
#
#                                 extracted_constraints
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
# 43                                                 []
# 31                                                 []
# 48  [{'type': 'Library and API Usage', 'constraint...
# 24  [{'type': 'File and Data Management', 'constra...
# 22  [{'type': 'Input and Output Handling', 'constr...
# 41  [{'type': 'Library and API Usage', 'constraint...
# 13  [{'type': 'Library and API Usage', 'constraint...
# 9   [{'type': 'Data Processing and Transformation'...
# 27  [{'type': 'File and Data Management', 'constra...
# 21  [{'type': 'Code Structure and Modularity', 'co...
# 1                                                  []
# 6   [{'type': 'Testing and Debugging', 'constraint...
# 52  [{'type': 'Error Handling and Robustness', 'co...
# 12  [{'type': 'Data Processing and Transformation'...
# 49                                                 []
# 56                                                 []
# 18  [{'type': 'Data Processing and Transformation'...
# 53  [{'type': 'Error Handling and Robustness', 'co...
# 42  [{'type': 'File and Data Management', 'constra...
# 44                                                 []
# 0   [{'type': 'Mathematical Computation', 'constra...
# 8   [{'type': 'Security and Privacy', 'constraint'...
# 40                                                 []
# 20  [{'type': 'File and Data Management', 'constra...
# 10  [{'type': 'Library and API Usage', 'constraint...
# 14  [{'type': 'Library and API Usage', 'constraint...
# 45                                                 []
# 4   [{'type': 'Code Structure and Modularity', 'co...
# 54  [{'type': 'Code Structure and Modularity', 'co...
# 3   [{'type': 'Code Structure and Modularity', 'co...
# 5                                                  []
# 15                                                 []
# 34  [{'type': 'Input and Output Handling', 'constr...
# 57  [{'type': 'Code Structure and Modularity', 'co...
# 28  [{'type': 'Error Handling and Robustness', 'co...
# 11  [{'type': 'Input and Output Handling', 'constr...
# 29  [{'type': 'Error Handling and Robustness', 'co...
# 17                                                 []
# 16                                                 []
# 25  [{'type': 'Library and API Usage', 'constraint...
# 55  [{'type': 'Code Structure and Modularity', 'co...
# 58  [{'type': 'Data Processing and Transformation'...
# 39  [{'type': 'Input and Output Handling', 'constr...
# 38  [{'type': 'Error Handling and Robustness', 'co...
# 23  [{'type': 'Input and Output Handling', 'constr...
# 32  [{'type': 'Code Structure and Modularity', 'co...
# 46                                                 []
# 50  [{'type': 'Performance and Optimization', 'con...
# 36  [{'type': 'Input and Output Handling', 'constr...
# 7   [{'type': 'Code Structure and Modularity', 'co...
# 47                                                 []
# 2   [{'type': 'Input and Output Handling', 'constr...
# 51                                                 []
# 59  [{'type': 'Data Processing and Transformation'...
# 30  [{'type': 'Input and Output Handling', 'constr...

# %% [markdown]
# ### Implementing stage 3

# %%
def generate_new_constraints(df,output_pth,input_col1,input_col2,input_col3,input_col4):
    prompts = []
    for _, row in df.iterrows():
        # print(f"Processing row {i}")
        prompt = get_prompt_stage3_generate_and_merge_constraints(row[input_col1], row[input_col2], row[input_col3], row[input_col4])
        prompts.append(prompt)
    responses = get_model_response_batch(prompts,SYSTEM_PROMPT_STAGE3_NEW)
    final_constraints = [extract_json(response,"final_comprehensive_constraints") for response in responses]
    df["final_comprehensive_constraints"] = final_constraints
    df.to_csv(output_pth, index=False)
    print("Saved the file successfully")
    return df

# %%
generate_new_constraints(df,"step3_with_final_comprehensive_constraints.csv","instruction","code","relevant_categories","extracted_constraints")
# Out:
# Processing: 100%|██████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:17<00:00,  3.35it/s]
# Saved the file successfully
#                                         dataset  \
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 19                              xlangai/DS-1000
# 26                         bigcode/bigcodebench
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
# 43                             nuprl/EditPackFT
# 31  Multilingual-Multimodal-NLP/McEval-Instruct
# 48                             nuprl/EditPackFT
# 24                         bigcode/bigcodebench
# 22                         bigcode/bigcodebench
# 41                             nuprl/EditPackFT
# 13                              xlangai/DS-1000
# 9         ajibawa-2023/Python-Code-23k-ShareGPT
# 27                         bigcode/bigcodebench
# 21                         bigcode/bigcodebench
# 1         ajibawa-2023/Python-Code-23k-ShareGPT
# 6         ajibawa-2023/Python-Code-23k-ShareGPT
# 52                              nuprl/CanItEdit
# 12                              xlangai/DS-1000
# 49                             nuprl/EditPackFT
# 56                              nuprl/CanItEdit
# 18                              xlangai/DS-1000
# 53                              nuprl/CanItEdit
# 42                             nuprl/EditPackFT
# 44                             nuprl/EditPackFT
# 0         ajibawa-2023/Python-Code-23k-ShareGPT
# 8         ajibawa-2023/Python-Code-23k-ShareGPT
# 40                             nuprl/EditPackFT
# 20                         bigcode/bigcodebench
# 10                              xlangai/DS-1000
# 14                              xlangai/DS-1000
# 45                             nuprl/EditPackFT
# 4         ajibawa-2023/Python-Code-23k-ShareGPT
# 54                              nuprl/CanItEdit
# 3         ajibawa-2023/Python-Code-23k-ShareGPT
# 5         ajibawa-2023/Python-Code-23k-ShareGPT
# 15                              xlangai/DS-1000
# 34  Multilingual-Multimodal-NLP/McEval-Instruct
# 57                              nuprl/CanItEdit
# 28                         bigcode/bigcodebench
# 11                              xlangai/DS-1000
# 29                         bigcode/bigcodebench
# 17                              xlangai/DS-1000
# 16                              xlangai/DS-1000
# 25                         bigcode/bigcodebench
# 55                              nuprl/CanItEdit
# 58                              nuprl/CanItEdit
# 39  Multilingual-Multimodal-NLP/McEval-Instruct
# 38  Multilingual-Multimodal-NLP/McEval-Instruct
# 23                         bigcode/bigcodebench
# 32  Multilingual-Multimodal-NLP/McEval-Instruct
# 46                             nuprl/EditPackFT
# 50                              nuprl/CanItEdit
# 36  Multilingual-Multimodal-NLP/McEval-Instruct
# 7         ajibawa-2023/Python-Code-23k-ShareGPT
# 47                             nuprl/EditPackFT
# 2         ajibawa-2023/Python-Code-23k-ShareGPT
# 51                              nuprl/CanItEdit
# 59                              nuprl/CanItEdit
# 30  Multilingual-Multimodal-NLP/McEval-Instruct
#
#                                           instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 31  Design a Python class `GroupDialogManager` tha...
# 48  Use Tracking DB Service URL rather than localh...
# 24  Load e-mail data from a JSON file, convert it ...
# 22  Extract all names from a string that is not en...
# 41  Add auth protocol for keystone connection in v...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 9   Create a program to combine the elements of tw...
# 27  Generates an RSA public and private key pair a...
# 21  Randomly generate a pandas DataFrame with spec...
# 1   Assuming that the given sentence is stored in ...
# 6   Can you provide an example of mutation testing...
# 52  Fix the methods in `Course` so that all of the...
# 12  Problem:\nHaving a pandas data frame as follow...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 56  The distance is not updated correctly, fix the...
# 18  Problem:\nI have a 2-dimensional numpy array w...
# 53  Make the `distances_to` function support negat...
# 42  Fix up import optional test to use temporary c...
# 44  Update manager API for update.\n"""Valve Manag...
# 0   Calculate the distance between two points loca...
# 8   Generate a random password that meets the foll...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 20  Rollback the update of a directory by restorin...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 14  Problem:\nSay I have a 3 dimensional numpy arr...
# 45  Change Node type a bit\n\nfrom typing import M...
# 4   How can I decrypt a set of jokes that are encr...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 3   Create a Python class for Animal with the foll...
# 5   What is the purpose of the 'enumerate' keyword...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 34  Write a Python function `rotate_text` that tak...
# 57  Edit the code to include a method `powermod` t...
# 28  Create a list of random numbers, sort them and...
# 11  Problem:\n\nI have a logistic regression model...
# 29  Search for occurrences of the word "error" in ...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 25  Generate diagrams for the sine and cosine func...
# 55  Change the code so that it supports a remove e...
# 58  Modify the function syllable_count so each 'co...
# 39  Write a Python function `send_email_with_attac...
# 38  Design a self-driving car simulation where the...
# 23  Replace a random substring (a sequence of char...
# 32  You are tasked with creating an automated test...
# 46  Make use of the return value of begin() and me...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 36  Create a Python function named `generate_mobil...
# 7   Edit the given code to fix the bug and increas...
# 47  Send a message back to client\nimport webapp2\...
# 2   Write a program in Python to find the factoria...
# 51  Fix how the alive neighbor count is calculated...
# 59  Make the name fully uppercase.\ndef hello_worl...
# 30  Write a Python function `calculate_distinct_av...
#
#                                                  code  \
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 26  # Check if DataFrame is empty\n    if data.emp...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
# 43  import os\n\nfrom unittest import TestCase\nfr...
# 31  ```python\nimport argparse\nfrom termcolor imp...
# 48  import pandas as pd\nimport sys\n\n\ndf = pd.r...
# 24  with open(json_file, 'r') as file:\n        em...
# 22  names = re.findall('(.*?)(?:\\[.*?\\]|$)', tex...
# 41  import string\n\ntemplate = string.Template(""...
# 13  sns.jointplot(\n    x="total_bill", y="tip", d...
# 9   Here's a Python program that combines the elem...
# 27  (pub_key, priv_key) = rsa.newkeys(512)\n    pa...
# 21  # Generate random data and create a DataFrame\...
# 1   To achieve this, you can use Python's string m...
# 6   Sure, here's an example of mutation testing in...
# 52  import functools\nimport numpy as np\nclass St...
# 12  import numpy as np\ndef g(df):\n    softmax = ...
# 49  import os\nimport numpy as np\nfrom whaler.dat...
# 56  class StepCounter:\n    def __init__(self):\n ...
# 18  bin_data_mean = data[:,:(data.shape[1] // bin_...
# 53  class Graph:\n    def __init__(self):\n       ...
# 42  import os\nimport subprocess\nimport sys\n\nne...
# 44  """Valve Manager base class"""\n\n# pylint: di...
# 0   To calculate the distance between two points i...
# 8   Here is a Python function that generates a ran...
# 40  import sys # Used to get rid of py2/3 differen...
# 20  # Check if the backup directory exists\n    if...
# 10         plt.plot(*zip(*points))\nplt.yscale("log")
# 14  result = a[:, np.array(second).reshape(-1,1), ...
# 45  from typing import Mapping, Set, Callable, Uni...
# 4   Sure, here's a Python function that decrypts t...
# 54  class Comparators:\n    """\n    A class for t...
# 3   ```python\nclass Animal:\n    def __init__(sel...
# 5   The purpose of the 'enumerate' keyword in Pyth...
# 15                   plt.imshow(data)\nplt.colorbar()
# 34  ```python\ndef rotate_text(text, rotation):\n ...
# 57  import math\n\ndef gcd(a : int, b : int) -> in...
# 28  if range_limit <= 1:\n        raise ValueError...
# 11  y = torch.argmax(softmax_output, dim=1).view(-...
# 29  if not os.path.isdir(dir_path):\n        raise...
# 17  plt.plot(y, x)\nplt.grid(color="blue", linesty...
# 16  result = True\nfor arr in a:\n    if any(np.is...
# 25  x_values = np.linspace(0, 2 * np.pi, 400)\n   ...
# 55  from abc import ABC, abstractmethod\n\nclass L...
# 58  import string\n\ndef prepare_string(line):\n  ...
# 39  ```python\nimport smtplib\nfrom email.mime.mul...
# 38  ```python\nimport pygame as pg\nimport math\nf...
# 23  random.seed(seed)\n\n    df = pd.DataFrame(dat...
# 32  ```python\nimport unittest\nfrom selenium impo...
# 46  import NDIR\nimport time\n\nsensor = NDIR.Sens...
# 50  import math\nfrom typing import List, Dict\n\n...
# 36  ```python\nimport pandas as pd\nimport plotly....
# 7   ```python\ndef calculate_tax(price):\n    tax_...
# 47  import webapp2\n\nfrom google.appengine.api im...
# 2   Here is a program in Python that finds the fac...
# 51  from typing import List\n\n\nclass ConwaysGame...
# 59  def hello_world(name):\n    return f'{name.upp...
# 30  ```python\nfrom __future__ import division\n\n...
#
#                                   relevant_categories  \
# 37  [Code Structure and Modularity, Input and Outp...
# 19  [Code Structure and Modularity, Input and Outp...
# 26  [Code Structure and Modularity, Input and Outp...
# 35  [Code Structure and Modularity, Input and Outp...
# 33  [Code Structure and Modularity, Input and Outp...
# 43  [Code Structure and Modularity, Testing and De...
# 31  [Code Structure and Modularity, Input and Outp...
# 48  [Code Structure and Modularity, Input and Outp...
# 24  [Code Structure and Modularity, Input and Outp...
# 22  [Code Structure and Modularity, Input and Outp...
# 41  [Code Structure and Modularity, Input and Outp...
# 13  [Library and API Usage, Data Processing and Tr...
# 9   [Code Structure and Modularity, Input and Outp...
# 27  [Code Structure and Modularity, Input and Outp...
# 21  [Code Structure and Modularity, Input and Outp...
# 1   [Code Structure and Modularity, Input and Outp...
# 6   [Code Structure and Modularity, Input and Outp...
# 52  [Error Handling and Robustness, Input and Outp...
# 12  [Code Structure and Modularity, Input and Outp...
# 49  [Code Structure and Modularity, Input and Outp...
# 56  [Code Structure and Modularity, Input and Outp...
# 18  [Code Structure and Modularity, Input and Outp...
# 53  [Code Structure and Modularity, Input and Outp...
# 42  [Code Structure and Modularity, Input and Outp...
# 44  [Code Structure and Modularity, Input and Outp...
# 0   [Code Structure and Modularity, Input and Outp...
# 8   [Code Structure and Modularity, Input and Outp...
# 40  [Code Structure and Modularity, Input and Outp...
# 20  [Code Structure and Modularity, Input and Outp...
# 10  [Code Structure and Modularity, Input and Outp...
# 14  [Code Structure and Modularity, Input and Outp...
# 45  [Code Structure and Modularity, Data Processin...
# 4   [Code Structure and Modularity, Input and Outp...
# 54  [Code Structure and Modularity, Input and Outp...
# 3   [Code Structure and Modularity, Input and Outp...
# 5   [Code Structure and Modularity, Input and Outp...
# 15  [Code Structure and Modularity, Input and Outp...
# 34  [Code Structure and Modularity, Input and Outp...
# 57  [Code Structure and Modularity, Error Handling...
# 28  [Code Structure and Modularity, Input and Outp...
# 11  [Code Structure and Modularity, Input and Outp...
# 29  [Code Structure and Modularity, Input and Outp...
# 17  [Code Structure and Modularity, Input and Outp...
# 16  [Code Structure and Modularity, Input and Outp...
# 25  [Code Structure and Modularity, Input and Outp...
# 55  [Code Structure and Modularity, Error Handling...
# 58  [Code Structure and Modularity, Input and Outp...
# 39  [Code Structure and Modularity, Input and Outp...
# 38  [Code Structure and Modularity, Input and Outp...
# 23  [Code Structure and Modularity, Input and Outp...
# 32  [Code Structure and Modularity, Input and Outp...
# 46  [Code Structure and Modularity, Input and Outp...
# 50  [Code Structure and Modularity, Performance an...
# 36  [Code Structure and Modularity, Input and Outp...
# 7   [Code Structure and Modularity, Input and Outp...
# 47  [Code Structure and Modularity, Input and Outp...
# 2   [Code Structure and Modularity, Input and Outp...
# 51  [Code Structure and Modularity, Error Handling...
# 59  [Code Structure and Modularity, Input and Outp...
# 30  [Code Structure and Modularity, Input and Outp...
#
#                                simplified_instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 31  Design a Python class `GroupDialogManager` tha...
# 48  Use Tracking DB Service URL rather than localh...
# 24  Load e-mail data from a JSON file, convert it ...
# 22  Extract all names from a string that is not en...
# 41  Add auth protocol for keystone connection in v...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 9   Create a program to combine the elements of tw...
# 27  Generates an RSA public and private key pair a...
# 21  Randomly generate a pandas DataFrame with spec...
# 1   Assuming that the given sentence is stored in ...
# 6   Can you provide an example of mutation testing...
# 52  Fix the methods in `Course` so that all of the...
# 12  Problem:\nHaving a pandas data frame as follow...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 56  The distance is not updated correctly, fix the...
# 18  Problem: I have a 2-dimensional numpy array wh...
# 53  Make the `distances_to` function support negat...
# 42  Fix up import optional test to use temporary c...
# 44  Update manager API for update.\n"""Valve Manag...
# 0   Calculate the distance between two points loca...
# 8   Generate a random password. The password must ...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 20  Rollback the update of a directory by restorin...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 14  Problem: Say I have a 3 dimensional numpy arra...
# 45  Change Node type a bit\n\nfrom typing import M...
# 4   How can I decrypt a set of jokes that are encr...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 3   Create a Python class for Animal with the foll...
# 5   What is the purpose of the 'enumerate' keyword...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 34  Write a Python function `rotate_text` that tak...
# 57  Edit the code to include a method `powermod` t...
# 28  Create a list of random numbers, sort them and...
# 11  I have a logistic regression model using Pytor...
# 29  Search for occurrences of the word "error" in ...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 25  Generate diagrams for the sine and cosine func...
# 55  Change the code so that it supports a remove e...
# 58  Modify the function syllable_count so each 'co...
# 39  Write a Python function `send_email_with_attac...
# 38  Design a self-driving car simulation where the...
# 23  Replace a random substring (a sequence of char...
# 32  You are tasked with creating an automated test...
# 46  Make use of the return value of begin() and me...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 36  Create a Python function named `generate_mobil...
# 7   Edit the given code to fix the bug and increas...
# 47  Send a message back to client\nimport webapp2\...
# 2   Write a program in Python to find the factoria...
# 51  Fix how the alive neighbor count is calculated...
# 59  Make the name fully uppercase.\ndef hello_worl...
# 30  Write a Python function `calculate_distinct_av...
#
#                                 extracted_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
# 43                                                 []
# 31                                                 []
# 48  [{'type': 'Library and API Usage', 'constraint...
# 24  [{'type': 'File and Data Management', 'constra...
# 22  [{'type': 'Input and Output Handling', 'constr...
# 41  [{'type': 'Library and API Usage', 'constraint...
# 13  [{'type': 'Library and API Usage', 'constraint...
# 9   [{'type': 'Data Processing and Transformation'...
# 27  [{'type': 'File and Data Management', 'constra...
# 21  [{'type': 'Code Structure and Modularity', 'co...
# 1                                                  []
# 6   [{'type': 'Testing and Debugging', 'constraint...
# 52  [{'type': 'Error Handling and Robustness', 'co...
# 12  [{'type': 'Data Processing and Transformation'...
# 49                                                 []
# 56                                                 []
# 18  [{'type': 'Data Processing and Transformation'...
# 53  [{'type': 'Error Handling and Robustness', 'co...
# 42  [{'type': 'File and Data Management', 'constra...
# 44                                                 []
# 0   [{'type': 'Mathematical Computation', 'constra...
# 8   [{'type': 'Security and Privacy', 'constraint'...
# 40                                                 []
# 20  [{'type': 'File and Data Management', 'constra...
# 10  [{'type': 'Library and API Usage', 'constraint...
# 14  [{'type': 'Library and API Usage', 'constraint...
# 45                                                 []
# 4   [{'type': 'Code Structure and Modularity', 'co...
# 54  [{'type': 'Code Structure and Modularity', 'co...
# 3   [{'type': 'Code Structure and Modularity', 'co...
# 5                                                  []
# 15                                                 []
# 34  [{'type': 'Input and Output Handling', 'constr...
# 57  [{'type': 'Code Structure and Modularity', 'co...
# 28  [{'type': 'Error Handling and Robustness', 'co...
# 11  [{'type': 'Input and Output Handling', 'constr...
# 29  [{'type': 'Error Handling and Robustness', 'co...
# 17                                                 []
# 16                                                 []
# 25  [{'type': 'Library and API Usage', 'constraint...
# 55  [{'type': 'Code Structure and Modularity', 'co...
# 58  [{'type': 'Data Processing and Transformation'...
# 39  [{'type': 'Input and Output Handling', 'constr...
# 38  [{'type': 'Error Handling and Robustness', 'co...
# 23  [{'type': 'Input and Output Handling', 'constr...
# 32  [{'type': 'Code Structure and Modularity', 'co...
# 46                                                 []
# 50  [{'type': 'Performance and Optimization', 'con...
# 36  [{'type': 'Input and Output Handling', 'constr...
# 7   [{'type': 'Code Structure and Modularity', 'co...
# 47                                                 []
# 2   [{'type': 'Input and Output Handling', 'constr...
# 51                                                 []
# 59  [{'type': 'Data Processing and Transformation'...
# 30  [{'type': 'Input and Output Handling', 'constr...
#
#                       final_comprehensive_constraints
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
# 43  [{'type': 'Testing and Debugging', 'constraint...
# 31  [{'type': 'Code Structure and Modularity', 'co...
# 48  [{'type': 'Library and API Usage', 'constraint...
# 24  [{'type': 'File and Data Management', 'constra...
# 22  [{'type': 'Input and Output Handling', 'constr...
# 41  [{'type': 'Library and API Usage', 'constraint...
# 13  [{'type': 'Library and API Usage', 'constraint...
# 9   [{'type': 'Data Processing and Transformation'...
# 27  [{'type': 'File and Data Management', 'constra...
# 21  [{'type': 'Code Structure and Modularity', 'co...
# 1   [{'type': 'Code Structure and Modularity', 'co...
# 6   [{'type': 'Testing and Debugging', 'constraint...
# 52  [{'type': 'Error Handling and Robustness', 'co...
# 12  [{'type': 'Data Processing and Transformation'...
# 49  [{'type': 'Code Structure and Modularity', 'co...
# 56  [{'type': 'Error Handling and Robustness', 'co...
# 18  [{'type': 'Data Processing and Transformation'...
# 53  [{'type': 'Error Handling and Robustness', 'co...
# 42  [{'type': 'File and Data Management', 'constra...
# 44  [{'type': 'Code Structure and Modularity', 'co...
# 0   [{'type': 'Mathematical Computation', 'constra...
# 8   [{'type': 'Security and Privacy', 'constraint'...
# 40  [{'type': 'Code Structure and Modularity', 'co...
# 20  [{'type': 'File and Data Management', 'constra...
# 10  [{'type': 'Library and API Usage', 'constraint...
# 14  [{'type': 'Library and API Usage', 'constraint...
# 45  [{'type': 'Code Structure and Modularity', 'co...
# 4   [{'type': 'Code Structure and Modularity', 'co...
# 54  [{'type': 'Code Structure and Modularity', 'co...
# 3   [{'type': 'Code Structure and Modularity', 'co...
# 5   [{'type': 'Library and API Usage', 'constraint...
# 15  [{'type': 'Library and API Usage', 'constraint...
# 34  [{'type': 'Input and Output Handling', 'constr...
# 57  [{'type': 'Code Structure and Modularity', 'co...
# 28  [{'type': 'Error Handling and Robustness', 'co...
# 11  [{'type': 'Input and Output Handling', 'constr...
# 29  [{'type': 'Error Handling and Robustness', 'co...
# 17  [{'type': 'Code Structure and Modularity', 'co...
# 16  [{'type': 'Data Processing and Transformation'...
# 25  [{'type': 'Library and API Usage', 'constraint...
# 55  [{'type': 'Code Structure and Modularity', 'co...
# 58  [{'type': 'Data Processing and Transformation'...
# 39  [{'type': 'Input and Output Handling', 'constr...
# 38  [{'type': 'Error Handling and Robustness', 'co...
# 23  [{'type': 'Input and Output Handling', 'constr...
# 32  [{'type': 'Code Structure and Modularity', 'co...
# 46  [{'type': 'Code Structure and Modularity', 'co...
# 50  [{'type': 'Performance and Optimization', 'con...
# 36  [{'type': 'Input and Output Handling', 'constr...
# 7   [{'type': 'Code Structure and Modularity', 'co...
# 47  [{'type': 'Code Structure and Modularity', 'co...
# 2   [{'type': 'Input and Output Handling', 'constr...
# 51  [{'type': 'Code Structure and Modularity', 'co...
# 59  [{'type': 'Data Processing and Transformation'...
# 30  [{'type': 'Input and Output Handling', 'constr...

# %% [markdown]
# ### Impementing the Stage 4

# %%
def final_relevance_filter(df,output_pth,input_col1,input_col2):
    results = []
    prompts = []
    for _, row in df.iterrows():
        # print(f"Processing row {i}")
        prompt = get_prompt_stage4_final_relevance_and_filter(row[input_col1], row[input_col2])
        prompts.append(prompt)
    responses = get_model_response_batch(prompts,SYSTEM_PROMPT_STAGE4_FINAL_RELEVANCE_FILTER)
    df["filtered_relevant_constraints"] = [extract_json(response,"filtered_relevant_constraints") for response in responses]
    df.to_csv(output_pth, index=False)
    print("Saved the file successfully")
    return df

# %%
final_relevance_filter(df,"step4_with_filtered_relevant_constraints.csv","instruction","final_comprehensive_constraints")
# Out:
# Processing: 100%|██████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:36<00:00,  1.65it/s]
# Saved the file successfully
#                                         dataset  \
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 19                              xlangai/DS-1000
# 26                         bigcode/bigcodebench
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
# 43                             nuprl/EditPackFT
# 31  Multilingual-Multimodal-NLP/McEval-Instruct
# 48                             nuprl/EditPackFT
# 24                         bigcode/bigcodebench
# 22                         bigcode/bigcodebench
# 41                             nuprl/EditPackFT
# 13                              xlangai/DS-1000
# 9         ajibawa-2023/Python-Code-23k-ShareGPT
# 27                         bigcode/bigcodebench
# 21                         bigcode/bigcodebench
# 1         ajibawa-2023/Python-Code-23k-ShareGPT
# 6         ajibawa-2023/Python-Code-23k-ShareGPT
# 52                              nuprl/CanItEdit
# 12                              xlangai/DS-1000
# 49                             nuprl/EditPackFT
# 56                              nuprl/CanItEdit
# 18                              xlangai/DS-1000
# 53                              nuprl/CanItEdit
# 42                             nuprl/EditPackFT
# 44                             nuprl/EditPackFT
# 0         ajibawa-2023/Python-Code-23k-ShareGPT
# 8         ajibawa-2023/Python-Code-23k-ShareGPT
# 40                             nuprl/EditPackFT
# 20                         bigcode/bigcodebench
# 10                              xlangai/DS-1000
# 14                              xlangai/DS-1000
# 45                             nuprl/EditPackFT
# 4         ajibawa-2023/Python-Code-23k-ShareGPT
# 54                              nuprl/CanItEdit
# 3         ajibawa-2023/Python-Code-23k-ShareGPT
# 5         ajibawa-2023/Python-Code-23k-ShareGPT
# 15                              xlangai/DS-1000
# 34  Multilingual-Multimodal-NLP/McEval-Instruct
# 57                              nuprl/CanItEdit
# 28                         bigcode/bigcodebench
# 11                              xlangai/DS-1000
# 29                         bigcode/bigcodebench
# 17                              xlangai/DS-1000
# 16                              xlangai/DS-1000
# 25                         bigcode/bigcodebench
# 55                              nuprl/CanItEdit
# 58                              nuprl/CanItEdit
# 39  Multilingual-Multimodal-NLP/McEval-Instruct
# 38  Multilingual-Multimodal-NLP/McEval-Instruct
# 23                         bigcode/bigcodebench
# 32  Multilingual-Multimodal-NLP/McEval-Instruct
# 46                             nuprl/EditPackFT
# 50                              nuprl/CanItEdit
# 36  Multilingual-Multimodal-NLP/McEval-Instruct
# 7         ajibawa-2023/Python-Code-23k-ShareGPT
# 47                             nuprl/EditPackFT
# 2         ajibawa-2023/Python-Code-23k-ShareGPT
# 51                              nuprl/CanItEdit
# 59                              nuprl/CanItEdit
# 30  Multilingual-Multimodal-NLP/McEval-Instruct
#
#                                           instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 31  Design a Python class `GroupDialogManager` tha...
# 48  Use Tracking DB Service URL rather than localh...
# 24  Load e-mail data from a JSON file, convert it ...
# 22  Extract all names from a string that is not en...
# 41  Add auth protocol for keystone connection in v...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 9   Create a program to combine the elements of tw...
# 27  Generates an RSA public and private key pair a...
# 21  Randomly generate a pandas DataFrame with spec...
# 1   Assuming that the given sentence is stored in ...
# 6   Can you provide an example of mutation testing...
# 52  Fix the methods in `Course` so that all of the...
# 12  Problem:\nHaving a pandas data frame as follow...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 56  The distance is not updated correctly, fix the...
# 18  Problem:\nI have a 2-dimensional numpy array w...
# 53  Make the `distances_to` function support negat...
# 42  Fix up import optional test to use temporary c...
# 44  Update manager API for update.\n"""Valve Manag...
# 0   Calculate the distance between two points loca...
# 8   Generate a random password that meets the foll...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 20  Rollback the update of a directory by restorin...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 14  Problem:\nSay I have a 3 dimensional numpy arr...
# 45  Change Node type a bit\n\nfrom typing import M...
# 4   How can I decrypt a set of jokes that are encr...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 3   Create a Python class for Animal with the foll...
# 5   What is the purpose of the 'enumerate' keyword...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 34  Write a Python function `rotate_text` that tak...
# 57  Edit the code to include a method `powermod` t...
# 28  Create a list of random numbers, sort them and...
# 11  Problem:\n\nI have a logistic regression model...
# 29  Search for occurrences of the word "error" in ...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 25  Generate diagrams for the sine and cosine func...
# 55  Change the code so that it supports a remove e...
# 58  Modify the function syllable_count so each 'co...
# 39  Write a Python function `send_email_with_attac...
# 38  Design a self-driving car simulation where the...
# 23  Replace a random substring (a sequence of char...
# 32  You are tasked with creating an automated test...
# 46  Make use of the return value of begin() and me...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 36  Create a Python function named `generate_mobil...
# 7   Edit the given code to fix the bug and increas...
# 47  Send a message back to client\nimport webapp2\...
# 2   Write a program in Python to find the factoria...
# 51  Fix how the alive neighbor count is calculated...
# 59  Make the name fully uppercase.\ndef hello_worl...
# 30  Write a Python function `calculate_distinct_av...
#
#                                                  code  \
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 26  # Check if DataFrame is empty\n    if data.emp...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
# 43  import os\n\nfrom unittest import TestCase\nfr...
# 31  ```python\nimport argparse\nfrom termcolor imp...
# 48  import pandas as pd\nimport sys\n\n\ndf = pd.r...
# 24  with open(json_file, 'r') as file:\n        em...
# 22  names = re.findall('(.*?)(?:\\[.*?\\]|$)', tex...
# 41  import string\n\ntemplate = string.Template(""...
# 13  sns.jointplot(\n    x="total_bill", y="tip", d...
# 9   Here's a Python program that combines the elem...
# 27  (pub_key, priv_key) = rsa.newkeys(512)\n    pa...
# 21  # Generate random data and create a DataFrame\...
# 1   To achieve this, you can use Python's string m...
# 6   Sure, here's an example of mutation testing in...
# 52  import functools\nimport numpy as np\nclass St...
# 12  import numpy as np\ndef g(df):\n    softmax = ...
# 49  import os\nimport numpy as np\nfrom whaler.dat...
# 56  class StepCounter:\n    def __init__(self):\n ...
# 18  bin_data_mean = data[:,:(data.shape[1] // bin_...
# 53  class Graph:\n    def __init__(self):\n       ...
# 42  import os\nimport subprocess\nimport sys\n\nne...
# 44  """Valve Manager base class"""\n\n# pylint: di...
# 0   To calculate the distance between two points i...
# 8   Here is a Python function that generates a ran...
# 40  import sys # Used to get rid of py2/3 differen...
# 20  # Check if the backup directory exists\n    if...
# 10         plt.plot(*zip(*points))\nplt.yscale("log")
# 14  result = a[:, np.array(second).reshape(-1,1), ...
# 45  from typing import Mapping, Set, Callable, Uni...
# 4   Sure, here's a Python function that decrypts t...
# 54  class Comparators:\n    """\n    A class for t...
# 3   ```python\nclass Animal:\n    def __init__(sel...
# 5   The purpose of the 'enumerate' keyword in Pyth...
# 15                   plt.imshow(data)\nplt.colorbar()
# 34  ```python\ndef rotate_text(text, rotation):\n ...
# 57  import math\n\ndef gcd(a : int, b : int) -> in...
# 28  if range_limit <= 1:\n        raise ValueError...
# 11  y = torch.argmax(softmax_output, dim=1).view(-...
# 29  if not os.path.isdir(dir_path):\n        raise...
# 17  plt.plot(y, x)\nplt.grid(color="blue", linesty...
# 16  result = True\nfor arr in a:\n    if any(np.is...
# 25  x_values = np.linspace(0, 2 * np.pi, 400)\n   ...
# 55  from abc import ABC, abstractmethod\n\nclass L...
# 58  import string\n\ndef prepare_string(line):\n  ...
# 39  ```python\nimport smtplib\nfrom email.mime.mul...
# 38  ```python\nimport pygame as pg\nimport math\nf...
# 23  random.seed(seed)\n\n    df = pd.DataFrame(dat...
# 32  ```python\nimport unittest\nfrom selenium impo...
# 46  import NDIR\nimport time\n\nsensor = NDIR.Sens...
# 50  import math\nfrom typing import List, Dict\n\n...
# 36  ```python\nimport pandas as pd\nimport plotly....
# 7   ```python\ndef calculate_tax(price):\n    tax_...
# 47  import webapp2\n\nfrom google.appengine.api im...
# 2   Here is a program in Python that finds the fac...
# 51  from typing import List\n\n\nclass ConwaysGame...
# 59  def hello_world(name):\n    return f'{name.upp...
# 30  ```python\nfrom __future__ import division\n\n...
#
#                                   relevant_categories  \
# 37  [Code Structure and Modularity, Input and Outp...
# 19  [Code Structure and Modularity, Input and Outp...
# 26  [Code Structure and Modularity, Input and Outp...
# 35  [Code Structure and Modularity, Input and Outp...
# 33  [Code Structure and Modularity, Input and Outp...
# 43  [Code Structure and Modularity, Testing and De...
# 31  [Code Structure and Modularity, Input and Outp...
# 48  [Code Structure and Modularity, Input and Outp...
# 24  [Code Structure and Modularity, Input and Outp...
# 22  [Code Structure and Modularity, Input and Outp...
# 41  [Code Structure and Modularity, Input and Outp...
# 13  [Library and API Usage, Data Processing and Tr...
# 9   [Code Structure and Modularity, Input and Outp...
# 27  [Code Structure and Modularity, Input and Outp...
# 21  [Code Structure and Modularity, Input and Outp...
# 1   [Code Structure and Modularity, Input and Outp...
# 6   [Code Structure and Modularity, Input and Outp...
# 52  [Error Handling and Robustness, Input and Outp...
# 12  [Code Structure and Modularity, Input and Outp...
# 49  [Code Structure and Modularity, Input and Outp...
# 56  [Code Structure and Modularity, Input and Outp...
# 18  [Code Structure and Modularity, Input and Outp...
# 53  [Code Structure and Modularity, Input and Outp...
# 42  [Code Structure and Modularity, Input and Outp...
# 44  [Code Structure and Modularity, Input and Outp...
# 0   [Code Structure and Modularity, Input and Outp...
# 8   [Code Structure and Modularity, Input and Outp...
# 40  [Code Structure and Modularity, Input and Outp...
# 20  [Code Structure and Modularity, Input and Outp...
# 10  [Code Structure and Modularity, Input and Outp...
# 14  [Code Structure and Modularity, Input and Outp...
# 45  [Code Structure and Modularity, Data Processin...
# 4   [Code Structure and Modularity, Input and Outp...
# 54  [Code Structure and Modularity, Input and Outp...
# 3   [Code Structure and Modularity, Input and Outp...
# 5   [Code Structure and Modularity, Input and Outp...
# 15  [Code Structure and Modularity, Input and Outp...
# 34  [Code Structure and Modularity, Input and Outp...
# 57  [Code Structure and Modularity, Error Handling...
# 28  [Code Structure and Modularity, Input and Outp...
# 11  [Code Structure and Modularity, Input and Outp...
# 29  [Code Structure and Modularity, Input and Outp...
# 17  [Code Structure and Modularity, Input and Outp...
# 16  [Code Structure and Modularity, Input and Outp...
# 25  [Code Structure and Modularity, Input and Outp...
# 55  [Code Structure and Modularity, Error Handling...
# 58  [Code Structure and Modularity, Input and Outp...
# 39  [Code Structure and Modularity, Input and Outp...
# 38  [Code Structure and Modularity, Input and Outp...
# 23  [Code Structure and Modularity, Input and Outp...
# 32  [Code Structure and Modularity, Input and Outp...
# 46  [Code Structure and Modularity, Input and Outp...
# 50  [Code Structure and Modularity, Performance an...
# 36  [Code Structure and Modularity, Input and Outp...
# 7   [Code Structure and Modularity, Input and Outp...
# 47  [Code Structure and Modularity, Input and Outp...
# 2   [Code Structure and Modularity, Input and Outp...
# 51  [Code Structure and Modularity, Error Handling...
# 59  [Code Structure and Modularity, Input and Outp...
# 30  [Code Structure and Modularity, Input and Outp...
#
#                                simplified_instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
# 43  Add Unit-Test For Scanner Problem\nimport os\n...
# 31  Design a Python class `GroupDialogManager` tha...
# 48  Use Tracking DB Service URL rather than localh...
# 24  Load e-mail data from a JSON file, convert it ...
# 22  Extract all names from a string that is not en...
# 41  Add auth protocol for keystone connection in v...
# 13  import matplotlib.pyplot as plt\nimport numpy ...
# 9   Create a program to combine the elements of tw...
# 27  Generates an RSA public and private key pair a...
# 21  Randomly generate a pandas DataFrame with spec...
# 1   Assuming that the given sentence is stored in ...
# 6   Can you provide an example of mutation testing...
# 52  Fix the methods in `Course` so that all of the...
# 12  Problem:\nHaving a pandas data frame as follow...
# 49  Set up data tabulation for gs\n\nimport os\nfr...
# 56  The distance is not updated correctly, fix the...
# 18  Problem: I have a 2-dimensional numpy array wh...
# 53  Make the `distances_to` function support negat...
# 42  Fix up import optional test to use temporary c...
# 44  Update manager API for update.\n"""Valve Manag...
# 0   Calculate the distance between two points loca...
# 8   Generate a random password. The password must ...
# 40  Fix python 3 support for exec\nimport sys # Us...
# 20  Rollback the update of a directory by restorin...
# 10  import numpy as np\nimport pandas as pd\nimpor...
# 14  Problem: Say I have a 3 dimensional numpy arra...
# 45  Change Node type a bit\n\nfrom typing import M...
# 4   How can I decrypt a set of jokes that are encr...
# 54  Write a function `sort_with_tiebreaker(items, ...
# 3   Create a Python class for Animal with the foll...
# 5   What is the purpose of the 'enumerate' keyword...
# 15  import matplotlib.pyplot as plt\nimport numpy ...
# 34  Write a Python function `rotate_text` that tak...
# 57  Edit the code to include a method `powermod` t...
# 28  Create a list of random numbers, sort them and...
# 11  I have a logistic regression model using Pytor...
# 29  Search for occurrences of the word "error" in ...
# 17  import numpy as np\nimport pandas as pd\nimpor...
# 16  Problem:\nI have a list of numpy arrays, and w...
# 25  Generate diagrams for the sine and cosine func...
# 55  Change the code so that it supports a remove e...
# 58  Modify the function syllable_count so each 'co...
# 39  Write a Python function `send_email_with_attac...
# 38  Design a self-driving car simulation where the...
# 23  Replace a random substring (a sequence of char...
# 32  You are tasked with creating an automated test...
# 46  Make use of the return value of begin() and me...
# 50  Optimize the bm25 algorithm by avoiding freque...
# 36  Create a Python function named `generate_mobil...
# 7   Edit the given code to fix the bug and increas...
# 47  Send a message back to client\nimport webapp2\...
# 2   Write a program in Python to find the factoria...
# 51  Fix how the alive neighbor count is calculated...
# 59  Make the name fully uppercase.\ndef hello_worl...
# 30  Write a Python function `calculate_distinct_av...
#
#                                 extracted_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
# 43                                                 []
# 31                                                 []
# 48  [{'type': 'Library and API Usage', 'constraint...
# 24  [{'type': 'File and Data Management', 'constra...
# 22  [{'type': 'Input and Output Handling', 'constr...
# 41  [{'type': 'Library and API Usage', 'constraint...
# 13  [{'type': 'Library and API Usage', 'constraint...
# 9   [{'type': 'Data Processing and Transformation'...
# 27  [{'type': 'File and Data Management', 'constra...
# 21  [{'type': 'Code Structure and Modularity', 'co...
# 1                                                  []
# 6   [{'type': 'Testing and Debugging', 'constraint...
# 52  [{'type': 'Error Handling and Robustness', 'co...
# 12  [{'type': 'Data Processing and Transformation'...
# 49                                                 []
# 56                                                 []
# 18  [{'type': 'Data Processing and Transformation'...
# 53  [{'type': 'Error Handling and Robustness', 'co...
# 42  [{'type': 'File and Data Management', 'constra...
# 44                                                 []
# 0   [{'type': 'Mathematical Computation', 'constra...
# 8   [{'type': 'Security and Privacy', 'constraint'...
# 40                                                 []
# 20  [{'type': 'File and Data Management', 'constra...
# 10  [{'type': 'Library and API Usage', 'constraint...
# 14  [{'type': 'Library and API Usage', 'constraint...
# 45                                                 []
# 4   [{'type': 'Code Structure and Modularity', 'co...
# 54  [{'type': 'Code Structure and Modularity', 'co...
# 3   [{'type': 'Code Structure and Modularity', 'co...
# 5                                                  []
# 15                                                 []
# 34  [{'type': 'Input and Output Handling', 'constr...
# 57  [{'type': 'Code Structure and Modularity', 'co...
# 28  [{'type': 'Error Handling and Robustness', 'co...
# 11  [{'type': 'Input and Output Handling', 'constr...
# 29  [{'type': 'Error Handling and Robustness', 'co...
# 17                                                 []
# 16                                                 []
# 25  [{'type': 'Library and API Usage', 'constraint...
# 55  [{'type': 'Code Structure and Modularity', 'co...
# 58  [{'type': 'Data Processing and Transformation'...
# 39  [{'type': 'Input and Output Handling', 'constr...
# 38  [{'type': 'Error Handling and Robustness', 'co...
# 23  [{'type': 'Input and Output Handling', 'constr...
# 32  [{'type': 'Code Structure and Modularity', 'co...
# 46                                                 []
# 50  [{'type': 'Performance and Optimization', 'con...
# 36  [{'type': 'Input and Output Handling', 'constr...
# 7   [{'type': 'Code Structure and Modularity', 'co...
# 47                                                 []
# 2   [{'type': 'Input and Output Handling', 'constr...
# 51                                                 []
# 59  [{'type': 'Data Processing and Transformation'...
# 30  [{'type': 'Input and Output Handling', 'constr...
#
#                       final_comprehensive_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
# 43  [{'type': 'Testing and Debugging', 'constraint...
# 31  [{'type': 'Code Structure and Modularity', 'co...
# 48  [{'type': 'Library and API Usage', 'constraint...
# 24  [{'type': 'File and Data Management', 'constra...
# 22  [{'type': 'Input and Output Handling', 'constr...
# 41  [{'type': 'Library and API Usage', 'constraint...
# 13  [{'type': 'Library and API Usage', 'constraint...
# 9   [{'type': 'Data Processing and Transformation'...
# 27  [{'type': 'File and Data Management', 'constra...
# 21  [{'type': 'Code Structure and Modularity', 'co...
# 1   [{'type': 'Code Structure and Modularity', 'co...
# 6   [{'type': 'Testing and Debugging', 'constraint...
# 52  [{'type': 'Error Handling and Robustness', 'co...
# 12  [{'type': 'Data Processing and Transformation'...
# 49  [{'type': 'Code Structure and Modularity', 'co...
# 56  [{'type': 'Error Handling and Robustness', 'co...
# 18  [{'type': 'Data Processing and Transformation'...
# 53  [{'type': 'Error Handling and Robustness', 'co...
# 42  [{'type': 'File and Data Management', 'constra...
# 44  [{'type': 'Code Structure and Modularity', 'co...
# 0   [{'type': 'Mathematical Computation', 'constra...
# 8   [{'type': 'Security and Privacy', 'constraint'...
# 40  [{'type': 'Code Structure and Modularity', 'co...
# 20  [{'type': 'File and Data Management', 'constra...
# 10  [{'type': 'Library and API Usage', 'constraint...
# 14  [{'type': 'Library and API Usage', 'constraint...
# 45  [{'type': 'Code Structure and Modularity', 'co...
# 4   [{'type': 'Code Structure and Modularity', 'co...
# 54  [{'type': 'Code Structure and Modularity', 'co...
# 3   [{'type': 'Code Structure and Modularity', 'co...
# 5   [{'type': 'Library and API Usage', 'constraint...
# 15  [{'type': 'Library and API Usage', 'constraint...
# 34  [{'type': 'Input and Output Handling', 'constr...
# 57  [{'type': 'Code Structure and Modularity', 'co...
# 28  [{'type': 'Error Handling and Robustness', 'co...
# 11  [{'type': 'Input and Output Handling', 'constr...
# 29  [{'type': 'Error Handling and Robustness', 'co...
# 17  [{'type': 'Code Structure and Modularity', 'co...
# 16  [{'type': 'Data Processing and Transformation'...
# 25  [{'type': 'Library and API Usage', 'constraint...
# 55  [{'type': 'Code Structure and Modularity', 'co...
# 58  [{'type': 'Data Processing and Transformation'...
# 39  [{'type': 'Input and Output Handling', 'constr...
# 38  [{'type': 'Error Handling and Robustness', 'co...
# 23  [{'type': 'Input and Output Handling', 'constr...
# 32  [{'type': 'Code Structure and Modularity', 'co...
# 46  [{'type': 'Code Structure and Modularity', 'co...
# 50  [{'type': 'Performance and Optimization', 'con...
# 36  [{'type': 'Input and Output Handling', 'constr...
# 7   [{'type': 'Code Structure and Modularity', 'co...
# 47  [{'type': 'Code Structure and Modularity', 'co...
# 2   [{'type': 'Input and Output Handling', 'constr...
# 51  [{'type': 'Code Structure and Modularity', 'co...
# 59  [{'type': 'Data Processing and Transformation'...
# 30  [{'type': 'Input and Output Handling', 'constr...
#
#                         filtered_relevant_constraints
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
# 43  [{'type': 'Testing and Debugging', 'constraint...
# 31  [{'type': 'Code Structure and Modularity', 'co...
# 48  [{'type': 'Library and API Usage', 'constraint...
# 24  [{'type': 'File and Data Management', 'constra...
# 22  [{'type': 'Input and Output Handling', 'constr...
# 41  [{'type': 'Library and API Usage', 'constraint...
# 13  [{'type': 'Library and API Usage', 'constraint...
# 9   [{'type': 'Data Processing and Transformation'...
# 27  [{'type': 'File and Data Management', 'constra...
# 21  [{'type': 'Code Structure and Modularity', 'co...
# 1   [{'type': 'Code Structure and Modularity', 'co...
# 6   [{'type': 'Testing and Debugging', 'constraint...
# 52  [{'type': 'Error Handling and Robustness', 'co...
# 12  [{'type': 'Data Processing and Transformation'...
# 49  [{'type': 'Code Structure and Modularity', 'co...
# 56  [{'type': 'Mathematical Computation', 'constra...
# 18  [{'type': 'Data Processing and Transformation'...
# 53  [{'type': 'Error Handling and Robustness', 'co...
# 42  [{'type': 'File and Data Management', 'constra...
# 44  [{'type': 'Code Structure and Modularity', 'co...
# 0   [{'type': 'Mathematical Computation', 'constra...
# 8   [{'type': 'Security and Privacy', 'constraint'...
# 40  [{'type': 'Input and Output Handling', 'constr...
# 20  [{'type': 'File and Data Management', 'constra...
# 10  [{'type': 'Library and API Usage', 'constraint...
# 14  [{'type': 'Library and API Usage', 'constraint...
# 45  [{'type': 'Code Structure and Modularity', 'co...
# 4   [{'type': 'Code Structure and Modularity', 'co...
# 54  [{'type': 'Code Structure and Modularity', 'co...
# 3   [{'type': 'Code Structure and Modularity', 'co...
# 5   [{'type': 'Library and API Usage', 'constraint...
# 15  [{'type': 'Library and API Usage', 'constraint...
# 34  [{'type': 'Input and Output Handling', 'constr...
# 57  [{'type': 'Code Structure and Modularity', 'co...
# 28  [{'type': 'Error Handling and Robustness', 'co...
# 11  [{'type': 'Input and Output Handling', 'constr...
# 29  [{'type': 'Error Handling and Robustness', 'co...
# 17  [{'type': 'Code Structure and Modularity', 'co...
# 16  [{'type': 'Data Processing and Transformation'...
# 25  [{'type': 'Library and API Usage', 'constraint...
# 55  [{'type': 'Code Structure and Modularity', 'co...
# 58  [{'type': 'Data Processing and Transformation'...
# 39  [{'type': 'Input and Output Handling', 'constr...
# 38  [{'type': 'Error Handling and Robustness', 'co...
# 23  [{'type': 'Input and Output Handling', 'constr...
# 32  [{'type': 'Code Structure and Modularity', 'co...
# 46  [{'type': 'Code Structure and Modularity', 'co...
# 50  [{'type': 'Performance and Optimization', 'con...
# 36  [{'type': 'Input and Output Handling', 'constr...
# 7   [{'type': 'Code Structure and Modularity', 'co...
# 47  [{'type': 'Input and Output Handling', 'constr...
# 2   [{'type': 'Input and Output Handling', 'constr...
# 51  [{'type': 'Data Processing and Transformation'...
# 59  [{'type': 'Data Processing and Transformation'...
# 30  [{'type': 'Input and Output Handling', 'constr...

# %% [markdown]
# # Validating the Constraints

# %%
# SYSTEM_PROMPT for the Quality Judge LLM
SYSTEM_PROMPT_QUALITY_JUDGE = """
You are an expert in meticulously evaluating the quality of programming constraints.
Your task is to objectively assess a provided list of generated constraints based on strict quality criteria.
For each constraint, you will provide specific scores for Atomicity, Relevance, and Objectivity, along with detailed reasoning and suggestions for improvement.
Finally, you will synthesize these individual evaluations into a unified quality score and an overall analysis for the entire set of constraints.
Your judgment must be impartial and directly tied to the definitions provided.
"""

# User-facing prompt for the Quality Judge LLM
def get_quality_judge_prompt(original_instruction, original_code, generated_constraint_list):
    return f"""
Original Instruction: {original_instruction}

Original Code (for context, if available):
```python
{original_code}
```

List of Generated Constraints to Evaluate:
{generated_constraint_list}

Constraint Quality Criteria:
Each score ranges from 1 (poor) to 5 (excellent).

Atomicity Score (1–5):
Definition: Measures whether a constraint expresses exactly one indivisible requirement.
An atomic constraint should not contain multiple independent rules or directives.
Examples:
- 1 (Non-Atomic): "Return a float and raise ValueError for invalid input."
- 5 (Atomic): "Raise ValueError for invalid input."

Relevance Score (1–5):
Definition: Measures how well the constraint aligns with the core task described in the instruction.
A relevant constraint addresses functionality, behavior, or structure directly related to the task.
Examples:
- 1 (Off-topic): "Avoid using global variables."
- 5 (Directly relevant): "Raise ValueError if the input DataFrame is empty."

Objectivity Score (1–5):
Definition: Measures whether the constraint can be evaluated without personal interpretation or judgment.
An objective constraint uses measurable, observable, or clearly definable criteria.
Examples:
- 1 (Subjective): "The code should be intuitive and clean."
- 5 (Objective): "The function must return a list of integers."

Output Format:
Your response must be a single JSON object.

{{
  "constraint_evaluations": [
    {{
      "constraint_text": "The exact text of the constraint from the input list.",
      "atomicity_score": int,      // Score from 1 to 5
      "relevance_score": int,      // Score from 1 to 5
      "objectivity_score": int,    // Score from 1 to 5
      "reasoning": "Detailed explanation for each score and, if any scores are low, suggestions for improving atomicity, relevance, or objectivity."
    }}
    // ... for each constraint in the input list
  ],
  "avg_atomicity": float,         // Average atomicity score
  "avg_relevance": float,         // Average relevance score
  "avg_objectivity": float,       // Average objectivity score
  "unified_quality_score": float, // Average of the three above
  "overall_analysis": "A summary of the overall quality of the constraint set, including strengths and weaknesses."
}}"""

prompt = get_quality_judge_prompt(df.iloc[0]["instruction"],df.iloc[0]["code"],df.iloc[0]["filtered_relevant_constraints"])
print(prompt)
# Out:
# Original Instruction: Design a Python Flask application that acts as a monitoring service for booking events. The application should receive messages from a RabbitMQ message broker, process these messages, and store them in a MySQL database. The messages represent logs of booking events in a JSON format.
#
# The application should have the following features:
#
# 1. Connect to a RabbitMQ message broker and listen for messages on a topic exchange named "booking_topic" with a routing key of '#', which means it will receive all messages regardless of the routing key used to send them.
# 2. When a message is received, it should be processed by adding it to a MySQL database table named 'monitoring'. Each log entry should have an auto-incrementing ID and a body that contains the JSON log data.
# 3. The application should use SQLAlchemy ORM for database interactions.
# 4. The application should handle the creation of the 'monitoring' table if it does not exist.
# 5. The application should provide a clear output to the console indicating when a message is received and when it is successfully stored in the database.
# 6. Include error handling for database and message broker connectivity issues.
#
# Original Code (for context, if available):
# ```python
# ```python
# from flask import Flask
# from flask_sqlalchemy import SQLAlchemy
# from sqlalchemy import desc
# import pika
# import json
# import os
#
# # Flask application setup
# app = Flask(__name__)
# app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql+mysqlconnector://root@localhost:3306/esd'
# app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
#
# # Database setup
# db = SQLAlchemy(app)
#
# # Model definition for the monitoring table
# class Monitor(db.Model):
#     __tablename__ = 'monitoring'
#
#     ID = db.Column(db.Integer, primary_key=True, autoincrement=True)
#     body = db.Column(db.Text, nullable=False)
#
#     def __init__(self, body):
#         self.body = body
#
#     def json(self):
#         return {"ID": self.ID, "body": self.body}
#
# # Create the database tables if they don't exist
# db.create_all()
#
# # RabbitMQ message receiving function
# def receive_booking_log():
#     hostname = "localhost"  # default host
#     port = 5672  # default port
#
#     # Connect to the broker and set up a communication channel
#     connection = pika.BlockingConnection(pika.ConnectionParameters(host=hostname, port=port))
#     channel = connection.channel()
#
#     # Set up the exchange if it doesn't exist
#     exchangename = "booking_topic"
#     channel.exchange_declare(exchange=exchangename, exchange_type='topic')
#
#     # Prepare a queue for receiving messages
#     channelqueue = channel.queue_declare(queue='', exclusive=True)
#     queue_name = channelqueue.method.queue
#     channel.queue_bind(exchange=exchangename, queue=queue_name, routing_key='#')
#
#     # Set up a consumer and start to wait for messages
#     channel.basic_consume(queue=queue_name, on_message_callback=callback, auto_ack=True)
#     channel.start_consuming()
#
# # Callback function for processing messages
# def callback(channel, method, properties, body):
#     print("Received a monitoring log by " + __file__)
#     process_log(json.loads(body))
#     print()  # print a new line feed
#
# # Function to process and store the log in the database
# def process_log(log):
#     print("Recording a monitoring log:")
#     monitor = Monitor(str(log))
#
#     db.session.add(monitor)
#     db.session.commit()
#
#     print("Monitoring log successfully added into database")
#     return "Success"
#
# if __name__ == "__main__":
#     print("This is " + os.path.basename(__file__) + ": monitoring for events...")
#     receive_booking_log()
# ```
#
# **Test Cases**:
#
# To verify the correctness of the solution, you can simulate the sending of a message to the RabbitMQ message broker and check if the message is received and stored in the database. You would need to have RabbitMQ and MySQL running with the appropriate configurations.
#
# 1. Send a test message to the RabbitMQ broker with the topic "booking.create" and a JSON body `{"event": "booking_created", "details": {"user_id": 123, "booking_id": 456}}`.
# 2. Check the console output to see if the message is received and processed by the Flask application.
# 3. Query the MySQL database to ensure that the log entry has been added to the 'monitoring' table with the correct JSON body.
#
# Please note that these test cases assume that the RabbitMQ broker and MySQL database are set up and configured correctly to work with the Flask application.
# ```
#
# List of Generated Constraints to Evaluate:
# [{'type': 'Library and API Usage', 'constraint': 'Use SQLAlchemy ORM for database interactions.', 'instruction_part': 'Extracted from instruction'}, {'type': 'File and Data Management', 'constraint': "Add received messages to a MySQL database table named 'monitoring'.", 'instruction_part': 'Extracted from instruction'}, {'type': 'File and Data Management', 'constraint': 'Each log entry should have an auto-incrementing ID and a body that contains the JSON log data.', 'instruction_part': 'Extracted from instruction'}, {'type': 'File and Data Management', 'constraint': "Handle the creation of the 'monitoring' table if it does not exist.", 'instruction_part': 'Extracted from instruction'}, {'type': 'Input and Output Handling', 'constraint': 'Provide a clear output to the console indicating when a message is received and when it is successfully stored in the database.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Error Handling and Robustness', 'constraint': 'Include error handling for database and message broker connectivity issues.', 'instruction_part': 'Extracted from instruction'}, {'type': 'Data Processing and Transformation', 'constraint': 'Ensure that the JSON log data is correctly parsed and validated before being stored in the database.', 'instruction_part': 'Newly Generated'}, {'type': 'Security and Privacy', 'constraint': 'Implement input validation to prevent SQL injection and ensure that only valid JSON messages are processed.', 'instruction_part': 'Newly Generated'}]
#
# Constraint Quality Criteria:
# Each score ranges from 1 (poor) to 5 (excellent).
#
# Atomicity Score (1–5):
# Definition: Measures whether a constraint expresses exactly one indivisible requirement.
# An atomic constraint should not contain multiple independent rules or directives.
# Examples:
# - 1 (Non-Atomic): "Return a float and raise ValueError for invalid input."
# - 5 (Atomic): "Raise ValueError for invalid input."
#
# Relevance Score (1–5):
# Definition: Measures how well the constraint aligns with the core task described in the instruction.
# A relevant constraint addresses functionality, behavior, or structure directly related to the task.
# Examples:
# - 1 (Off-topic): "Avoid using global variables."
# - 5 (Directly relevant): "Raise ValueError if the input DataFrame is empty."
#
# Objectivity Score (1–5):
# Definition: Measures whether the constraint can be evaluated without personal interpretation or judgment.
# An objective constraint uses measurable, observable, or clearly definable criteria.
# Examples:
# - 1 (Subjective): "The code should be intuitive and clean."
# - 5 (Objective): "The function must return a list of integers."
#
# Output Format:
# Your response must be a single JSON object.
#
# {
#   "constraint_evaluations": [
#     {
#       "constraint_text": "The exact text of the constraint from the input list.",
#       "atomicity_score": int,      // Score from 1 to 5
#       "relevance_score": int,      // Score from 1 to 5
#       "objectivity_score": int,    // Score from 1 to 5
#       "reasoning": "Detailed explanation for each score and, if any scores are low, suggestions for improving atomicity, relevance, or objectivity."
#     }
#     // ... for each constraint in the input list
#   ],
#   "avg_atomicity": float,         // Average atomicity score
#   "avg_relevance": float,         // Average relevance score
#   "avg_objectivity": float,       // Average objectivity score
#   "unified_quality_score": float, // Average of the three above
#   "overall_analysis": "A summary of the overall quality of the constraint set, including strengths and weaknesses."
# }

# %%
response = get_response(prompt,SYSTEM_PROMPT_QUALITY_JUDGE)
print(response)
# Out:
# ```json
# {
#   "constraint_evaluations": [
#     {
#       "constraint_text": "Use SQLAlchemy ORM for database interactions.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic as it specifies a single requirement regarding the use of SQLAlchemy ORM. It is highly relevant to the task of interacting with a MySQL database in the Flask application. The requirement is also objective, as it can be clearly evaluated by checking the code for the use of SQLAlchemy."
#     },
#     {
#       "constraint_text": "Add received messages to a MySQL database table named 'monitoring'.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic, focusing solely on the action of adding messages to a specific database table. It is directly relevant to the application's purpose of logging booking events. The objective nature of this constraint allows for straightforward verification by checking the database entries."
#     },
#     {
#       "constraint_text": "Each log entry should have an auto-incrementing ID and a body that contains the JSON log data.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic as it specifies two distinct attributes of the log entry, both of which are essential for the application's functionality. It is relevant because it directly pertains to how data is structured in the database. The criteria are objective, as they can be verified by examining the database schema."
#     },
#     {
#       "constraint_text": "Handle the creation of the 'monitoring' table if it does not exist.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic, focusing on a single requirement regarding the creation of the database table. It is relevant to the application's functionality, ensuring that the necessary table is available for logging. The objective nature allows for verification by checking the database state."
#     },
#     {
#       "constraint_text": "Provide a clear output to the console indicating when a message is received and when it is successfully stored in the database.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic as it specifies two distinct outputs related to message processing. It is relevant to the application's requirement for user feedback during operation. The outputs can be objectively verified by checking console logs."
#     },
#     {
#       "constraint_text": "Include error handling for database and message broker connectivity issues.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic, focusing on a single requirement for error handling. It is highly relevant as it addresses potential issues that could arise during operation. The effectiveness of error handling can be objectively evaluated through testing."
#     },
#     {
#       "constraint_text": "Ensure that the JSON log data is correctly parsed and validated before being stored in the database.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic, specifying a single requirement for data validation. It is relevant to the application's functionality, ensuring that only valid data is processed. The parsing and validation can be objectively tested through unit tests."
#     },
#     {
#       "constraint_text": "Implement input validation to prevent SQL injection and ensure that only valid JSON messages are processed.",
#       "atomicity_score": 5,
#       "relevance_score": 5,
#       "objectivity_score": 5,
#       "reasoning": "This constraint is atomic, focusing on two aspects of input validation. It is relevant as it addresses security concerns related to SQL injection and data integrity. The implementation can be objectively evaluated through code review and testing."
#     }
#   ],
#   "avg_atomicity": 5.0,
#   "avg_relevance": 5.0,
#   "avg_objectivity": 5.0,
#   "unified_quality_score": 5.0,
#   "overall_analysis": "The set of constraints is of excellent quality, with all constraints scoring the maximum in atomicity, relevance, and objectivity. Each constraint is clear, focused, and directly aligned with the requirements of the Flask application for monitoring booking events. There are no weaknesses identified, and the constraints collectively provide a robust framework for the application's development."
# }
# ```

# %%
def get_dict(response):
    try:
        json_string = response.strip().replace('```json\n', '', 1).replace('\n```', '', 1)
        dict_json = json.loads(json_string)
        return dict_json
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e} in string: {response}")
        return []
    except AttributeError as e:
        print(f"Attribute error: {e} in string: {response}")
        return []

# %%
# extract the final scores and keep them in separated 4 columns
def extract_quality_scores(df,score_column="quality_scores"):
    df["relevance_score"] = df[score_column].apply(lambda x: x.get("avg_relevance", 0) if isinstance(x, dict) else 0)
    df["objectivity_score"] = df[score_column].apply(lambda x: x.get("avg_objectivity", 0) if isinstance(x, dict) else 0)
    df["atomicity_score"] = df[score_column].apply(lambda x: x.get("avg_atomicity", 0) if isinstance(x, dict) else 0)
    df["unified_quality_score"] = df[score_column].apply(lambda x: x.get("unified_quality_score", 0) if isinstance(x, dict) else 0)
    return df

# %%
def measure_constraints(df,output_pth,input_col1,input_col2,input_col3,output_col):
    results = []
    prompts = []
    for _, row in df.iterrows():
        # print(f"Processing row {i}")
        prompt = get_quality_judge_prompt(row[input_col1], row[input_col2], row[input_col3])
        prompts.append(prompt)
    responses = get_model_response_batch(prompts,SYSTEM_PROMPT_QUALITY_JUDGE)
    # print(responses)
    results = [get_dict(response) for response in responses]
    df[output_col] = results
    df = extract_quality_scores(df)
    print(df.head())
    df.to_csv(output_pth, index=False)
    print("Saved the file successfully")
    return df

# %%
df = measure_constraints(df,"step5_with_quality_scores.csv","instruction","code","filtered_relevant_constraints","quality_scores")
df.head()
# Out:
# Processing: 100%|██████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:38<00:00,  1.56it/s]
#                                         dataset  \
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 19                              xlangai/DS-1000
# 26                         bigcode/bigcodebench
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
#
#                                           instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
#
#                                                  code  \
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 26  # Check if DataFrame is empty\n    if data.emp...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
#
#                                   relevant_categories  \
# 37  [Code Structure and Modularity, Input and Outp...
# 19  [Code Structure and Modularity, Input and Outp...
# 26  [Code Structure and Modularity, Input and Outp...
# 35  [Code Structure and Modularity, Input and Outp...
# 33  [Code Structure and Modularity, Input and Outp...
#
#                                simplified_instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
#
#                                 extracted_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
#
#                       final_comprehensive_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
#
#                         filtered_relevant_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
#
#                                        quality_scores  relevance_score  \
# 37  {'constraint_evaluations': [{'constraint_text'...            5.000
# 19  {'constraint_evaluations': [{'constraint_text'...            4.830
# 26  {'constraint_evaluations': [{'constraint_text'...            4.875
# 35  {'constraint_evaluations': [{'constraint_text'...            5.000
# 33  {'constraint_evaluations': [{'constraint_text'...            5.000
#
#     objectivity_score  atomicity_score  unified_quality_score
# 37               5.00             5.00               5.000000
# 19               4.67             4.67               4.720000
# 26               5.00             5.00               4.958333
# 35               5.00             5.00               5.000000
# 33               5.00             5.00               5.000000
# Saved the file successfully
#                                         dataset  \
# 37  Multilingual-Multimodal-NLP/McEval-Instruct
# 19                              xlangai/DS-1000
# 26                         bigcode/bigcodebench
# 35  Multilingual-Multimodal-NLP/McEval-Instruct
# 33  Multilingual-Multimodal-NLP/McEval-Instruct
#
#                                           instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
#
#                                                  code  \
# 37  ```python\nfrom flask import Flask\nfrom flask...
# 19          Feature = sparse.hstack((c1, c2)).tocsr()
# 26  # Check if DataFrame is empty\n    if data.emp...
# 35  ```python\n# motion_control.py\n\nimport drawp...
# 33  ```python\nimport pandas as pd\n\nclass MockSD...
#
#                                   relevant_categories  \
# 37  [Code Structure and Modularity, Input and Outp...
# 19  [Code Structure and Modularity, Input and Outp...
# 26  [Code Structure and Modularity, Input and Outp...
# 35  [Code Structure and Modularity, Input and Outp...
# 33  [Code Structure and Modularity, Input and Outp...
#
#                                simplified_instruction  \
# 37  Design a Python Flask application that acts as...
# 19  Problem:\nI have two csr_matrix, c1, c2.\n\nI ...
# 26  Perform a chi-square test of independence of v...
# 35  Write a Python module named `motion_control` t...
# 33  In a fictional universe, there are multiple sp...
#
#                                 extracted_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
#
#                       final_comprehensive_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
#
#                         filtered_relevant_constraints  \
# 37  [{'type': 'Library and API Usage', 'constraint...
# 19  [{'type': 'Library and API Usage', 'constraint...
# 26  [{'type': 'Error Handling and Robustness', 'co...
# 35  [{'type': 'Code Structure and Modularity', 'co...
# 33  [{'type': 'Code Structure and Modularity', 'co...
#
#                                        quality_scores  relevance_score  \
# 37  {'constraint_evaluations': [{'constraint_text'...            5.000
# 19  {'constraint_evaluations': [{'constraint_text'...            4.830
# 26  {'constraint_evaluations': [{'constraint_text'...            4.875
# 35  {'constraint_evaluations': [{'constraint_text'...            5.000
# 33  {'constraint_evaluations': [{'constraint_text'...            5.000
#
#     objectivity_score  atomicity_score  unified_quality_score
# 37               5.00             5.00               5.000000
# 19               4.67             4.67               4.720000
# 26               5.00             5.00               4.958333
# 35               5.00             5.00               5.000000
# 33               5.00             5.00               5.000000

# %%
# df = df.drop(columns=["","quality_scores","unified_quality_score"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 37 to 30
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   dataset                          60 non-null     object
#  1   instruction                      60 non-null     object
#  2   code                             60 non-null     object
#  3   relevant_categories              60 non-null     object
#  4   simplified_instruction           60 non-null     object
#  5   extracted_constraints            60 non-null     object
#  6   final_comprehensive_constraints  60 non-null     object
#  7   filtered_relevant_constraints    60 non-null     object
#  8   quality_scores                   60 non-null     object
#  9   relevance_score                  60 non-null     float64
#  10  objectivity_score                60 non-null     float64
#  11  atomicity_score                  60 non-null     float64
#  12  unified_quality_score            60 non-null     float64
# dtypes: float64(4), object(9)
# memory usage: 6.6+ KB

# %%
df.columns
# Out:
# Index(['dataset', 'instruction', 'code', 'relevant_categories',
#        'simplified_instruction', 'extracted_constraints',
#        'final_comprehensive_constraints', 'filtered_relevant_constraints',
#        'quality_scores', 'relevance_score', 'objectivity_score',
#        'atomicity_score', 'unified_quality_score'],
#       dtype='object')

# %%
# df = df.drop(columns=['quality_scores', 'specificity_score', 'objectivity_score',
#        'atomicity_score', 'unified_quality_score', 'relevance_score'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 37 to 30
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   dataset                          60 non-null     object
#  1   instruction                      60 non-null     object
#  2   code                             60 non-null     object
#  3   relevant_categories              60 non-null     object
#  4   simplified_instruction           60 non-null     object
#  5   extracted_constraints            60 non-null     object
#  6   final_comprehensive_constraints  60 non-null     object
#  7   filtered_relevant_constraints    60 non-null     object
#  8   quality_scores                   60 non-null     object
#  9   relevance_score                  60 non-null     float64
#  10  objectivity_score                60 non-null     float64
#  11  atomicity_score                  60 non-null     float64
#  12  unified_quality_score            60 non-null     float64
# dtypes: float64(4), object(9)
# memory usage: 6.6+ KB

# %% [markdown]
# # Step 8 - Generate code from Instruction and Generated Constraints

# %%
n = 10
# n=12
# n = 11

original_instruction = df.iloc[n]["instruction"]
new_constraints = df.iloc[n]["filtered_relevant_constraints"]
#filter new_constraints on 'instruction_part': 'Newly Generated'
def filter_new_constraints(constraints):
    return [c["constraint"] for c in constraints if c.get("instruction_part") == "Newly Generated"]

new_constraints = filter_new_constraints(new_constraints)
print(f"Original Instruction: {original_instruction}")
print("New Constraints:", new_constraints)

# %%
prompt = f""" Context: I have instruction for LLM to generate response and I also have some set of conditions for the model to follow while generating the response related to the instruction.
Task: Take the instruction and the conditions provided and insert the conditions into the instruction and return the new instruction.
Rules for completing the task:
1. For every condition , find a relevant position in the instruction where this condition could be easily be inserted and still the instruction make sense.
2. Depending on the need, paraphrase the condition to suit the relevant position in the instruction so that the condition is naturally inserted into the instruction.
3. Do not delete, reorder, or alter any original content.
4. Keep all punctuation, line breaks, return types, and code formatting intact.
5. Solution snippets demarcated by 'BEGIN SOLUTION', you **MUST NOT** modify or remove these from the new_instruction
## Input format:
{{"Instruction": {original_instruction}
"Conditions": {new_constraints} }}
## response format
{{"new_instruction": "The new instruction with the conditions merged in a natural way.}}"""
print("original_instruction:", original_instruction)
print("------------------")
print("new_constraints:", new_constraints)
print("------------------")
response = get_response(prompt)
print("New Instruction:", extract_json(response, "new_instruction"))
